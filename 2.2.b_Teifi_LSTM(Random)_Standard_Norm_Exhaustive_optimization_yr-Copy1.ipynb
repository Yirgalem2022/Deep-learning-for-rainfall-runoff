# %% [markdown]
# # Teifi catchment
# # 2. LSTM
# ## Kears_tuner:Random search
# ## Wider search space(0 to 100)

# %% [markdown]
# # Hyperparameter tuning using model_builder function from tensorflow   (Standard normalization)
# (After midterm)
# #(https://www.tensorflow.org/tutorials/keras/keras_tuner)

# %%
import numpy as np
import pandas as pd

### define file path
path = 'Teifi_R and Q with lag.csv'  ####### This excel data is not scaled/normalized

## Read CSV file and convert it to dataframe

df = pd.read_csv( path, sep = ',', header = 'infer')

# %% [raw]
# print(tf.__version__)

# %%
df
# Out:
#             Date    Rt  R_t_1  R_t_2  R_t_3  R_t_4  R_t_5  R_t_6  R_t_7  \
# 0     09/10/2000  15.7   11.8    1.6    2.8    1.1    7.7    7.7    2.9
# 1     10/10/2000  21.4   15.7   11.8    1.6    2.8    1.1    7.7    7.7
# 2     11/10/2000  10.3   21.4   15.7   11.8    1.6    2.8    1.1    7.7
# 3     12/10/2000  21.9   10.3   21.4   15.7   11.8    1.6    2.8    1.1
# 4     13/10/2000   2.7   21.9   10.3   21.4   15.7   11.8    1.6    2.8
# ...          ...   ...    ...    ...    ...    ...    ...    ...    ...
# 3639  26/09/2010   0.0    0.0    0.3    9.5   17.1    0.0    0.1    0.9
# 3640  27/09/2010   0.0    0.0    0.0    0.3    9.5   17.1    0.0    0.1
# 3641  28/09/2010  14.1    0.0    0.0    0.0    0.3    9.5   17.1    0.0
# 3642  29/09/2010   0.2   14.1    0.0    0.0    0.0    0.3    9.5   17.1
# 3643  30/09/2010  13.3    0.2   14.1    0.0    0.0    0.0    0.3    9.5
#
#       R_t_8      Qt
# 0      12.9   70.30
# 1       2.9   73.51
# 2       7.7   96.17
# 3       7.7  132.60
# 4       1.1  119.70
# ...     ...     ...
# 3639    0.5   17.29
# 3640    0.9   15.30
# 3641    0.1   14.28
# 3642    0.0   23.13
# 3643   17.1   19.60
#
# [3644 rows x 11 columns]

# %%
df = df.set_index('Date')
print(df)
# Out:
#               Rt  R_t_1  R_t_2  R_t_3  R_t_4  R_t_5  R_t_6  R_t_7  R_t_8  \
# Date
# 09/10/2000  15.7   11.8    1.6    2.8    1.1    7.7    7.7    2.9   12.9
# 10/10/2000  21.4   15.7   11.8    1.6    2.8    1.1    7.7    7.7    2.9
# 11/10/2000  10.3   21.4   15.7   11.8    1.6    2.8    1.1    7.7    7.7
# 12/10/2000  21.9   10.3   21.4   15.7   11.8    1.6    2.8    1.1    7.7
# 13/10/2000   2.7   21.9   10.3   21.4   15.7   11.8    1.6    2.8    1.1
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 26/09/2010   0.0    0.0    0.3    9.5   17.1    0.0    0.1    0.9    0.5
# 27/09/2010   0.0    0.0    0.0    0.3    9.5   17.1    0.0    0.1    0.9
# 28/09/2010  14.1    0.0    0.0    0.0    0.3    9.5   17.1    0.0    0.1
# 29/09/2010   0.2   14.1    0.0    0.0    0.0    0.3    9.5   17.1    0.0
# 30/09/2010  13.3    0.2   14.1    0.0    0.0    0.0    0.3    9.5   17.1
#
#                 Qt
# Date
# 09/10/2000   70.30
# 10/10/2000   73.51
# 11/10/2000   96.17
# 12/10/2000  132.60
# 13/10/2000  119.70
# ...            ...
# 26/09/2010   17.29
# 27/09/2010   15.30
# 28/09/2010   14.28
# 29/09/2010   23.13
# 30/09/2010   19.60
#
# [3644 rows x 10 columns]

# %%
df.describe()
# Out:
#                 Rt        R_t_1        R_t_2        R_t_3        R_t_4  \
# count  3644.000000  3644.000000  3644.000000  3644.000000  3644.000000
# mean      3.992179     3.991767     3.992151     3.989050     3.989352
# std       6.542103     6.541564     6.541383     6.539268     6.539109
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       1.100000     1.100000     1.100000     1.100000     1.100000
# 75%       5.300000     5.300000     5.300000     5.300000     5.300000
# max      60.000000    60.000000    60.000000    60.000000    60.000000
#
#              R_t_5        R_t_6        R_t_7        R_t_8           Qt
# count  3644.000000  3644.000000  3644.000000  3644.000000  3644.000000
# mean      3.991465     3.993578     3.994292     3.995225    30.440950
# std       6.539064     6.539018     6.538756     6.539785    34.149581
# min       0.000000     0.000000     0.000000     0.000000     2.085000
# 25%       0.000000     0.000000     0.000000     0.000000     8.120500
# 50%       1.100000     1.100000     1.100000     1.100000    18.020000
# 75%       5.300000     5.300000     5.300000     5.300000    40.450000
# max      60.000000    60.000000    60.000000    60.000000   373.000000

# %%
#### visualize the distribution
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
# Plot the distribution of rainfall data as a histogram
sns.histplot(df["Rt"], kde=False)

# Add labels and title to the plot
plt.xlabel("Rainfall (mm)")
plt.ylabel("Frequency")
plt.title("Histogram of Rainfall Data")
# plt.xlim(0, 80)
# plt.ylim(0, 300)
plt.show()

# %% [markdown]
# # 1. Data splitting

# %% [markdown]
# ##  Train, Validation and Test data
# ###  70% train (2550 data points)
# ###  15% train (547 data points)
# ###  15% train (547 data points)

# %%
df_train = df.iloc[:2550]

df_val = df.iloc[2550:3097] 

# df_test = df.iloc[3097:] 
df_test = df.tail(547).iloc[:]   ## gives the same result as the above line of code

# %%
df_train
# Out:
#               Rt  R_t_1  R_t_2  R_t_3  R_t_4  R_t_5  R_t_6  R_t_7  R_t_8  \
# Date
# 09/10/2000  15.7   11.8    1.6    2.8    1.1    7.7    7.7    2.9   12.9
# 10/10/2000  21.4   15.7   11.8    1.6    2.8    1.1    7.7    7.7    2.9
# 11/10/2000  10.3   21.4   15.7   11.8    1.6    2.8    1.1    7.7    7.7
# 12/10/2000  21.9   10.3   21.4   15.7   11.8    1.6    2.8    1.1    7.7
# 13/10/2000   2.7   21.9   10.3   21.4   15.7   11.8    1.6    2.8    1.1
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 28/09/2007   0.5    0.0    0.7    7.5    5.6   26.1    2.4    6.0    4.9
# 29/09/2007   0.5    0.5    0.0    0.7    7.5    5.6   26.1    2.4    6.0
# 30/09/2007   1.1    0.5    0.5    0.0    0.7    7.5    5.6   26.1    2.4
# 01/10/2007   0.1    1.1    0.5    0.5    0.0    0.7    7.5    5.6   26.1
# 02/10/2007   0.0    0.1    1.1    0.5    0.5    0.0    0.7    7.5    5.6
#
#                  Qt
# Date
# 09/10/2000   70.300
# 10/10/2000   73.510
# 11/10/2000   96.170
# 12/10/2000  132.600
# 13/10/2000  119.700
# ...             ...
# 28/09/2007   15.180
# 29/09/2007   12.430
# 30/09/2007   10.660
# 01/10/2007    9.556
# 02/10/2007    8.796
#
# [2550 rows x 10 columns]

# %% [markdown]
# # 2. Normalization

# %%
import pandas as pd
import numpy as np

### General function for all the normalization methods

def normalize_df(data, norm_method):     

    ## Normalize data using specified method
 
    if norm_method == 'minmax':
        # Min-Max normalization
        data_n = (data - data.min()) / (data.max() - data.min())
    elif norm_method == 'zscore':
        # Z-score normalization
        mean = data.mean()
        std = data.std()
        data_n = (data - mean) / std
    elif norm_method == 'max':
        # Max normalization
        data_n = 1 - ((data.max() - data)/data.max())
    else:
        raise ValueError("Invalid normalization method. Choose from: 'minmax', 'zscore', 'max'")
    return data_n

# %% [markdown]
# ### Standard normalization  (Data sets for training, validation and testing are nromalized separately)

# %%
## Z_score(standard)
df_train_norm = normalize_df(df_train, 'zscore')
df_val_norm = normalize_df(df_val, 'zscore')
df_test_norm = normalize_df(df_test, 'zscore')

# %%
###example
df_train_norm.describe()
# Out:
#                  Rt         R_t_1         R_t_2         R_t_3         R_t_4  \
# count  2.550000e+03  2.550000e+03  2.550000e+03  2.550000e+03  2.550000e+03
# mean  -2.099671e-15 -2.549943e-15 -1.856685e-15 -2.574847e-15 -2.324807e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -6.082633e-01 -6.088429e-01 -6.089583e-01 -6.090787e-01 -6.091250e-01
# 25%   -6.082633e-01 -6.088429e-01 -6.089583e-01 -6.090787e-01 -6.091250e-01
# 50%   -4.413379e-01 -4.343651e-01 -4.268866e-01 -4.270013e-01 -4.270444e-01
# 75%    1.808389e-01  1.801004e-01  1.800189e-01  1.799234e-01  1.798909e-01
# max    8.496762e+00  8.494350e+00  8.494624e+00  8.494792e+00  8.494905e+00
#
#               R_t_5         R_t_6         R_t_7         R_t_8            Qt
# count  2.550000e+03  2.550000e+03  2.550000e+03  2.550000e+03  2.550000e+03
# mean  -2.219924e-15 -2.402566e-15 -2.379970e-15 -2.489621e-15  1.455045e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -6.095501e-01 -6.100155e-01 -6.101733e-01 -6.103107e-01 -8.089168e-01
# 25%   -6.095501e-01 -6.100155e-01 -6.101733e-01 -6.103107e-01 -6.712789e-01
# 50%   -4.274705e-01 -4.279337e-01 -4.280835e-01 -4.282758e-01 -3.507176e-01
# 75%    1.794615e-01  1.903855e-01  1.902630e-01  1.898844e-01  2.884958e-01
# max    8.494430e+00  8.494071e+00  8.494315e+00  8.491435e+00  9.760296e+00

# %%
### convert the dataframes to numpy arrays

df_train_f = df_train_norm.to_numpy()

df_val_f = df_val_norm.to_numpy()

df_test_f = df_test_norm.to_numpy()

# %%
### Define input and output sequences (list of sub sequences)

def split_sequences(sequences, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequences)):
    # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out-1
    # check if we are beyond the dataset
        if out_end_ix > len(sequences):
            break
    # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1:out_end_ix, -1] 
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

n_steps_in, n_steps_out = 1, 1    #### 1 input sequences and 1 output sequences

# %% [markdown]
# ### Split into input and target variables

# %%
#### Training data


X_train, y_train = split_sequences(df_train_f, n_steps_in, n_steps_out)
print(X_train.shape, y_train.shape)

# reshape from [samples, timesteps] into [samples, timesteps, features]

n_features = 9   ## 9 rainfall inputs

X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
print(X_train.shape)
# Out:
# (2550, 1, 9) (2550, 1)
# (2550, 1, 9)

# %%
#### validation data

X_val, y_val = split_sequences(df_val_f , n_steps_in, n_steps_out)


X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], n_features))

### reshape

X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], n_features))

print(X_val.shape, y_val.shape)
# Out:
# (547, 1, 9) (547, 1)

# %%
#### Test data

X_test, y_test = split_sequences(df_test_f , n_steps_in, n_steps_out)

X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))

print(X_test.shape, y_test.shape)
# Out:
# (547, 1, 9) (547, 1)

# %% [raw]
# !pip install keras

# %% [raw]
# !pip install tensorflow

# %%
#### model fitting
import keras
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import save_model

from tensorflow.keras import initializers

from tensorflow.keras import layers

# %% [markdown]
# ## Hyperparameter tuning using KerasTuner

# %% [raw]
# !pip install keras-tuner --upgrade

# %%
import keras_tuner as kt


from keras_tuner.engine.hyperparameters import HyperParameters
from keras_tuner.engine.hyperparameters import Choice,Float

# %% [markdown]
# ### a. Define model (Using model_buider function)
# ### (https://www.tensorflow.org/tutorials/keras/keras_tuner)
# ## LSTM

# %%
def model_builder(hp):
    model = keras.Sequential()
    ##1. Tune number of units
    hp_units = hp.Int('units', min_value = 1, max_value = 100, step = 1)
    
    ##2. Tune weight initialization method
    
    hp_initializer=hp.Choice('weight_init', ['he_uniform', 'glorot_uniform', 'random_normal' , 'lecun_normal'])
    ### Fix the seeds for reproducibility purposes     
    if hp_initializer == 'he_uniform':
        init = tf.keras.initializers.he_uniform(seed=1)
    elif hp_initializer == 'glorot_uniform':
        init = tf.keras.initializers.glorot_uniform(seed=1)
    elif hp_initializer == 'random_normal':
        init = tf.keras.initializers.RandomNormal(seed=1)
    else:
        init = tf.keras.initializers.lecun_normal(seed=1)

    ##3. Tune number of layers   
    ###4. Tune the activation function

    hp_activation = hp.Choice("activation", ["relu", "tanh", "sigmoid"])
    
    for i in range(hp.Int("num_layers", 1, 3)):
        
        model.add(keras.layers.LSTM(units=hp_units,
                                activation = hp_activation,
                                return_sequences=True,
                                kernel_initializer = init))
        ##5. Tune dropout rate
        model.add(Dropout(hp.Float('dropout_rate', 0, 0.3, step=0.1)))
        
    
    model.add(keras.layers.Dense(1, kernel_initializer = init))
    
    ##6. Tune optimizer
    
    hp_optimizer = hp.Choice("optimizer", ['Adam', 'SGD', 'RMSprop'])

    model.compile (optimizer = hp_optimizer, 
                   loss='mean_squared_error',
                   metrics=[tf.keras.metrics.MeanSquaredError()])
    
    return model

# %% [markdown]
# ### b.  Instantiate the tuner and perform hypertuning
# ###### Random search

# %%
#### Random search
from keras_tuner.tuners import RandomSearch
tuner = RandomSearch(
    model_builder,
    objective='val_loss',
    max_trials=100,
    executions_per_trial=1,
    directory='Exhaustive_Opt_norm',
    project_name='Teifi_LSTM_RandomS_1')

# %%
### Create a callback to stop training early after reaching a certain value for the validation loss.

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
# %load_ext tensorboard

# %% [raw]
# rm -rf ./logs/

# %%
from keras.callbacks import TensorBoard

import datetime, os
log_dir = "Exhaustive_Opt_norm/Teifi_LS_test_1" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %% [markdown]
# ### C. Run hyperparameter search

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
 tuner.search(X_train, y_train, 
             epochs=200, 
             validation_data=(X_val, y_val), 
             callbacks=[stop_early,tb])
# Out:
# Trial 100 Complete [00h 00m 42s]
# val_loss: 0.20542681217193604
#
# Best val_loss So Far: 0.16664308309555054
# Total elapsed time: 01h 45m 07s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in Exhaustive_Opt_norm\Teifi_LSTM_RandomS_1
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x000001902AD20610>
# Trial summary
# Hyperparameters:
# units: 7
# weight_init: random_normal
# activation: relu
# num_layers: 2
# dropout_rate: 0.0
# optimizer: RMSprop
# Score: 0.16664308309555054
# Trial summary
# Hyperparameters:
# units: 9
# weight_init: random_normal
# activation: relu
# num_layers: 2
# dropout_rate: 0.0
# optimizer: Adam
# Score: 0.16739515960216522
# Trial summary
# Hyperparameters:
# units: 6
# weight_init: random_normal
# activation: relu
# num_layers: 2
# dropout_rate: 0.1
# optimizer: RMSprop
# Score: 0.16953468322753906
# Trial summary
# Hyperparameters:
# units: 10
# weight_init: random_normal
# activation: relu
# num_layers: 2
# dropout_rate: 0.0
# optimizer: Adam
# Score: 0.17095410823822021
# Trial summary
# Hyperparameters:
# units: 10
# weight_init: random_normal
# activation: relu
# num_layers: 1
# dropout_rate: 0.0
# optimizer: SGD
# Score: 0.17191533744335175
# Trial summary
# Hyperparameters:
# units: 7
# weight_init: random_normal
# activation: relu
# num_layers: 2
# dropout_rate: 0.1
# optimizer: Adam
# Score: 0.17309631407260895
# Trial summary
# Hyperparameters:
# units: 3
# weight_init: random_normal
# activation: sigmoid
# num_layers: 1
# dropout_rate: 0.0
# optimizer: SGD
# Score: 0.1745733916759491
# Trial summary
# Hyperparameters:
# units: 5
# weight_init: random_normal
# activation: sigmoid
# num_layers: 1
# dropout_rate: 0.0
# optimizer: SGD
# Score: 0.17503193020820618
# Trial summary
# Hyperparameters:
# units: 9
# weight_init: random_normal
# activation: sigmoid
# num_layers: 1
# dropout_rate: 0.0
# optimizer: RMSprop
# Score: 0.17717593908309937
# Trial summary
# Hyperparameters:
# units: 5
# weight_init: random_normal
# activation: relu
# num_layers: 2
# dropout_rate: 0.1
# optimizer: RMSprop
# Score: 0.17885421216487885

# %%
# %tensorboard --logdir Exhaustive_Opt_norm/Teifi_test_1
# Out:
# Reusing TensorBoard on port 6006 (pid 9648), started 23:23:03 ago. (Use '!kill 9648' to kill it.)
#       <iframe id="tensorboard-frame-f34591154beb79" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f34591154beb79");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### steps in tensorboard

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [raw]
# rm -rf ./logs/

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
# %tensorboard --logdir logs/fit
# Out:
# Reusing TensorBoard on port 6006 (pid 5332), started 21:33:35 ago. (Use '!kill 5332' to kill it.)
#       <iframe id="tensorboard-frame-b102aeb8f38af289" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b102aeb8f38af289");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir /Exhaustive_Opt_norm/
# Out:
# Reusing TensorBoard on port 6006 (pid 10448), started 21:33:02 ago. (Use '!kill 10448' to kill it.)
#       <iframe id="tensorboard-frame-771c5eddfa4bf0bc" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-771c5eddfa4bf0bc");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir AMT_Exhaustive_optimization/Test1--port=7007
# Out:
# Reusing TensorBoard on port 6006 (pid 10312), started 21:32:18 ago. (Use '!kill 10312' to kill it.)
#       <iframe id="tensorboard-frame-cdcd4adfe262a396" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-cdcd4adfe262a396");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## d.  get the optimal hyperparameters

# %%
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]



print(f"""
The hyperparameter search is complete. 

The optimal number of units in the first densely-connected layer is {best_hps.get('units')}, 
The optimal activation function is {best_hps.get('activation')},
The optimal weight initialization is {best_hps.get('weight_init')}
The optimal optimizer is {best_hps.get('optimizer')}.
The optimal number of layers is {best_hps.get('num_layers')},
The optimal dropout rate is {best_hps.get('dropout_rate')},

""")
# Out:
# The hyperparameter search is complete.
#
# The optimal number of units in the first densely-connected layer is 7,
# The optimal activation function is relu,
# The optimal weight initialization is random_normal
# The optimal optimizer is RMSprop.
# The optimal number of layers is 2,
# The optimal dropout rate is 0.0,

# %% [markdown]
# ## e. Train the model using the best model

# %%
model = tuner.hypermodel.build(best_hps)

# %%
### model training 
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
LSTM_T_1 = model.fit(X_train, y_train, epochs=200, validation_data = (X_val, y_val), shuffle = 0,callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 80/80 [==============================] - 6s 15ms/step - loss: 1.0000 - mean_squared_error: 1.0000 - val_loss: 0.9978 - val_mean_squared_error: 0.9978
# Epoch 2/200
# 80/80 [==============================] - 1s 8ms/step - loss: 0.9989 - mean_squared_error: 0.9989 - val_loss: 0.9954 - val_mean_squared_error: 0.9954
# Epoch 3/200
# 80/80 [==============================] - 1s 7ms/step - loss: 0.9939 - mean_squared_error: 0.9939 - val_loss: 0.9858 - val_mean_squared_error: 0.9858
# Epoch 4/200
# 80/80 [==============================] - 1s 7ms/step - loss: 0.9774 - mean_squared_error: 0.9774 - val_loss: 0.9583 - val_mean_squared_error: 0.9583
# Epoch 5/200
# 80/80 [==============================] - 1s 8ms/step - loss: 0.9341 - mean_squared_error: 0.9341 - val_loss: 0.8931 - val_mean_squared_error: 0.8931
# Epoch 6/200
# 80/80 [==============================] - 1s 7ms/step - loss: 0.8384 - mean_squared_error: 0.8384 - val_loss: 0.7607 - val_mean_squared_error: 0.7607
# Epoch 7/200
# 80/80 [==============================] - 1s 7ms/step - loss: 0.6683 - mean_squared_error: 0.6683 - val_loss: 0.5521 - val_mean_squared_error: 0.5521
# Epoch 8/200
# 80/80 [==============================] - 1s 7ms/step - loss: 0.4594 - mean_squared_error: 0.4594 - val_loss: 0.3478 - val_mean_squared_error: 0.3478
# Epoch 9/200
# 80/80 [==============================] - 1s 7ms/step - loss: 0.3173 - mean_squared_error: 0.3173 - val_loss: 0.2446 - val_mean_squared_error: 0.2446
# Epoch 10/200
# 80/80 [==============================] - 1s 8ms/step - loss: 0.2665 - mean_squared_error: 0.2665 - val_loss: 0.2123 - val_mean_squared_error: 0.2123
# Epoch 11/200
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2468 - mean_squared_error: 0.2468 - val_loss: 0.1983 - val_mean_squared_error: 0.1983
# Epoch 12/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2338 - mean_squared_error: 0.2338 - val_loss: 0.1899 - val_mean_squared_error: 0.1899
# Epoch 13/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2251 - mean_squared_error: 0.2251 - val_loss: 0.1847 - val_mean_squared_error: 0.1847
# Epoch 14/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2194 - mean_squared_error: 0.2194 - val_loss: 0.1814 - val_mean_squared_error: 0.1814
# Epoch 15/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2156 - mean_squared_error: 0.2156 - val_loss: 0.1794 - val_mean_squared_error: 0.1794
# Epoch 16/200
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2132 - mean_squared_error: 0.2132 - val_loss: 0.1780 - val_mean_squared_error: 0.1780
# Epoch 17/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2115 - mean_squared_error: 0.2115 - val_loss: 0.1772 - val_mean_squared_error: 0.1772
# Epoch 18/200
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2102 - mean_squared_error: 0.2102 - val_loss: 0.1765 - val_mean_squared_error: 0.1765
# Epoch 19/200
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2093 - mean_squared_error: 0.2093 - val_loss: 0.1761 - val_mean_squared_error: 0.1761
# Epoch 20/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2084 - mean_squared_error: 0.2084 - val_loss: 0.1757 - val_mean_squared_error: 0.1757
# Epoch 21/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2077 - mean_squared_error: 0.2077 - val_loss: 0.1754 - val_mean_squared_error: 0.1754
# Epoch 22/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2070 - mean_squared_error: 0.2070 - val_loss: 0.1751 - val_mean_squared_error: 0.1751
# Epoch 23/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2063 - mean_squared_error: 0.2063 - val_loss: 0.1749 - val_mean_squared_error: 0.1749
# Epoch 24/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2056 - mean_squared_error: 0.2056 - val_loss: 0.1747 - val_mean_squared_error: 0.1747
# Epoch 25/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2050 - mean_squared_error: 0.2050 - val_loss: 0.1746 - val_mean_squared_error: 0.1746
# Epoch 26/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2042 - mean_squared_error: 0.2042 - val_loss: 0.1745 - val_mean_squared_error: 0.1745
# Epoch 27/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2035 - mean_squared_error: 0.2035 - val_loss: 0.1745 - val_mean_squared_error: 0.1745
# Epoch 28/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2028 - mean_squared_error: 0.2028 - val_loss: 0.1744 - val_mean_squared_error: 0.1744
# Epoch 29/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2020 - mean_squared_error: 0.2020 - val_loss: 0.1744 - val_mean_squared_error: 0.1744
# Epoch 30/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2012 - mean_squared_error: 0.2012 - val_loss: 0.1745 - val_mean_squared_error: 0.1745
# Epoch 31/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2004 - mean_squared_error: 0.2004 - val_loss: 0.1746 - val_mean_squared_error: 0.1746
# Epoch 32/200
# 80/80 [==============================] - 0s 6ms/step - loss: 0.1995 - mean_squared_error: 0.1995 - val_loss: 0.1747 - val_mean_squared_error: 0.1747
# Epoch 33/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1987 - mean_squared_error: 0.1987 - val_loss: 0.1749 - val_mean_squared_error: 0.1749
# Epoch 34/200
# 80/80 [==============================] - 0s 6ms/step - loss: 0.1978 - mean_squared_error: 0.1978 - val_loss: 0.1752 - val_mean_squared_error: 0.1752
# Epoch 35/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1969 - mean_squared_error: 0.1969 - val_loss: 0.1755 - val_mean_squared_error: 0.1755
# Epoch 36/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1959 - mean_squared_error: 0.1959 - val_loss: 0.1759 - val_mean_squared_error: 0.1759
# Epoch 37/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1949 - mean_squared_error: 0.1949 - val_loss: 0.1763 - val_mean_squared_error: 0.1763
# Epoch 38/200
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1939 - mean_squared_error: 0.1939 - val_loss: 0.1768 - val_mean_squared_error: 0.1768

# %% [raw]
# ### To find out how much time the model is taking to train
# ### Think about this one more
# import time
# start_time = time.time()
# tuner.search(X_train, y_train, validation_data=(X_val, y_val))
# end_time = time.time()
#
# elapsed_time = end_time - start_time
# print("Time elapsed: {:.2f} seconds".format(elapsed_time))

# %% [markdown]
# ## Plot training and validation errors

# %%
plt.plot(LSTM_T_1.history['mean_squared_error'], label = 'Training loss')
plt.plot(LSTM_T_1.history['val_mean_squared_error'], label = 'Validation loss')
plt.title('Mean Squared Error')
plt.xlabel('epochs')
plt.ylabel('mse')
plt.legend()

# %%
model.summary()   #### this shows us that the number of layers are 3 in this MLP model
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 1, 7)              476
#
#  dropout_8 (Dropout)         (None, 1, 7)              0
#
#  lstm_9 (LSTM)               (None, 1, 7)              420
#
#  dropout_9 (Dropout)         (None, 1, 7)              0
#
#  dense_4 (Dense)             (None, 1, 1)              8
#
# =================================================================
# Total params: 904
# Trainable params: 904
# Non-trainable params: 0
# _________________________________________________________________

# %% [raw]
# #### find the best epoch by looking in to the validation loss
#
# val_acc_per_epoch = LSTM_T_1.history['val_loss']
#
# #### 'val_loss' should align with the objective function used when applying 'tuner.search' (both should be loss or both accuracy)
#
# best_epoch = val_acc_per_epoch.index(min(val_acc_per_epoch)) + 1
#
# print('Best epoch: %d' % (best_epoch,))

# %% [raw]
# ### Re-instantiate the hypermodel and train it with the optimal number of epochs from above.
#
# hypermodel = tuner.hypermodel.build(best_hps)
#
# # Retrain the model
#
# hypermodel.fit(X_train, y_train, epochs= best_epoch, verbose = 1, validation_data=(X_val, y_val), shuffle = False)
#
# # hypermodel.fit(X_train, y_train, epochs= 250, verbose = 1, validation_data=(X_val, y_val), shuffle = False)

# %% [markdown]
# ## f. Test best model

# %%
eval_result = model.evaluate(X_test, y_test)
# eval_result = hypermodel.evaluate(X_test, y_test)

print("[test loss, test accuracy]:", eval_result)
# Out:
# 18/18 [==============================] - 0s 2ms/step - loss: 0.2371 - mean_squared_error: 0.2371
# [test loss, test accuracy]: [0.2371475249528885, 0.2371475249528885]

# %%
Y_pred = model.predict(X_test)   ### when using early stopping
# Y_pred = hypermodel.predict(X_test)
# Out:
# 18/18 [==============================] - 0s 2ms/step

# %%
#        [ 7.46174529e-02],
#        [ 2.47571677e-01]], dtype=float32)

# %%
y_test
# Out:
# array([[-0.56212305],
#        [-0.57290687],
#        [-0.57818475],
#        [-0.5882844 ],
#        [-0.58369069],
#        [-0.51338408],
#        [-0.42525648],
#        [-0.4581618 ],
#        [-0.44578158],
#        [-0.46532929],
#        [-0.51706557],
#        [-0.53729745],
#        [-0.54394367],
#        [-0.55342431],
#        [-0.53309469],
#        [-0.49986358],
#        [-0.49627984],
#        [-0.54475816],
#        [-0.56886701],
#        [-0.58202913],
#        [-0.58880567],
#        [-0.59567995],
#        [-0.60297776],
#        [-0.59861211],
#        [-0.57404715],
#        [-0.34380768],
#        [-0.40114764],
#        [-0.43991727],
#        [-0.2613815 ],
#        [-0.3356628 ],
#        [-0.41352786],
#        [-0.44610738],
#        [-0.46044236],
#        [-0.47640633],
#        [-0.48878655],
#        [-0.4988862 ],
#        [-0.49953779],
#        [-0.52403759],
#        [-0.54381336],
#        [-0.56495746],
#        [-0.5844726 ],
#        [-0.59056497],
#        [-0.56036375],
#        [ 0.07842289],
#        [ 0.11784411],
#        [ 0.25858764],
#        [ 0.90301054],
#        [ 1.41939593],
#        [ 0.93168052],
#        [ 0.70069172],
#        [ 0.42963012],
#        [ 0.28628023],
#        [ 0.08168085],
#        [-0.04928882],
#        [-0.12487331],
#        [ 0.18756429],
#        [ 0.19636076],
#        [-0.13399557],
#        [-0.2610557 ],
#        [-0.33207906],
#        [-0.3832289 ],
#        [-0.42590807],
#        [-0.45425226],
#        [-0.4917187 ],
#        [-0.5041315 ],
#        [-0.14539841],
#        [ 0.38988311],
#        [-0.12226695],
#        [-0.30634123],
#        [-0.30992498],
#        [-0.30536385],
#        [-0.37964515],
#        [-0.42981762],
#        [-0.46304873],
#        [-0.44838794],
#        [-0.48455121],
#        [-0.45653282],
#        [-0.49953779],
#        [-0.52745844],
#        [-0.54821159],
#        [-0.56029859],
#        [-0.57254849],
#        [-0.58825182],
#        [-0.60441126],
#        [-0.61858335],
#        [-0.62141777],
#        [-0.62695629],
#        [-0.63842428],
#        [-0.65073934],
#        [-0.66067609],
#        [-0.66152316],
#        [-0.64907778],
#        [-0.61939784],
#        [-0.62285127],
#        [-0.60059946],
#        [-0.36661335],
#        [-0.12780547],
#        [-0.20762529],
#        [-0.43274977],
#        [-0.53094445],
#        [-0.48748337],
#        [-0.34152712],
#        [-0.42199853],
#        [-0.4373109 ],
#        [-0.33110167],
#        [ 0.42278842],
#        [ 3.58821457],
#        [ 2.23746768],
#        [ 1.27343968],
#        [ 0.80005926],
#        [ 0.79680131],
#        [ 0.66648323],
#        [ 0.62738781],
#        [ 0.51042733],
#        [ 0.32472407],
#        [ 0.42539478],
#        [ 0.40161173],
#        [ 0.56744149],
#        [ 1.61291828],
#        [ 1.09555551],
#        [ 0.78800484],
#        [ 0.86749887],
#        [ 0.48729587],
#        [ 0.43028171],
#        [ 0.56907046],
#        [ 0.36381949],
#        [ 0.17094873],
#        [ 0.01782499],
#        [-0.09099061],
#        [-0.16722669],
#        [ 0.48631848],
#        [ 0.51629164],
#        [ 0.37978345],
#        [ 0.06897483],
#        [-0.17146202],
#        [-0.25877514],
#        [-0.31937304],
#        [-0.37834197],
#        [-0.29656738],
#        [ 0.1123056 ],
#        [ 0.2344788 ],
#        [-0.10304503],
#        [-0.26626843],
#        [-0.33110167],
#        [-0.36433278],
#        [-0.07600403],
#        [-0.19100973]])

# %%
y_test.shape
# Out:
# (547, 1)

# %%
print(y_test[:,:-1].shape)   
print(y_test[:,1:2].shape)
# Out:
# (547, 0)
# (547, 0)

# %%
y_test[:,-1:]    ##### all rows and all columns including -1(which is the last column)
# Out:
# array([[-0.56212305],
#        [-0.57290687],
#        [-0.57818475],
#        [-0.5882844 ],
#        [-0.58369069],
#        [-0.51338408],
#        [-0.42525648],
#        [-0.4581618 ],
#        [-0.44578158],
#        [-0.46532929],
#        [-0.51706557],
#        [-0.53729745],
#        [-0.54394367],
#        [-0.55342431],
#        [-0.53309469],
#        [-0.49986358],
#        [-0.49627984],
#        [-0.54475816],
#        [-0.56886701],
#        [-0.58202913],
#        [-0.58880567],
#        [-0.59567995],
#        [-0.60297776],
#        [-0.59861211],
#        [-0.57404715],
#        [-0.34380768],
#        [-0.40114764],
#        [-0.43991727],
#        [-0.2613815 ],
#        [-0.3356628 ],
#        [-0.41352786],
#        [-0.44610738],
#        [-0.46044236],
#        [-0.47640633],
#        [-0.48878655],
#        [-0.4988862 ],
#        [-0.49953779],
#        [-0.52403759],
#        [-0.54381336],
#        [-0.56495746],
#        [-0.5844726 ],
#        [-0.59056497],
#        [-0.56036375],
#        [ 0.07842289],
#        [ 0.11784411],
#        [ 0.25858764],
#        [ 0.90301054],
#        [ 1.41939593],
#        [ 0.93168052],
#        [ 0.70069172],
#        [ 0.42963012],
#        [ 0.28628023],
#        [ 0.08168085],
#        [-0.04928882],
#        [-0.12487331],
#        [ 0.18756429],
#        [ 0.19636076],
#        [-0.13399557],
#        [-0.2610557 ],
#        [-0.33207906],
#        [-0.3832289 ],
#        [-0.42590807],
#        [-0.45425226],
#        [-0.4917187 ],
#        [-0.5041315 ],
#        [-0.14539841],
#        [ 0.38988311],
#        [-0.12226695],
#        [-0.30634123],
#        [-0.30992498],
#        [-0.30536385],
#        [-0.37964515],
#        [-0.42981762],
#        [-0.46304873],
#        [-0.44838794],
#        [-0.48455121],
#        [-0.45653282],
#        [-0.49953779],
#        [-0.52745844],
#        [-0.54821159],
#        [-0.56029859],
#        [-0.57254849],
#        [-0.58825182],
#        [-0.60441126],
#        [-0.61858335],
#        [-0.62141777],
#        [-0.62695629],
#        [-0.63842428],
#        [-0.65073934],
#        [-0.66067609],
#        [-0.66152316],
#        [-0.64907778],
#        [-0.61939784],
#        [-0.62285127],
#        [-0.60059946],
#        [-0.36661335],
#        [-0.12780547],
#        [-0.20762529],
#        [-0.43274977],
#        [-0.53094445],
#        [-0.48748337],
#        [-0.34152712],
#        [-0.42199853],
#        [-0.4373109 ],
#        [-0.33110167],
#        [ 0.42278842],
#        [ 3.58821457],
#        [ 2.23746768],
#        [-0.2066479 ],
#        [-0.36661335],
#        [-0.44741056],
#        [-0.42655966],
#        [-0.30699283],
#        [-0.40538298],
#        [-0.4780353 ],
#        [-0.50312154],
#        [-0.52775165],
#        [-0.5542388 ],
#        [-0.57489422],
#        [-0.59366002],
#        [-0.60933077],
#        [-0.61926752],
#        [-0.63008392],
#        [-0.5338766 ],
#        [-0.37899356],
#        [-0.38257731],
#        [-0.4373109 ],
#        [ 0.13022433],
#        [ 0.70720763],
#        [ 0.27846115],
#        [ 0.06213313],
#        [ 0.48631848],
#        [ 0.51629164],
#        [ 0.37978345],
#        [ 0.06897483],
#        [-0.17146202],
#        [-0.25877514],
#        [-0.31937304],
#        [-0.37834197],
#        [-0.29656738],
#        [ 0.1123056 ],
#        [ 0.2344788 ],
#        [-0.10304503],
#        [-0.26626843],
#        [-0.33110167],
#        [-0.36433278],
#        [-0.07600403],
#        [-0.19100973]])

# %% [markdown]
# ## Evaluation metics

# %% [raw]
# !pip install hydroeval

# %%
###nse

import hydroeval as he
nse = he.evaluator(he.nse, Y_pred, y_test  )
print(nse)
# Out:
# [0.76241813]

# %%
##rmse
rmse = he.evaluator(he.rmse, Y_pred, y_test[:,-1:]  )
print(rmse)
# Out:
# [0.48697796]

# %%
###logrmse
from sklearn.metrics import mean_squared_error
#### log of predicted values
y_pred_lg = np.log1p(Y_pred)  ### log1p instead of log: to avoid taking the logarithm of zero or negative values

#### log of test values
y_test_lg = np.log1p(y_test)

# %%
y_pred_lg
# Out:
# array([[-0.5432653 ],
#        [-0.7043445 ],
#        [-0.60537827],
#        [-0.9618346 ],
#        [-0.9402586 ],
#        [-0.59196436],
#        [-0.4148375 ],
#        [-0.38481057],
#        [-0.2680351 ],
#        [-0.32605836],
#        [-0.40289026],
#        [-0.37534386],
#        [-0.32405427],
#        [-0.37736067],
#        [-0.5373618 ],
#        [-0.39715144],
#        [-0.6495022 ],
#        [-0.7161817 ],
#        [-0.6496537 ],
#        [-0.6284745 ],
#        [-0.77752954],
#        [-0.7637869 ],
#        [-0.6506575 ],
#        [-0.90900064],
#        [-0.6353878 ],
#        [-0.32005298],
#        [-0.3792214 ],
#        [-0.18622063],
#        [ 0.0387876 ],
#        [-0.06940977],
#        [-0.05592534],
#        [-0.08909339],
#        [-0.14961791],
#        [-0.45137632],
#        [-0.41949803],
#        [-0.42281792],
#        [-0.6192441 ],
#        [-0.6876574 ],
#        [-0.7397386 ],
#        [-0.82477075],
#        [-0.81635374],
#        [-0.8612611 ],
#        [-0.61534154],
#        [-0.08079924],
#        [ 0.37521133],
#        [ 0.624628  ],
#        [ 0.884387  ],
#        [ 0.8874809 ],
#        [ 0.7138327 ],
#        [ 0.6030614 ],
#        [ 0.3931656 ],
#        [ 0.16750048],
#        [-0.03156888],
#        [-0.10549162],
#        [-0.09146959],
#        [-0.20243344],
#        [-0.32699373],
#        [-0.53274876],
#        [-0.4913227 ],
#        [-0.5209424 ],
#        [-0.55620635],
#        [-0.5192765 ],
#        [-0.51233834],
#        [-0.9724224 ],
#        [-1.2338037 ],
#        [-0.60596484],
#        [ 0.5073193 ],
#        [ 0.19175825],
#        [-0.12913194],
#        [-0.12502337],
#        [-0.04638309],
#        [-0.08781021],
#        [-0.11788065],
#        [-0.10198058],
#        [-0.660289  ],
#        [-0.5102125 ],
#        [-0.49777564],
#        [-0.36430192],
#        [-0.5513559 ],
#        [-0.5642507 ],
#        [-0.55409855],
#        [-0.5528381 ],
#        [-0.51244664],
#        [-0.77939224],
#        [-0.72577906],
#        [-1.0036666 ],
#        [-0.8427315 ],
#        [-0.97522354],
#        [-0.97812164],
#        [-0.90823674],
#        [-0.82973516],
#        [-0.6853649 ],
#        [-0.4354081 ],
#        [-0.45182174],
#        [-0.28253388],
#        [ 0.50779074],
#        [ 0.5220794 ],
#        [ 0.36951405],
#        [ 0.09677568],
#        [ 0.01589952],
#        [ 0.09822759],
#        [ 0.35378438],
#        [ 0.28357905],
#        [ 0.17569157],
#        [ 0.06672951],
#        [ 0.7025235 ],
#        [ 1.620505  ],
#        [ 1.2965462 ],
#        [ 1.0201495 ],
#        [ 0.6698104 ],
#        [ 0.5931395 ],
#        [ 0.67616165],
#        [ 0.55551773],
#        [ 0.48209018],
#        [-0.03208118],
#        [ 0.09301517],
#        [ 0.20019501],
#        [ 0.39305264],
#        [ 0.68794143],
#        [ 0.42110938],
#        [ 0.3036781 ],
#        [ 0.26612476],
#        [ 0.09222066],
#        [ 0.14770076],
#        [ 0.21307766],
#        [ 0.08547005],
#        [-0.3663772 ],
#        [-0.4203539 ],
#        [-0.36658707],
#        [-0.6412398 ],
#        [-0.5603985 ],
#        [-0.45566937],
#        [-0.7073593 ],
#        [-0.7955681 ],
#        [-0.7966831 ],
#        [-0.69833475],
#        [-0.71074766],
#        [-0.70810664],
#        [-0.7699774 ],
#        [-0.5981957 ],
#        [-0.48310825],
#        [-0.55720377],
#        [-0.5730341 ],
#        [-0.46913427],
#        [-0.15739058],
#        [-0.16882436],
#        [ 0.08758634],
#        [ 0.17170766],
#        [ 0.0265061 ],
#        [-0.08226404],
#        [-0.08123216],
#        [ 0.17339899],
#        [ 0.18952274],
#        [ 0.69003934],
#        [ 1.025483  ],
#        [ 0.63459605],
#        [ 0.2685914 ],
#        [ 0.08300587],
#        [ 0.07249492],
#        [ 0.07374433],
#        [ 0.03004087],
#        [-0.10336254],
#        [-0.6142341 ],
#        [-0.7353486 ],
#        [-0.7597    ],
#        [-0.73419815],
#        [-0.89296234],
#        [-0.8624026 ],
#        [-1.2438273 ],
#        [-1.2446005 ],
#        [-1.2326467 ],
#        [-1.2038125 ],
#        [-1.2124466 ],
#        [-1.1701998 ],
#        [-1.1225417 ],
#        [-1.1414073 ],
#        [-1.1474283 ],
#        [-1.1343032 ],
#        [-1.1291686 ],
#        [-1.1683115 ],
#        [-1.1421818 ],
#        [-1.104531  ],
#        [-1.1292913 ],
#        [-1.1214321 ],
#        [-1.0048527 ],
#        [-0.96735644],
#        [-0.7754836 ],
#        [ 0.12714142],
#        [ 0.63986546],
#        [ 0.31423262],
#        [ 0.13396941],
#        [ 0.16895528],
#        [ 0.11086468],
#        [ 0.1396653 ],
#        [ 0.06019773],
#        [-0.11096454],
#        [-0.620677  ],
#        [-0.61645585],
#        [-0.5466953 ],
#        [-0.83076304],
#        [-0.9219576 ],
#        [-0.90135026],
#        [-0.53571934],
#        [-0.56585187],
#        [-0.41862965],
#        [-0.32660443],
#        [-0.37640005],
#        [-0.38350245],
#        [-0.31990212],
#        [-0.15478809],
#        [-0.47594446],
#        [-0.37459427],
#        [ 0.37380648],
#        [ 0.782808  ],
#        [ 0.7329565 ],
#        [ 0.7090439 ],
#        [ 0.6163579 ],
#        [ 0.5832475 ],
#        [ 0.7088228 ],
#        [ 0.9340967 ],
#        [ 0.8548794 ],
#        [ 0.3307419 ],
#        [ 0.20353971],
#        [ 0.06787272],
#        [ 0.32787484],
#        [ 1.1984719 ],
#        [ 1.7152698 ],
#        [ 1.6201082 ],
#        [ 1.417172  ],
#        [ 1.3669089 ],
#        [ 1.4378631 ],
#        [ 1.429132  ],
#        [ 1.5571588 ],
#        [ 1.4680688 ],
#        [ 1.6184677 ],
#        [ 1.3848077 ],
#        [ 1.2472725 ],
#        [ 1.2196316 ],
#        [ 0.9780915 ],
#        [ 1.1599683 ],
#        [ 1.2053843 ],
#        [ 1.0219312 ],
#        [ 0.55485463],
#        [ 0.41130644],
#        [ 0.71667826],
#        [ 0.7638369 ],
#        [ 0.6269027 ],
#        [ 0.90314037],
#        [ 1.1526266 ],
#        [ 1.2338254 ],
#        [ 1.1364096 ],
#        [ 0.9120652 ],
#        [ 0.59680307],
#        [ 0.24819826],
#        [ 0.14152612],
#        [ 0.00396609],
#        [-0.16973627],
#        [-0.39492244],
#        [-0.66548055],
#        [-0.77525216],
#        [-1.1454934 ],
#        [-1.0068349 ],
#        [-0.740659  ],
#        [-0.76936674],
#        [-0.75932676],
#        [-0.61208063],
#        [-0.41558087],
#        [-0.3319774 ],
#        [ 0.30376855],
#        [ 0.3624065 ],
#        [ 0.10722449],
#        [ 0.20349215],
#        [ 0.47119093],
#        [ 0.45051673],
#        [ 0.23742375],
#        [ 0.22044119],
#        [-0.01348266],
#        [-0.25151598],
#        [-0.16733947],
#        [-0.00514806],
#        [-0.36694252],
#        [-0.58954877],
#        [-0.5016514 ],
#        [-0.6297628 ],
#        [-0.76823217],
#        [-0.6854236 ],
#        [-0.5681362 ],
#        [-0.7076288 ],
#        [-0.0443535 ],
#        [ 0.6614719 ],
#        [ 0.38656005],
#        [ 0.12396907],
#        [-0.01463676],
#        [ 0.01816738],
#        [ 0.1738644 ],
#        [ 0.31814793],
#        [ 0.07014847],
#        [-0.4484645 ],
#        [-0.45016572],
#        [-0.49033794],
#        [-0.4417482 ],
#        [-0.34859207],
#        [-0.03063351],
#        [-0.4211925 ],
#        [-0.40640575],
#        [-0.32099047],
#        [-0.12517865],
#        [ 0.10926341],
#        [ 0.17622696],
#        [ 0.02156313],
#        [-0.32132193],
#        [-0.36857015],
#        [-0.3750485 ],
#        [-0.41583425],
#        [-0.5006273 ],
#        [-0.7340901 ],
#        [-1.0052125 ],
#        [-1.2005644 ],
#        [-1.1290275 ],
#        [-0.8487402 ],
#        [-0.75189286],
#        [-0.79383266],
#        [-0.7547736 ],
#        [-0.6861052 ],
#        [-0.6061313 ],
#        [-0.49529672],
#        [-0.48382527],
#        [-0.5535166 ],
#        [-0.54914063],
#        [-0.5812151 ],
#        [-0.58527917],
#        [-0.49641147],
#        [-0.44999775],
#        [-0.654871  ],
#        [-0.689955  ],
#        [-0.62236637],
#        [-0.7883162 ],
#        [-0.84826523],
#        [-0.8276259 ],
#        [-0.9396852 ],
#        [-1.1912851 ],
#        [-1.2363263 ],
#        [-1.2340027 ],
#        [-1.2080171 ],
#        [-1.1260163 ],
#        [-1.1479583 ],
#        [-1.1729119 ],
#        [-1.1495962 ],
#        [-1.1244097 ],
#        [-1.0673379 ],
#        [-0.98547137],
#        [-0.5443978 ],
#        [-0.04452772],
#        [-0.28878263],
#        [-0.33159232],
#        [-0.0682511 ],
#        [ 0.09662706],
#        [ 0.42022192],
#        [ 0.73716193],
#        [ 0.4341481 ],
#        [ 0.05836717],
#        [ 0.3019806 ],
#        [ 0.8943539 ],
#        [ 1.1728039 ],
#        [ 1.0170113 ],
#        [ 0.89127624],
#        [ 0.48742697],
#        [ 0.286334  ],
#        [ 0.21169974],
#        [ 0.22271778],
#        [ 0.15199625],
#        [-0.22924   ],
#        [-0.36315942],
#        [-0.4623255 ],
#        [-0.66588926],
#        [-0.7538299 ],
#        [-0.78659093],
#        [-0.6756319 ],
#        [-1.2510881 ],
#        [-1.2510881 ],
#        [-1.2510881 ],
#        [-1.2510881 ],
#        [-1.2510881 ],
#        [-1.2510881 ],
#        [-1.2510881 ],
#        [-1.2510881 ],
#        [-1.2510881 ],
#        [-1.1565589 ],
#        [-0.9539565 ],
#        [-0.97713727],
#        [-1.0237601 ],
#        [-0.9710205 ],
#        [-0.83395165],
#        [-0.56610864],
#        [-0.40229967],
#        [-0.28970143],
#        [-0.43957698],
#        [-0.462177  ],
#        [-0.41191685],
#        [-0.37205103],
#        [-0.34610382],
#        [-0.44056174],
#        [-0.52878577],
#        [-0.8575859 ],
#        [-0.83550304],
#        [-0.78269696],
#        [-0.6771818 ],
#        [-0.6420671 ],
#        [-0.66883224],
#        [-0.6586488 ],
#        [-0.6743971 ],
#        [-0.65312976],
#        [-0.6298485 ],
#        [-0.6725663 ],
#        [-0.66360885],
#        [-0.8463729 ],
#        [-0.9469481 ],
#        [-1.1316457 ],
#        [-1.1346211 ],
#        [-1.0952942 ],
#        [-1.1954997 ],
#        [-0.98058385],
#        [-0.70827353],
#        [-0.6797874 ],
#        [-0.61681306],
#        [-0.3638882 ],
#        [-0.42895216],
#        [-0.48520684],
#        [-0.42006016],
#        [-0.41908333],
#        [-0.5820519 ],
#        [-0.5812391 ],
#        [-0.11231638],
#        [-0.26085177],
#        [-0.17278071],
#        [-0.33198637],
#        [-0.3497683 ],
#        [-0.32777384],
#        [-0.29781437],
#        [-0.25201508],
#        [-0.4462728 ],
#        [-0.57013416],
#        [-1.0364841 ],
#        [-1.0572412 ],
#        [-1.0443614 ],
#        [-0.9724224 ],
#        [-1.2510881 ],
#        [-1.2510881 ],
#        [-1.2510881 ],
#        [-1.2510881 ],
#        [-1.2510881 ],
#        [-1.2510881 ],
#        [-1.0884873 ],
#        [-0.80539024],
#        [-0.9024209 ],
#        [-0.59348243],
#        [ 0.25078523],
#        [-0.10728078],
#        [-0.2849447 ],
#        [-0.17430353],
#        [-0.16778615],
#        [-0.2863252 ],
#        [-0.14314604],
#        [-0.1142754 ],
#        [-0.6456965 ],
#        [-0.46649778],
#        [-0.5136133 ],
#        [-0.5183964 ],
#        [ 0.13593416],
#        [ 0.7286962 ],
#        [ 0.7475948 ],
#        [ 0.5959977 ],
#        [ 0.42495427],
#        [ 0.42686194],
#        [ 1.3147889 ],
#        [ 1.816733  ],
#        [ 1.5662643 ],
#        [ 1.0062699 ],
#        [ 0.4447988 ],
#        [ 0.2842911 ],
#        [ 0.2937774 ],
#        [ 0.1811151 ],
#        [-0.02461825],
#        [-0.4246384 ],
#        [-0.68823373],
#        [-0.6420955 ],
#        [-0.6422963 ],
#        [-0.6539514 ],
#        [-0.7567269 ],
#        [-0.624848  ],
#        [-0.6569858 ],
#        [-0.6223162 ],
#        [-0.480188  ],
#        [-0.6615471 ],
#        [-0.7411569 ],
#        [-0.6696886 ],
#        [-0.6554939 ],
#        [-0.8445485 ],
#        [-0.761402  ],
#        [-0.6909785 ],
#        [-0.88391393],
#        [-0.8631272 ],
#        [-0.7037152 ],
#        [-0.7415537 ],
#        [-0.5066872 ],
#        [ 0.30817917],
#        [ 0.31859925],
#        [ 0.33042032],
#        [ 0.14775911],
#        [ 0.01933181],
#        [ 0.08787052],
#        [ 0.22363324],
#        [ 0.08471442],
#        [-0.35153776],
#        [-0.3148301 ],
#        [-0.50890064],
#        [-0.6344026 ],
#        [-0.6599838 ],
#        [-0.55043924],
#        [-1.148341  ],
#        [-1.1412295 ],
#        [-1.0414314 ],
#        [-0.7275691 ],
#        [-0.1080614 ],
#        [-0.08947643],
#        [ 0.00939136],
#        [ 0.47248554],
#        [ 0.70639175],
#        [ 0.4953499 ],
#        [ 0.44216666],
#        [ 0.5767474 ],
#        [ 0.3281877 ],
#        [ 0.21708533],
#        [ 0.07404514],
#        [-0.06583165],
#        [-0.43211448],
#        [-0.4376742 ],
#        [-0.4031183 ],
#        [-0.4818043 ],
#        [-0.12596504],
#        [-0.10091781],
#        [-0.38296667],
#        [-0.364432  ],
#        [-0.3491911 ],
#        [-0.31021157],
#        [ 0.07196473],
#        [ 0.22119899]], dtype=float32)

# %%
##calculate mse
mse = mean_squared_error(y_pred_lg, y_test_lg)
rmse_lg = np.sqrt(mse)   
print(rmse_lg)
# Out:
# 0.42502613568111186

# %% [markdown]
# ## g. plot

# %%
import matplotlib.pyplot as plt
# plt.plot(Q_pred)
# plt.plot(y_test)

plt.figure(figsize = (16, 12))

plt.subplot(2, 1, 1)

plt.plot(Y_pred[:,-1],'b', label = "Predicted")

plt.plot(y_test[:,-1], 'm',  label = "Observed")  

plt.legend()
plt.grid()

plt.subplot(2,1,2)

plt.plot(Y_pred[:,-1] - y_test[:,-1],'r', label = "Error")

plt.legend()

plt.grid()

# %% [markdown]
# ##  save_model

# %% [raw]
# save_model(Y_pred,'MLP_hT_1.h5')  #### recommended to save as .h5 file

# %% [markdown]
# ## h. Denormalize the data

# %%
#### Original data
df_train_norm

# df_val_f

# df_test_f
# Out:
#                   Rt     R_t_1     R_t_2     R_t_3     R_t_4     R_t_5  \
# Date
# 09/10/2000  1.774218  1.181452 -0.366196 -0.184231 -0.442218  0.558794
# 10/10/2000  2.639196  1.773159  1.181413 -0.366309 -0.184270 -0.442644
# 11/10/2000  0.954766  2.637962  1.773146  1.181349 -0.366351 -0.184698
# 12/10/2000  2.715071  0.953872  2.637986  1.773101  1.181334 -0.366777
# 13/10/2000 -0.198537  2.713822  0.953823  2.637969  1.773096  1.180899
# ...              ...       ...       ...       ...       ...       ...
# 28/09/2007 -0.532388 -0.608843 -0.502750  0.528905  0.240584  3.350681
# 29/09/2007 -0.532388 -0.532983 -0.608958 -0.502867  0.528879  0.240155
# 30/09/2007 -0.441338 -0.532983 -0.533095 -0.609079 -0.502911  0.528447
# 01/10/2007 -0.593088 -0.441951 -0.533095 -0.533213 -0.609125 -0.503337
# 02/10/2007 -0.608263 -0.593671 -0.442059 -0.533213 -0.533258 -0.609550
#
#                R_t_6     R_t_7     R_t_8        Qt
# Date
# 09/10/2000  0.558342 -0.170123  1.346565  1.134868
# 10/10/2000  0.558342  0.558236 -0.170393  1.226337
# 11/10/2000 -0.443107  0.558236  0.557747  1.872033
# 12/10/2000 -0.185158 -0.443258  0.557747  2.910104
# 13/10/2000 -0.367240 -0.185297 -0.443445  2.542519
# ...              ...       ...       ...       ...
# 28/09/2007 -0.245852  0.300276  0.132999 -0.435775
# 29/09/2007  3.350262 -0.245994  0.299864 -0.514136
# 30/09/2007  0.239699  3.350279 -0.246241 -0.564572
# 01/10/2007  0.527995  0.239579  3.348949 -0.596031
# 02/10/2007 -0.503801  0.527888  0.239186 -0.617687
#
# [2550 rows x 10 columns]

# %%
### normalized data after model training
Y_pred    #### model out put
# y_obser = y_test[:,-1:]      ## observed discharge
# Out:
# array([[-4.19151485e-01],
#        [-5.05567431e-01],
#        [-4.54132110e-01],
#        [-6.17808938e-01],
#        [-6.09473169e-01],
#        [-4.46760535e-01],
#        [-3.39552402e-01],
#        [-3.19420457e-01],
#        [-2.35119075e-01],
#        [-2.78236926e-01],
#        [-3.31614554e-01],
#        [-3.12947005e-01],
#        [-2.76789010e-01],
#        [-3.14331263e-01],
#        [-4.15712327e-01],
#        [-3.27767789e-01],
#        [-4.77694303e-01],
#        [-5.11385620e-01],
#        [-4.77773398e-01],
#        [-4.66595083e-01],
#        [-5.40460110e-01],
#        [-5.34101248e-01],
#        [-4.78297353e-01],
#        [-5.97073317e-01],
#        [-4.70269978e-01],
#        [-2.73889452e-01],
#        [-3.15605938e-01],
#        [-1.69909567e-01],
#        [ 3.95496562e-02],
#        [-6.70556873e-02],
#        [-5.43902665e-02],
#        [-8.52398574e-02],
#        [-1.38963088e-01],
#        [-3.63248825e-01],
#        [-3.42623264e-01],
#        [-3.44802082e-01],
#        [-4.61648792e-01],
#        [-4.97247577e-01],
#        [-5.22761345e-01],
#        [-5.61664522e-01],
#        [-5.57959497e-01],
#        [-5.77371240e-01],
#        [-4.73811358e-01],
#        [-4.73917007e-01],
#        [-4.80012983e-01],
#        [-5.30800343e-01],
#        [-4.64657217e-01],
#        [-4.81588423e-01],
#        [-4.63300109e-01],
#        [-3.81332934e-01],
#        [-4.83947694e-01],
#        [-5.23437738e-01],
#        [-4.88132030e-01],
#        [-4.80814427e-01],
#        [-5.70248663e-01],
#        [-5.32988787e-01],
#        [-4.98914510e-01],
#        [-5.86837351e-01],
#        [-5.78159153e-01],
#        [-5.05256176e-01],
#        [-5.23626804e-01],
#        [-3.97511810e-01],
#        [ 3.60944808e-01],
#        [ 3.75200123e-01],
#        [ 3.91552866e-01],
#        [ 1.59233630e-01],
#        [ 1.95198730e-02],
#        [ 9.18467417e-02],
#        [ 2.50612259e-01],
#        [ 8.84061977e-02],
#        [-2.96394736e-01],
#        [-2.70087123e-01],
#        [-3.98843884e-01],
#        [-4.69747812e-01],
#        [-4.83140290e-01],
#        [-4.23303545e-01],
#        [-6.82837486e-01],
#        [-6.80573940e-01],
#        [-6.47050917e-01],
#        [-5.16918123e-01],
#        [-1.02427512e-01],
#        [-8.55901837e-02],
#        [ 9.43559408e-03],
#        [ 6.03976011e-01],
#        [ 1.02666533e+00],
#        [ 6.41072392e-01],
#        [ 5.56075037e-01],
#        [ 7.80238628e-01],
#        [ 3.88449550e-01],
#        [ 2.42450118e-01],
#        [ 7.68554136e-02],
#        [-6.37115240e-02],
#        [-3.50864947e-01],
#        [-3.54463935e-01],
#        [-3.31766963e-01],
#        [-3.82332087e-01],
#        [-1.18354335e-01],
#        [-9.59926695e-02],
#        [-3.18164378e-01],
#        [-3.05408925e-01],
#        [-2.94741660e-01],
#        [-2.66708195e-01],
#        [ 7.46174529e-02],
#        [ 2.47571677e-01]], dtype=float32)

# %%
def denormalize(data, original_data, type='min_max'):   ### default is min-max in this case(there is no reason behind this)

    if type == 'min_max':
        min = np.min(original_data)
        max = np.max(original_data)
        data = data * (max - min) + min
    elif type == 'z_score':
        mean = np.mean(original_data)
        std = np.std(original_data)
        data = data * std + mean
    elif type == 'max':                
        max = np.max(original_data)
        data = data * max
    else:
        raise ValueError("Invalid normalization type. Choose either 'max', 'min_max', or 'z_score'.")
    return data

# %%
Y_observ_unnorm = df_test['Qt']

# %%
Y_observ_unnorm = Y_observ_unnorm.to_numpy()

# %% [markdown]
# ###  denormalized predicted discharge

# %%
### Standard denormalization (becasue we used standard(z-score) in this experiment)

Y_pred_denorm = denormalize(Y_pred, Y_observ_unnorm, type='z_score')

# %%
print(Y_pred_denorm)
print(Y_pred_denorm.shape)
# Out:
# [[ 12.609153 ]
#  [  9.959116 ]
#  [ 11.536435 ]
#  [  6.517111 ]
#  [  6.7727375]
#  [ 11.762492 ]
#  [ 15.050143 ]
#  [ 15.667511 ]
#  [ 18.2527   ]
#  [ 16.930447 ]
#  [ 15.293566 ]
#  [ 15.866026 ]
#  [ 16.97485  ]
#  [ 15.823576 ]
#  [ 12.714619 ]
#  [ 15.4115305]
#  [ 10.813875 ]
#  [  9.780695 ]
#  [ 10.81145  ]
#  [ 11.154244 ]
#  [  8.889095 ]
#  [  9.084097 ]
#  [ 10.7953825]
#  [  7.1529922]
#  [ 11.04155  ]
#  [ 17.063766 ]
#  [ 15.784487 ]
#  [ 20.25242  ]
#  [ 26.675709 ]
#  [ 23.406544 ]
#  [ 23.794943 ]
#  [ 22.848907 ]
#  [ 21.201427 ]
#  [ 14.323467 ]
#  [ 14.955972 ]
#  [ 14.889156 ]
#  [ 11.305928 ]
#  [ 10.214253 ]
#  [  9.431847 ]
#  [  8.23884  ]
#  [  8.352459 ]
#  [  7.7571774]
#  [ 11.3704815]
#  [ 23.082542 ]
#  [ 39.425102 ]
#  [ 52.067253 ]
#  [ 69.05467  ]
#  [ 69.284775 ]
#  [ 57.410835 ]
#  [ 50.845345 ]
#  [ 40.233604 ]
#  [ 31.054707 ]
#  [ 24.509905 ]
#  [ 22.392653 ]
#  [ 22.78233  ]
#  [ 19.84304  ]
#  [ 16.909752 ]
#  [ 12.797465 ]
#  [ 13.558823 ]
#  [ 13.011248 ]
#  [ 12.380127 ]
#  [ 13.041616 ]
#  [ 13.168641 ]
#  [  6.393675 ]
#  [  3.7262497]
#  [ 11.52662  ]
#  [ 45.72802  ]
#  [ 31.944996 ]
#  [ 21.747929 ]
#  [ 21.858889 ]
#  [ 24.072973 ]
#  [ 22.884926 ]
#  [ 22.052877 ]
#  [ 22.489714 ]
#  [ 10.642032 ]
#  [ 13.207738 ]
#  [ 13.438142 ]
#  [ 16.09996  ]
#  [ 12.465622 ]
#  [ 12.239248 ]
#  [ 12.417229 ]
#  [ 12.439452 ]
#  [ 13.166652 ]
#  [  8.862869 ]
#  [  9.637577 ]
#  [  6.0369415]
#  [  7.999567 ]
#  [  6.3612347]
#  [  6.32777  ]
#  [  7.1624336]
#  [  8.172274 ]
#  [ 10.249639 ]
#  [ 14.637776 ]
#  [ 14.314772 ]
#  [ 17.915073 ]
#  [ 45.75204  ]
#  [ 46.485344 ]
#  [ 39.171562 ]
#  [ 28.578955 ]
#  [ 25.95435  ]
#  [ 28.628038 ]
#  [ 38.479027 ]
#  [ 35.51748  ]
#  [ 31.352917 ]
#  [ 27.57903  ]
#  [ 56.70671  ]
#  [149.83345  ]
#  [106.93173  ]
#  [ 79.852486 ]
#  [ 54.714214 ]
#  [ 50.291992 ]
#  [ 55.095978 ]
#  [ 48.242947 ]
#  [ 44.459145 ]
#  [ 24.494688 ]
#  [ 28.452156 ]
#  [ 32.25973  ]
#  [ 40.228474 ]
#  [ 55.810486 ]
#  [ 41.521187 ]
#  [ 36.3442   ]
#  [ 34.812893 ]
#  [ 28.425426 ]
#  [ 30.34387  ]
#  [ 32.745476 ]
#  [ 28.199177 ]
#  [ 16.055796 ]
#  [ 14.938725 ]
#  [ 16.051334 ]
#  [ 10.946763 ]
#  [ 12.30657  ]
#  [ 14.239818 ]
#  [  9.913473 ]
#  [  8.637169 ]
#  [  8.621746 ]
#  [ 10.050512 ]
#  [  9.86234  ]
#  [  9.902181 ]
#  [  8.995926 ]
#  [ 11.657103 ]
#  [ 13.713576 ]
#  [ 12.362598 ]
#  [ 12.086715 ]
#  [ 13.979774 ]
#  [ 20.996988 ]
#  [ 20.699127 ]
#  [ 28.269941 ]
#  [ 31.207571 ]
#  [ 26.286583 ]
#  [ 23.04114  ]
#  [ 23.0703   ]
#  [ 31.269205 ]
#  [ 31.862043 ]
#  [ 55.93862  ]
#  [ 80.30735  ]
#  [ 52.64098  ]
#  [ 34.91172  ]
#  [ 28.11697  ]
#  [ 27.768578 ]
#  [ 27.809797 ]
#  [ 26.398088 ]
#  [ 22.45147  ]
#  [ 11.388847 ]
#  [  9.496236 ]
#  [  9.142607 ]
#  [  9.513156 ]
#  [  7.352762 ]
#  [  7.7423916]
#  [  3.6371918]
#  [  3.6303596]
#  [  3.7365875]
#  [  3.9981117]
#  [  3.9190083]
#  [  4.312647 ]
#  [  4.777134 ]
#  [  4.5906143]
#  [  4.531824 ]
#  [  4.6604385]
#  [  4.711214 ]
#  [  4.330633 ]
#  [  4.5830326]
#  [  4.958515 ]
#  [  4.709997 ]
#  [  4.7882156]
#  [  6.0236187]
#  [  6.452572 ]
#  [  8.917957 ]
#  [ 29.620508 ]
#  [ 52.946587 ]
#  [ 36.785038 ]
#  [ 29.859097 ]
#  [ 31.107492 ]
#  [ 29.05828  ]
#  [ 30.059378 ]
#  [ 27.365599 ]
#  [ 22.242037 ]
#  [ 11.2822895]
#  [ 11.352024 ]
#  [ 12.5481615]
#  [  8.158531 ]
#  [  6.993925 ]
#  [  7.247883 ]
#  [ 12.744072 ]
#  [ 12.211343 ]
#  [ 14.973484 ]
#  [ 16.918365 ]
#  [ 15.843784 ]
#  [ 15.69483  ]
#  [ 17.067127 ]
#  [ 21.065262 ]
#  [ 13.849579 ]
#  [ 15.8818245]
#  [ 39.36245  ]
#  [ 61.882088 ]
#  [ 58.619774 ]
#  [ 57.11171  ]
#  [ 51.595573 ]
#  [ 49.745735 ]
#  [ 57.09793  ]
#  [ 72.839294 ]
#  [ 66.89551  ]
#  [ 37.483986 ]
#  [ 32.385246 ]
#  [ 27.616526 ]
#  [ 37.361774 ]
#  [ 96.45625  ]
#  [165.24414  ]
#  [149.77197  ]
#  [121.30771  ]
#  [115.10605  ]
#  [123.95264  ]
#  [122.82987  ]
#  [140.31708  ]
#  [127.9134   ]
#  [149.51793  ]
#  [117.278824 ]
#  [101.54034  ]
#  [ 98.63026  ]
#  [ 76.3494   ]
#  [ 92.616394 ]
#  [ 97.1614   ]
#  [ 80.004166 ]
#  [ 48.20752  ]
#  [ 41.065388 ]
#  [ 57.589264 ]
#  [ 60.621407 ]
#  [ 52.19767  ]
#  [ 70.460396 ]
#  [ 91.90087  ]
#  [100.114555 ]
#  [ 90.33884  ]
#  [ 71.138695 ]
#  [ 50.49567  ]
#  [ 34.101936 ]
#  [ 30.125057 ]
#  [ 25.584743 ]
#  [ 20.675518 ]
#  [ 15.457533 ]
#  [ 10.559984 ]
#  [  8.921225 ]
#  [  4.5506783]
#  [  6.0013866]
#  [  9.418383 ]
#  [  9.004599 ]
#  [  9.147963 ]
#  [ 11.424616 ]
#  [ 15.035092 ]
#  [ 16.799824 ]
#  [ 36.34796  ]
#  [ 38.85729  ]
#  [ 28.933788 ]
#  [ 32.383457 ]
#  [ 43.920803 ]
#  [ 42.91563  ]
#  [ 33.680717 ]
#  [ 33.025944 ]
#  [ 25.052193 ]
#  [ 18.64339  ]
#  [ 20.737617 ]
#  [ 25.305412 ]
#  [ 16.043781 ]
#  [ 11.803523 ]
#  [ 13.366033 ]
#  [ 11.1331835]
#  [  9.020727 ]
#  [ 10.248732 ]
#  [ 12.171607 ]
#  [  9.909401 ]
#  [ 24.132452 ]
#  [ 54.216667 ]
#  [ 39.93446  ]
#  [ 29.51021  ]
#  [ 25.017294 ]
#  [ 26.025091 ]
#  [ 31.286184 ]
#  [ 36.949757 ]
#  [ 27.691301 ]
#  [ 14.380408 ]
#  [ 14.34712  ]
#  [ 13.577308 ]
#  [ 14.51238  ]
#  [ 16.437271 ]
#  [ 24.537712 ]
#  [ 14.921842 ]
#  [ 15.221636 ]
#  [ 17.042902 ]
#  [ 21.854687 ]
#  [ 29.003462 ]
#  [ 31.372494 ]
#  [ 26.131315 ]
#  [ 17.03553  ]
#  [ 16.009228 ]
#  [ 15.87225  ]
#  [ 15.029965 ]
#  [ 13.38506  ]
#  [  9.514747 ]
#  [  6.019579 ]
#  [  4.0280457]
#  [  4.712614 ]
#  [  7.920471 ]
#  [  9.255045 ]
#  [  8.661209 ]
#  [  9.213455 ]
#  [ 10.238204 ]
#  [ 11.523835 ]
#  [ 13.484409 ]
#  [ 13.700018 ]
#  [ 12.427485 ]
#  [ 12.5048065]
#  [ 11.945844 ]
#  [ 11.87629  ]
#  [ 13.46359  ]
#  [ 14.350405 ]
#  [ 10.728114 ]
#  [ 10.178872 ]
#  [ 11.254463 ]
#  [  8.737904 ]
#  [  7.9267063]
#  [  8.200516 ]
#  [  6.779606 ]
#  [  4.1141033]
#  [  3.7037525]
#  [  3.724472 ]
#  [  3.9595032]
#  [  4.7425175]
#  [  4.5266647]
#  [  4.286875 ]
#  [  4.510742 ]
#  [  4.7585087]
#  [  5.3435764]
#  [  6.24333  ]
#  [ 12.588993 ]
#  [ 24.127342 ]
#  [ 17.771065 ]
#  [ 16.8083   ]
#  [ 23.439713 ]
#  [ 28.573935 ]
#  [ 41.47974  ]
#  [ 58.88874  ]
#  [ 42.134403 ]
#  [ 27.306036 ]
#  [ 36.273735 ]
#  [ 69.79849  ]
#  [ 93.880066 ]
#  [ 79.585976 ]
#  [ 69.568016 ]
#  [ 44.72489  ]
#  [ 35.629814 ]
#  [ 32.693222 ]
#  [ 33.113075 ]
#  [ 30.496891 ]
#  [ 19.180557 ]
#  [ 16.124313 ]
#  [ 14.110832 ]
#  [ 10.553542 ]
#  [  9.227066 ]
#  [  8.761976 ]
#  [ 10.400776 ]
#  [  3.5732346]
#  [  3.5732346]
#  [  3.5732346]
#  [  3.5732346]
#  [  3.5732346]
#  [  3.5732346]
#  [  3.5732346]
#  [  3.5732346]
#  [  3.5732346]
#  [  4.443342 ]
#  [  6.60981  ]
#  [  6.3391266]
#  [  5.813343 ]
#  [  6.4099426]
#  [  8.1159935]
#  [ 12.206872 ]
#  [ 15.305675 ]
#  [ 17.749966 ]
#  [ 14.555234 ]
#  [ 14.113701 ]
#  [ 15.109383 ]
#  [ 15.935517 ]
#  [ 16.491184 ]
#  [ 14.535786 ]
#  [ 12.868944 ]
#  [  7.8048954]
#  [  8.095346 ]
#  [  8.816463 ]
#  [ 10.376611 ]
#  [ 10.933409 ]
#  [ 10.507238 ]
#  [ 10.668042 ]
#  [ 10.420055 ]
#  [ 10.755878 ]
#  [ 11.131784 ]
#  [ 10.448685 ]
#  [ 10.589516 ]
#  [  7.951576 ]
#  [  6.692892 ]
#  [  4.6866856]
#  [  4.657303 ]
#  [  5.0528107]
#  [  4.0749187]
#  [  6.299412 ]
#  [  9.89966  ]
#  [ 10.336068 ]
#  [ 11.346111 ]
#  [ 16.108776 ]
#  [ 14.766282 ]
#  [ 13.67392  ]
#  [ 14.944643 ]
#  [ 14.964334 ]
#  [ 11.9315   ]
#  [ 11.945433 ]
#  [ 22.20496  ]
#  [ 18.421799 ]
#  [ 20.596851 ]
#  [ 16.799627 ]
#  [ 16.41183  ]
#  [ 16.89251  ]
#  [ 17.5645   ]
#  [ 18.63149  ]
#  [ 14.423377 ]
#  [ 12.136928 ]
#  [  5.674055 ]
#  [  5.4506035]
#  [  5.588711 ]
#  [  6.393675 ]
#  [  3.5732346]
#  [  3.5732346]
#  [  3.5732346]
#  [  3.5732346]
#  [  3.5732346]
#  [  3.5732346]
#  [  5.122862 ]
#  [  8.501894 ]
#  [  7.23456  ]
#  [ 11.736756 ]
#  [ 34.20375  ]
#  [ 22.343325 ]
#  [ 17.859406 ]
#  [ 20.557592 ]
#  [ 20.726032 ]
#  [ 17.82759  ]
#  [ 21.372868 ]
#  [ 22.15132  ]
#  [ 10.8749485]
#  [ 14.030417 ]
#  [ 13.145233 ]
#  [ 13.05768  ]
#  [ 29.928053 ]
#  [ 58.34845  ]
#  [ 59.560905 ]
#  [ 50.45083  ]
#  [ 41.701183 ]
#  [ 41.79075  ]
#  [108.99615  ]
#  [183.44606  ]
#  [141.64816  ]
#  [ 78.6801   ]
#  [ 42.641273 ]
#  [ 35.546482 ]
#  [ 35.934883 ]
#  [ 31.55172  ]
#  [ 24.71715  ]
#  [ 14.8526125]
#  [ 10.205371 ]
#  [ 10.93295  ]
#  [ 10.92971  ]
#  [ 10.74277  ]
#  [  9.185322 ]
#  [ 11.213672 ]
#  [ 10.694458 ]
#  [ 11.255288 ]
#  [ 13.768899 ]
#  [ 10.622108 ]
#  [  9.411104 ]
#  [ 10.493792 ]
#  [ 10.718193 ]
#  [  7.9755974]
#  [  9.118212 ]
#  [ 10.163136 ]
#  [  7.4668884]
#  [  7.733015 ]
#  [  9.968661 ]
#  [  9.405306 ]
#  [ 13.272757 ]
#  [ 36.53163  ]
#  [ 36.96879  ]
#  [ 37.47026  ]
#  [ 30.345945 ]
#  [ 26.061476 ]
#  [ 28.279455 ]
#  [ 33.148167 ]
#  [ 28.173946 ]
#  [ 16.37362  ]
#  [ 17.18037  ]
#  [ 13.231907 ]
#  [ 11.057563 ]
#  [ 10.646869 ]
#  [ 12.481826 ]
#  [  4.5229416]
#  [  4.5923557]
#  [  5.6203747]
#  [  9.611035 ]
#  [ 22.321829 ]
#  [ 22.838163 ]
#  [ 25.75223  ]
#  [ 43.984444 ]
#  [ 56.946655 ]
#  [ 45.12204  ]
#  [ 42.515507 ]
#  [ 49.38972  ]
#  [ 37.375095 ]
#  [ 32.897865 ]
#  [ 27.81973  ]
#  [ 23.509096 ]
#  [ 14.703232 ]
#  [ 14.592865 ]
#  [ 15.288892 ]
#  [ 13.738258 ]
#  [ 21.833416 ]
#  [ 22.519161 ]
#  [ 15.70603  ]
#  [ 16.097189 ]
#  [ 16.424313 ]
#  [ 17.283989 ]
#  [ 27.7511   ]
#  [ 33.054924 ]]
# (547, 1)

# %% [markdown]
# ### denormalized Observed discharge

# %%
len(y_test)
# Out:
# 547

# %%
Y_obser_denorm = denormalize(y_test, Y_observ_unnorm, type='z_score')

# %%
Y_obser_denorm
# Out:
# array([[  8.22477858],
#        [  7.89408128],
#        [  7.73222943],
#        [  7.42251292],
#        [  7.56338398],
#        [  9.7194105 ],
#        [ 12.42193679],
#        [ 11.41286043],
#        [ 11.79251292],
#        [ 11.19306162],
#        [  9.60651384],
#        [  8.98608174],
#        [  8.7822683 ],
#        [  8.49153441],
#        [  9.11496377],
#        [ 10.13403098],
#        [ 10.24393039],
#        [  8.75729116],
#        [  8.01796788],
#        [  7.61433734],
#        [  7.40652755],
#        [  7.19572051],
#        [  6.97192536],
#        [  7.10580282],
#        [  7.85911329],
#        [ 14.91965055],
#        [ 13.16126006],
#        [ 11.97234831],
#        [ 17.44733688],
#        [ 15.16942193],
#        [ 12.78160757],
#        [ 11.78252207],
#        [ 11.34292444],
#        [ 10.85337255],
#        [ 10.47372006],
#        [ 10.16400355],
#        [ 10.14402184],
#        [  9.39270954],
#        [  8.78626464],
#        [  8.13785814],
#        [  7.53940593],
#        [  7.35257694],
#        [  8.2787292 ],
#        [ 27.8677987 ],
#        [ 29.07669216],
#        [ 33.39274154],
#        [ 53.15465283],
#        [ 68.99015809],
#        [ 54.03384808],
#        [ 46.95033185],
#        [ 38.63794044],
#        [ 34.24196422],
#        [ 27.96770725],
#        [ 23.95138352],
#        [ 21.63350515],
#        [ 31.21473514],
#        [ 31.48448823],
#        [ 21.35376121],
#        [ 17.45732774],
#        [ 15.27932133],
#        [ 13.71075709],
#        [ 12.40195508],
#        [ 11.53275069],
#        [ 10.38380236],
#        [ 10.00315078],
#        [ 21.00408128],
#        [ 37.41905613],
#        [ 21.71343199],
#        [ 16.06859888],
#        [ 15.95869948],
#        [ 16.09857145],
#        [ 13.8206565 ],
#        [ 12.28206482],
#        [ 11.2629976 ],
#        [ 11.71258608],
#        [ 10.60360117],
#        [ 11.46281471],
#        [ 10.14402184],
#        [  9.28780556],
#        [  8.65138809],
#        [  8.28072737],
#        [  7.90507122],
#        [  7.42351201],
#        [  6.9279656 ],
#        [  6.4933634 ],
#        [  6.40644296],
#        [  6.23659843],
#        [  5.88492033],
#        [  5.50726601],
#        [  5.20254493],
#        [  5.17656871],
#        [  5.55821937],
#        [  6.46838627],
#        [ 13.14127835],
#        [ 11.07317136],
#        [  9.69043702],
#        [  9.33875892],
#        [  9.75138124],
#        [  8.65638352],
#        [  8.30770268],
#        [  8.28472371],
#        [  7.55738947],
#        [  6.98890981],
#        [  6.38845943],
#        [  5.98083254],
#        [  5.76103373],
#        [  5.85494777],
#        [  5.64613889],
#        [  5.2325175 ],
#        [  5.21753121],
#        [  5.26848457],
#        [  6.48037529],
#        [ 18.50636752],
#        [ 21.06402641],
#        [ 19.12580053],
#        [ 14.2202907 ],
#        [ 11.74255865],
#        [ 12.38197337],
#        [ 16.04861717],
#        [ 13.03137895],
#        [ 10.80341827],
#        [ 10.03412243],
#        [  9.27881379],
#        [  8.46655728],
#        [  7.83313707],
#        [  7.25766381],
#        [  6.77710369],
#        [  6.47238261],
#        [  6.14068622],
#        [  9.09098572],
#        [ 13.84063821],
#        [ 13.7307388 ],
#        [ 12.05227515],
#        [ 29.45634465],
#        [ 47.15014895],
#        [ 34.0021837 ],
#        [ 27.36825595],
#        [ 40.37634922],
#        [ 41.29550789],
#        [ 37.10933962],
#        [ 27.5780639 ],
#        [ 20.20481287],
#        [ 17.52726372],
#        [ 15.66896468],
#        [ 13.86061992],
#        [ 16.36832454],
#        [ 28.90684762],
#        [ 32.65341827],
#        [ 22.30289244],
#        [ 17.29747406],
#        [ 15.3092939 ],
#        [ 14.29022668],
#        [ 23.1321334 ],
#        [ 19.60536157]])

# %% [markdown]
# # Plot the denomalized data

# %%
plt.figure(figsize = (16, 12))

plt.subplot(2, 1, 1)

plt.plot(Y_pred_denorm,'b', label = "Predicted")

plt.plot(Y_obser_denorm , 'm',  label = "Observed")  

plt.legend()
plt.grid()

plt.subplot(2,1,2)

plt.plot(Y_pred_denorm - Y_obser_denorm ,'r', label = "Error")

plt.legend()

plt.grid()

# %% [markdown]
# ### NSE after denormalization

# %%
nse_d = he.evaluator(he.nse, Y_pred_denorm , Y_obser_denorm  )
print(nse_d)
# Out:
# [0.76241812]

# %% [markdown]
# ### RMSE after denormalization (in m3/sec)

# %%
#### rmse in m3/sec
rmse_d = he.evaluator(he.rmse, Y_pred_denorm, Y_obser_denorm)
print(rmse_d)    ###
# Out:
# [14.93369542]

# %% [raw]
# #### check for negative values
# if (df < 0).any().any():
#     print('The DataFrame contains negative values')

# %%
y_test_pl= df_test['Qt']
y_test_pl = y_test_pl.to_numpy()
y_test_pl = y_test_pl.reshape(547,1)

# %%
# type(Y_pred_denorm)
type(y_test_pl)
print(y_test_pl.shape)
# Out:
# (547, 1)

# %%
y_test_pl
# Out:
# array([[  8.209],
#        [  7.878],
#        [  7.716],
#        [  7.406],
#        [  7.547],
#        [  9.705],
#        [ 12.41 ],
#        [ 11.4  ],
#        [ 11.78 ],
#        [ 11.18 ],
#        [  9.592],
#        [  8.971],
#        [  8.767],
#        [  8.476],
#        [  9.1  ],
#        [ 10.12 ],
#        [ 10.23 ],
#        [  8.742],
#        [  8.002],
#        [  7.598],
#        [  7.39 ],
#        [  7.179],
#        [  6.955],
#        [  7.089],
#        [  7.843],
#        [ 14.91 ],
#        [ 13.15 ],
#        [ 11.96 ],
#        [ 17.44 ],
#        [ 15.16 ],
#        [ 12.77 ],
#        [ 11.77 ],
#        [ 11.33 ],
#        [ 10.84 ],
#        [ 10.46 ],
#        [ 10.15 ],
#        [ 10.13 ],
#        [  9.378],
#        [  8.771],
#        [  8.122],
#        [  7.523],
#        [  7.336],
#        [  8.263],
#        [ 27.87 ],
#        [ 29.08 ],
#        [ 33.4  ],
#        [ 53.18 ],
#        [ 69.03 ],
#        [ 54.06 ],
#        [ 46.97 ],
#        [ 38.65 ],
#        [ 34.25 ],
#        [ 27.97 ],
#        [ 23.95 ],
#        [ 21.63 ],
#        [ 31.22 ],
#        [ 31.49 ],
#        [ 21.35 ],
#        [ 17.45 ],
#        [ 15.27 ],
#        [ 13.7  ],
#        [ 12.39 ],
#        [ 11.52 ],
#        [ 10.37 ],
#        [  9.989],
#        [ 21.   ],
#        [ 37.43 ],
#        [ 21.71 ],
#        [ 16.06 ],
#        [ 15.95 ],
#        [ 16.09 ],
#        [ 13.81 ],
#        [ 12.27 ],
#        [ 11.25 ],
#        [ 11.7  ],
#        [ 10.59 ],
#        [ 11.45 ],
#        [ 10.13 ],
#        [  9.273],
#        [  8.636],
#        [  8.265],
#        [  7.889],
#        [  7.407],
#        [  6.911],
#        [  6.476],
#        [  6.389],
#        [  6.219],
#        [  5.867],
#        [  5.489],
#        [  5.184],
#        [  5.158],
#        [  5.54 ],
#        [  6.451],
#        [  6.345],
#        [  7.028],
#        [ 14.21 ],
#        [ 21.54 ],
#        [ 19.09 ],
#        [ 12.18 ],
#        [  9.166],
#        [ 10.5  ],
#        [ 14.98 ],
#        [ 12.51 ],
#        [ 12.04 ],
#        [ 15.3  ],
#        [ 38.44 ],
#        [135.6  ],
#        [ 94.14 ],
#        [ 64.55 ],
#        [ 50.02 ],
#        [ 49.92 ],
#        [ 45.92 ],
#        [ 44.72 ],
#        [ 41.13 ],
#        [ 35.43 ],
#        [ 38.52 ],
#        [ 37.79 ],
#        [ 42.88 ],
#        [ 74.97 ],
#        [ 59.09 ],
#        [ 49.65 ],
#        [ 52.09 ],
#        [ 40.42 ],
#        [ 38.67 ],
#        [ 42.93 ],
#        [ 36.63 ],
#        [ 30.71 ],
#        [ 26.01 ],
#        [ 22.67 ],
#        [ 20.33 ],
#        [ 19.19 ],
#        [ 17.23 ],
#        [ 16.11 ],
#        [ 18.02 ],
#        [ 14.77 ],
#        [ 13.5  ],
#        [ 12.41 ],
#        [ 11.33 ],
#        [ 10.46 ],
#        [ 10.83 ],
#        [ 12.7  ],
#        [ 11.3  ],
#        [  9.761],
#        [ 13.73 ],
#        [ 16.12 ],
#        [ 12.96 ],
#        [ 26.59 ],
#        [ 22.08 ],
#        [ 21.64 ],
#        [ 20.23 ],
#        [ 17.77 ],
#        [ 25.71 ],
#        [ 34.06 ],
#        [ 50.96 ],
#        [ 67.6  ],
#        [ 52.86 ],
#        [ 44.75 ],
#        [ 37.59 ],
#        [ 28.72 ],
#        [ 27.94 ],
#        [ 26.49 ],
#        [ 20.83 ],
#        [ 17.92 ],
#        [ 16.01 ],
#        [ 14.5  ],
#        [ 13.24 ],
#        [ 12.23 ],
#        [ 11.25 ],
#        [ 10.41 ],
#        [  9.776],
#        [  9.222],
#        [  8.65 ],
#        [  8.201],
#        [  7.915],
#        [  7.624],
#        [  7.299],
#        [  6.976],
#        [  6.719],
#        [  6.468],
#        [  6.263],
#        [  6.092],
#        [  5.932],
#        [  5.746],
#        [  5.542],
#        [  5.422],
#        [  5.331],
#        [  5.351],
#        [ 20.08 ],
#        [ 29.37 ],
#        [ 16.69 ],
#        [ 12.52 ],
#        [ 13.73 ],
#        [ 14.17 ],
#        [ 14.71 ],
#        [ 11.79 ],
#        [ 10.78 ],
#        [ 10.18 ],
#        [  9.696],
#        [  9.197],
#        [  8.802],
#        [  8.45 ],
#        [ 10.68 ],
#        [ 12.57 ],
#        [ 11.77 ],
#        [ 12.25 ],
#        [ 15.63 ],
#        [ 13.39 ],
#        [ 12.06 ],
#        [ 12.51 ],
#        [ 13.46 ],
#        [ 12.2  ],
#        [ 18.79 ],
#        [ 23.29 ],
#        [ 93.26 ],
#        [ 57.06 ],
#        [ 53.9  ],
#        [ 47.79 ],
#        [ 53.45 ],
#        [ 69.58 ],
#        [ 87.12 ],
#        [ 75.97 ],
#        [ 56.12 ],
#        [ 46.28 ],
#        [ 41.59 ],
#        [ 64.17 ],
#        [138.9  ],
#        [236.2  ],
#        [176.2  ],
#        [151.2  ],
#        [103.2  ],
#        [131.1  ],
#        [139.7  ],
#        [181.3  ],
#        [190.1  ],
#        [157.1  ],
#        [123.1  ],
#        [102.1  ],
#        [108.1  ],
#        [ 90.38 ],
#        [ 85.77 ],
#        [109.3  ],
#        [ 94.95 ],
#        [ 77.04 ],
#        [ 65.18 ],
#        [ 82.45 ],
#        [ 75.   ],
#        [ 70.31 ],
#        [107.4  ],
#        [122.6  ],
#        [151.3  ],
#        [118.9  ],
#        [ 92.42 ],
#        [ 71.94 ],
#        [ 56.04 ],
#        [ 46.4  ],
#        [ 41.19 ],
#        [ 37.92 ],
#        [ 33.49 ],
#        [ 28.7  ],
#        [ 25.03 ],
#        [ 22.01 ],
#        [ 21.85 ],
#        [ 21.35 ],
#        [ 19.01 ],
#        [ 17.15 ],
#        [ 16.76 ],
#        [ 19.33 ],
#        [ 32.43 ],
#        [ 48.98 ],
#        [ 51.9  ],
#        [ 46.07 ],
#        [ 54.02 ],
#        [ 62.73 ],
#        [ 50.91 ],
#        [ 42.14 ],
#        [ 38.45 ],
#        [ 34.74 ],
#        [ 28.62 ],
#        [ 26.75 ],
#        [ 23.7  ],
#        [ 20.17 ],
#        [ 17.26 ],
#        [ 17.82 ],
#        [ 16.53 ],
#        [ 15.55 ],
#        [ 15.2  ],
#        [ 15.01 ],
#        [ 16.91 ],
#        [ 78.7  ],
#        [176.1  ],
#        [100.6  ],
#        [ 67.98 ],
#        [ 48.97 ],
#        [ 43.29 ],
#        [ 44.99 ],
#        [ 50.75 ],
#        [ 41.32 ],
#        [ 38.06 ],
#        [ 34.88 ],
#        [ 29.38 ],
#        [ 27.76 ],
#        [ 32.53 ],
#        [ 45.71 ],
#        [ 39.85 ],
#        [ 33.23 ],
#        [ 29.75 ],
#        [ 43.97 ],
#        [ 47.81 ],
#        [ 45.74 ],
#        [ 39.73 ],
#        [ 35.93 ],
#        [ 31.37 ],
#        [ 28.03 ],
#        [ 24.78 ],
#        [ 22.01 ],
#        [ 19.84 ],
#        [ 18.37 ],
#        [ 17.23 ],
#        [ 16.31 ],
#        [ 17.09 ],
#        [ 18.85 ],
#        [ 16.58 ],
#        [ 14.82 ],
#        [ 14.09 ],
#        [ 13.87 ],
#        [ 15.35 ],
#        [ 14.86 ],
#        [ 13.73 ],
#        [ 14.66 ],
#        [ 15.43 ],
#        [ 14.53 ],
#        [ 15.55 ],
#        [ 16.75 ],
#        [ 14.52 ],
#        [ 13.27 ],
#        [ 12.64 ],
#        [ 12.03 ],
#        [ 11.53 ],
#        [ 11.22 ],
#        [ 10.61 ],
#        [  9.909],
#        [  9.332],
#        [  8.89 ],
#        [  8.572],
#        [  8.409],
#        [  8.164],
#        [  7.851],
#        [  7.57 ],
#        [  7.295],
#        [  7.139],
#        [  7.548],
#        [  8.947],
#        [ 29.27 ],
#        [ 17.7  ],
#        [ 17.14 ],
#        [ 17.3  ],
#        [ 24.81 ],
#        [ 34.48 ],
#        [ 52.67 ],
#        [ 41.87 ],
#        [ 35.51 ],
#        [ 45.74 ],
#        [ 74.29 ],
#        [102.1  ],
#        [ 85.23 ],
#        [ 76.3  ],
#        [ 64.36 ],
#        [ 52.04 ],
#        [ 43.14 ],
#        [ 41.94 ],
#        [ 39.07 ],
#        [ 32.12 ],
#        [ 27.13 ],
#        [ 23.93 ],
#        [ 21.37 ],
#        [ 19.24 ],
#        [ 17.51 ],
#        [ 16.04 ],
#        [ 14.72 ],
#        [ 13.55 ],
#        [ 12.67 ],
#        [ 11.85 ],
#        [ 11.12 ],
#        [ 10.46 ],
#        [  9.896],
#        [  9.414],
#        [  8.966],
#        [  8.631],
#        [  8.671],
#        [  8.281],
#        [  7.982],
#        [  7.632],
#        [  7.924],
#        [  8.491],
#        [  9.341],
#        [ 11.86 ],
#        [  9.315],
#        [  7.756],
#        [  7.232],
#        [  7.286],
#        [  7.104],
#        [  6.727],
#        [  6.318],
#        [  6.115],
#        [  5.874],
#        [  5.73 ],
#        [  5.598],
#        [  6.2  ],
#        [  5.96 ],
#        [  5.777],
#        [  5.445],
#        [  5.224],
#        [  5.107],
#        [  4.954],
#        [  4.801],
#        [  4.581],
#        [  4.399],
#        [  4.225],
#        [  4.056],
#        [  3.923],
#        [  3.817],
#        [  3.735],
#        [  4.239],
#        [  4.126],
#        [  4.239],
#        [  5.173],
#        [  4.387],
#        [  4.089],
#        [  3.703],
#        [  3.472],
#        [  3.376],
#        [  3.682],
#        [  4.718],
#        [  6.465],
#        [  6.837],
#        [  5.137],
#        [  4.219],
#        [  3.859],
#        [  3.64 ],
#        [  3.443],
#        [  3.262],
#        [  3.095],
#        [  2.98 ],
#        [  2.877],
#        [  2.76 ],
#        [  2.677],
#        [  2.595],
#        [  2.521],
#        [  2.462],
#        [  2.387],
#        [  2.331],
#        [  2.267],
#        [  2.293],
#        [  2.39 ],
#        [  2.272],
#        [  4.259],
#        [  5.729],
#        [  3.993],
#        [  3.34 ],
#        [  3.015],
#        [  2.793],
#        [  2.976],
#        [  2.92 ],
#        [  2.837],
#        [  3.002],
#        [  3.292],
#        [  3.19 ],
#        [  3.051],
#        [  5.549],
#        [ 14.94 ],
#        [ 15.93 ],
#        [ 11.08 ],
#        [  9.529],
#        [ 10.92 ],
#        [ 59.81 ],
#        [ 88.13 ],
#        [ 54.39 ],
#        [ 41.38 ],
#        [ 28.44 ],
#        [ 21.98 ],
#        [ 19.79 ],
#        [ 18.62 ],
#        [ 15.04 ],
#        [ 13.11 ],
#        [ 12.06 ],
#        [ 13.12 ],
#        [ 13.13 ],
#        [ 11.06 ],
#        [  9.676],
#        [  9.324],
#        [  9.737],
#        [  8.641],
#        [  8.292],
#        [  8.269],
#        [  7.541],
#        [  6.972],
#        [  6.371],
#        [  5.963],
#        [  5.743],
#        [  5.837],
#        [  5.628],
#        [  5.214],
#        [  5.199],
#        [  5.25 ],
#        [  6.463],
#        [ 18.5  ],
#        [ 21.06 ],
#        [ 19.12 ],
#        [ 14.21 ],
#        [ 11.73 ],
#        [ 12.37 ],
#        [ 16.04 ],
#        [ 13.02 ],
#        [ 10.79 ],
#        [ 10.02 ],
#        [  9.264],
#        [  8.451],
#        [  7.817],
#        [  7.241],
#        [  6.76 ],
#        [  6.455],
#        [  6.123],
#        [  9.076],
#        [ 13.83 ],
#        [ 13.72 ],
#        [ 12.04 ],
#        [ 29.46 ],
#        [ 47.17 ],
#        [ 34.01 ],
#        [ 27.37 ],
#        [ 40.39 ],
#        [ 41.31 ],
#        [ 37.12 ],
#        [ 27.58 ],
#        [ 20.2  ],
#        [ 17.52 ],
#        [ 15.66 ],
#        [ 13.85 ],
#        [ 16.36 ],
#        [ 28.91 ],
#        [ 32.66 ],
#        [ 22.3  ],
#        [ 17.29 ],
#        [ 15.3  ],
#        [ 14.28 ],
#        [ 23.13 ],
#        [ 19.6  ]])

# %%
plt.figure(figsize = (16, 12))

plt.subplot(2, 1, 1)

plt.plot(Y_pred_denorm,'b', label = "Predicted")

plt.plot(y_test_pl , 'm',  label = "Observed")  

plt.legend()
plt.grid()

plt.subplot(2,1,2)

plt.plot(Y_pred_denorm - y_test_pl ,'r', label = "Error")

plt.legend()

plt.grid()

# %% [markdown]
# ## Log RMSE after denormalizaton

# %%
from sklearn.metrics import mean_squared_error
#### log of predicted values
y_pred_lg = np.log1p(Y_pred_denorm)  ### log1p instead of log: to avoid taking the logarithm of zero or negative values

#### log of test values
y_test_lg = np.log1p(Y_obser_denorm)

# %%
##calculate mse
mse = mean_squared_error(y_pred_lg, y_test_lg)
rmse_lg = np.sqrt(mse)   
print(rmse_lg)
# Out:
# 0.5648002456414619
