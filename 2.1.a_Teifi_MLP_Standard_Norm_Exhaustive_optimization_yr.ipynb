# %% [markdown]
# # Teifi catchment
# # 1. MLP

# %% [markdown]
# # Hyperparameter tuning using model_builder function from tensorflow   (Standard normalization)
# (After midterm)
# #(https://www.tensorflow.org/tutorials/keras/keras_tuner)

# %%
import numpy as np
import pandas as pd

### define file path
path = 'Teifi_R and Q with lag.csv'  ####### This excel data is not scaled/normalized

## Read CSV file and convert it to dataframe

df = pd.read_csv( path, sep = ',', header = 'infer')

# %% [raw]
# print(tf.__version__)

# %%
df
# Out:
#             Date    Rt  R_t_1  R_t_2  R_t_3  R_t_4  R_t_5  R_t_6  R_t_7  \
# 0     09/10/2000  15.7   11.8    1.6    2.8    1.1    7.7    7.7    2.9
# 1     10/10/2000  21.4   15.7   11.8    1.6    2.8    1.1    7.7    7.7
# 2     11/10/2000  10.3   21.4   15.7   11.8    1.6    2.8    1.1    7.7
# 3     12/10/2000  21.9   10.3   21.4   15.7   11.8    1.6    2.8    1.1
# 4     13/10/2000   2.7   21.9   10.3   21.4   15.7   11.8    1.6    2.8
# ...          ...   ...    ...    ...    ...    ...    ...    ...    ...
# 3639  26/09/2010   0.0    0.0    0.3    9.5   17.1    0.0    0.1    0.9
# 3640  27/09/2010   0.0    0.0    0.0    0.3    9.5   17.1    0.0    0.1
# 3641  28/09/2010  14.1    0.0    0.0    0.0    0.3    9.5   17.1    0.0
# 3642  29/09/2010   0.2   14.1    0.0    0.0    0.0    0.3    9.5   17.1
# 3643  30/09/2010  13.3    0.2   14.1    0.0    0.0    0.0    0.3    9.5
#
#       R_t_8      Qt
# 0      12.9   70.30
# 1       2.9   73.51
# 2       7.7   96.17
# 3       7.7  132.60
# 4       1.1  119.70
# ...     ...     ...
# 3639    0.5   17.29
# 3640    0.9   15.30
# 3641    0.1   14.28
# 3642    0.0   23.13
# 3643   17.1   19.60
#
# [3644 rows x 11 columns]

# %%
df = df.set_index('Date')
print(df)
# Out:
#               Rt  R_t_1  R_t_2  R_t_3  R_t_4  R_t_5  R_t_6  R_t_7  R_t_8  \
# Date
# 09/10/2000  15.7   11.8    1.6    2.8    1.1    7.7    7.7    2.9   12.9
# 10/10/2000  21.4   15.7   11.8    1.6    2.8    1.1    7.7    7.7    2.9
# 11/10/2000  10.3   21.4   15.7   11.8    1.6    2.8    1.1    7.7    7.7
# 12/10/2000  21.9   10.3   21.4   15.7   11.8    1.6    2.8    1.1    7.7
# 13/10/2000   2.7   21.9   10.3   21.4   15.7   11.8    1.6    2.8    1.1
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 26/09/2010   0.0    0.0    0.3    9.5   17.1    0.0    0.1    0.9    0.5
# 27/09/2010   0.0    0.0    0.0    0.3    9.5   17.1    0.0    0.1    0.9
# 28/09/2010  14.1    0.0    0.0    0.0    0.3    9.5   17.1    0.0    0.1
# 29/09/2010   0.2   14.1    0.0    0.0    0.0    0.3    9.5   17.1    0.0
# 30/09/2010  13.3    0.2   14.1    0.0    0.0    0.0    0.3    9.5   17.1
#
#                 Qt
# Date
# 09/10/2000   70.30
# 10/10/2000   73.51
# 11/10/2000   96.17
# 12/10/2000  132.60
# 13/10/2000  119.70
# ...            ...
# 26/09/2010   17.29
# 27/09/2010   15.30
# 28/09/2010   14.28
# 29/09/2010   23.13
# 30/09/2010   19.60
#
# [3644 rows x 10 columns]

# %%
df.describe()
# Out:
#                 Rt        R_t_1        R_t_2        R_t_3        R_t_4  \
# count  3644.000000  3644.000000  3644.000000  3644.000000  3644.000000
# mean      3.992179     3.991767     3.992151     3.989050     3.989352
# std       6.542103     6.541564     6.541383     6.539268     6.539109
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       1.100000     1.100000     1.100000     1.100000     1.100000
# 75%       5.300000     5.300000     5.300000     5.300000     5.300000
# max      60.000000    60.000000    60.000000    60.000000    60.000000
#
#              R_t_5        R_t_6        R_t_7        R_t_8           Qt
# count  3644.000000  3644.000000  3644.000000  3644.000000  3644.000000
# mean      3.991465     3.993578     3.994292     3.995225    30.440950
# std       6.539064     6.539018     6.538756     6.539785    34.149581
# min       0.000000     0.000000     0.000000     0.000000     2.085000
# 25%       0.000000     0.000000     0.000000     0.000000     8.120500
# 50%       1.100000     1.100000     1.100000     1.100000    18.020000
# 75%       5.300000     5.300000     5.300000     5.300000    40.450000
# max      60.000000    60.000000    60.000000    60.000000   373.000000

# %%
#### visualize the distribution
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
# Plot the distribution of rainfall data as a histogram
sns.histplot(df["Rt"], kde=False)

# Add labels and title to the plot
plt.xlabel("Rainfall (mm)")
plt.ylabel("Frequency")
plt.title("Histogram of Rainfall Data")
# plt.xlim(0, 80)
# plt.ylim(0, 300)
plt.show()

# %% [markdown]
# # 1. Data splitting

# %% [markdown]
# ##  Train, Validation and Test data
# ###  70% train (2550 data points)
# ###  15% train (547 data points)
# ###  15% train (547 data points)

# %%
df_train = df.iloc[:2550]

df_val = df.iloc[2550:3097] 

# df_test = df.iloc[3097:] 
df_test = df.tail(547).iloc[:]   ## gives the same result as the above line of code

# %%
df_train
# Out:
#               Rt  R_t_1  R_t_2  R_t_3  R_t_4  R_t_5  R_t_6  R_t_7  R_t_8  \
# Date
# 09/10/2000  15.7   11.8    1.6    2.8    1.1    7.7    7.7    2.9   12.9
# 10/10/2000  21.4   15.7   11.8    1.6    2.8    1.1    7.7    7.7    2.9
# 11/10/2000  10.3   21.4   15.7   11.8    1.6    2.8    1.1    7.7    7.7
# 12/10/2000  21.9   10.3   21.4   15.7   11.8    1.6    2.8    1.1    7.7
# 13/10/2000   2.7   21.9   10.3   21.4   15.7   11.8    1.6    2.8    1.1
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 28/09/2007   0.5    0.0    0.7    7.5    5.6   26.1    2.4    6.0    4.9
# 29/09/2007   0.5    0.5    0.0    0.7    7.5    5.6   26.1    2.4    6.0
# 30/09/2007   1.1    0.5    0.5    0.0    0.7    7.5    5.6   26.1    2.4
# 01/10/2007   0.1    1.1    0.5    0.5    0.0    0.7    7.5    5.6   26.1
# 02/10/2007   0.0    0.1    1.1    0.5    0.5    0.0    0.7    7.5    5.6
#
#                  Qt
# Date
# 09/10/2000   70.300
# 10/10/2000   73.510
# 11/10/2000   96.170
# 12/10/2000  132.600
# 13/10/2000  119.700
# ...             ...
# 28/09/2007   15.180
# 29/09/2007   12.430
# 30/09/2007   10.660
# 01/10/2007    9.556
# 02/10/2007    8.796
#
# [2550 rows x 10 columns]

# %% [markdown]
# # 2. Normalization

# %%
import pandas as pd
import numpy as np

### General function for all the normalization methods

def normalize_df(data, norm_method):     

    ## Normalize data using specified method
 
    if norm_method == 'minmax':
        # Min-Max normalization
        data_n = (data - data.min()) / (data.max() - data.min())
    elif norm_method == 'zscore':
        # Z-score normalization
        mean = data.mean()
        std = data.std()
        data_n = (data - mean) / std
    elif norm_method == 'max':
        # Max normalization
        data_n = 1 - ((data.max() - data)/data.max())
    else:
        raise ValueError("Invalid normalization method. Choose from: 'minmax', 'zscore', 'max'")
    return data_n

# %% [markdown]
# ### Standard normalization  (Data sets for training, validation and testing are nromalized separately)

# %%
## Z_score(standard)
df_train_norm = normalize_df(df_train, 'zscore')
df_val_norm = normalize_df(df_val, 'zscore')
df_test_norm = normalize_df(df_test, 'zscore')

# %%
###example
df_train_norm.describe()
# Out:
#                  Rt         R_t_1         R_t_2         R_t_3         R_t_4  \
# count  2.550000e+03  2.550000e+03  2.550000e+03  2.550000e+03  2.550000e+03
# mean  -2.099671e-15 -2.549943e-15 -1.856685e-15 -2.574847e-15 -2.324807e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -6.082633e-01 -6.088429e-01 -6.089583e-01 -6.090787e-01 -6.091250e-01
# 25%   -6.082633e-01 -6.088429e-01 -6.089583e-01 -6.090787e-01 -6.091250e-01
# 50%   -4.413379e-01 -4.343651e-01 -4.268866e-01 -4.270013e-01 -4.270444e-01
# 75%    1.808389e-01  1.801004e-01  1.800189e-01  1.799234e-01  1.798909e-01
# max    8.496762e+00  8.494350e+00  8.494624e+00  8.494792e+00  8.494905e+00
#
#               R_t_5         R_t_6         R_t_7         R_t_8            Qt
# count  2.550000e+03  2.550000e+03  2.550000e+03  2.550000e+03  2.550000e+03
# mean  -2.219924e-15 -2.402566e-15 -2.379970e-15 -2.489621e-15  1.455045e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -6.095501e-01 -6.100155e-01 -6.101733e-01 -6.103107e-01 -8.089168e-01
# 25%   -6.095501e-01 -6.100155e-01 -6.101733e-01 -6.103107e-01 -6.712789e-01
# 50%   -4.274705e-01 -4.279337e-01 -4.280835e-01 -4.282758e-01 -3.507176e-01
# 75%    1.794615e-01  1.903855e-01  1.902630e-01  1.898844e-01  2.884958e-01
# max    8.494430e+00  8.494071e+00  8.494315e+00  8.491435e+00  9.760296e+00

# %%
### convert the dataframes to numpy arrays

df_train_f = df_train_norm.to_numpy()

df_val_f = df_val_norm.to_numpy()

df_test_f = df_test_norm.to_numpy()

# %%
### Define input and output sequences (list of sub sequences)

def split_sequences(sequences, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequences)):
    # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out-1
    # check if we are beyond the dataset
        if out_end_ix > len(sequences):
            break
    # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1:out_end_ix, -1] 
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

n_steps_in, n_steps_out = 1, 1    #### 1 input sequences and 1 output sequences

# %% [markdown]
# ### Split into input and target variables

# %%
#### Training data


X_train, y_train = split_sequences(df_train_f, n_steps_in, n_steps_out)
print(X_train.shape, y_train.shape)

# reshape from [samples, timesteps] into [samples, timesteps, features]

n_features = 9   ## 9 rainfall inputs

X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
print(X_train.shape)
# Out:
# (2550, 1, 9) (2550, 1)
# (2550, 1, 9)

# %%
#### validation data

X_val, y_val = split_sequences(df_val_f , n_steps_in, n_steps_out)


X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], n_features))

### reshape

X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], n_features))

print(X_val.shape, y_val.shape)
# Out:
# (547, 1, 9) (547, 1)

# %%
#### Test data

X_test, y_test = split_sequences(df_test_f , n_steps_in, n_steps_out)

X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))

print(X_test.shape, y_test.shape)
# Out:
# (547, 1, 9) (547, 1)

# %% [raw]
# !pip install keras

# %% [raw]
# !pip install tensorflow

# %%
#### model fitting
import keras
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import save_model

from tensorflow.keras import initializers

from tensorflow.keras import layers

# %% [markdown]
# ## Hyperparameter tuning using KerasTuner

# %% [raw]
# !pip install keras-tuner --upgrade

# %%
import keras_tuner as kt


from keras_tuner.engine.hyperparameters import HyperParameters
from keras_tuner.engine.hyperparameters import Choice,Float

# %% [markdown]
# ### a. Define model (Using model_buider function)
# ### (https://www.tensorflow.org/tutorials/keras/keras_tuner)
# ## MLP

# %%
def model_buider(hp):
    
    model = keras.Sequential()
    
    model.add(keras.layers.Flatten(input_shape = (n_steps_in, n_features)))   ### flattening is important when using this function
 ###1. Tune the number of units in the first Dense layer
     
    hp_units = hp.Int('units', min_value = 1, max_value = 10, step = 1)
    
###2. Tune the activation function

    hp_activation = hp.Choice("activation", ["relu", "tanh", "sigmoid"])
    
###3. Tune the weight initialization
    hp_initializer=hp.Choice('weight_init', ['he_uniform', 'glorot_uniform', 'random_normal' , 'lecun_normal'])  ##
    
       ### Fix the seeds for reproducibility purposes   
        
    if hp_initializer == 'he_uniform':
        init = tf.keras.initializers.he_uniform(seed=1)
    elif hp_initializer == 'glorot_uniform':
        init = tf.keras.initializers.glorot_uniform(seed=1)
    elif hp_initializer == 'random_normal':
        init = tf.keras.initializers.RandomNormal(seed=1)
    else:
        init = tf.keras.initializers.lecun_normal(seed=1)
    
###4. Tune the number of layers
###5. Tune dropout rate

    for i in range(hp.Int("num_layers", 1, 3)):
        
        model.add(keras.layers.Dense(units = hp_units, activation = hp_activation, kernel_initializer = init))
        model.add(Dropout(hp.Float('dropout_rate', 0, 0.3, step=0.1)))
    ### Output layer
   
    model.add(keras.layers.Dense(1, kernel_initializer = init))
    model.add(Dropout(hp.Float('dropout_rate', 0, 0.3, step=0.1)))
###6. Tune the optimizer 

    hp_optimizer = hp.Choice("optimizer", ['Adam', 'SGD', 'RMSprop'])

    model.compile (
                    optimizer = hp_optimizer, ##(learning_rate=hp.Float('learning_rate', 1e-4, 1e-2, sampling='log'))###
                  
                    loss='mean_squared_error',
                   
                    metrics=[tf.keras.metrics.MeanSquaredError()])
    
  
    return model

# %% [markdown]
# ### b.  Instantiate the tuner and perform hypertuning

# %%
#### Hyperband tuner ( it is a class)

tuner = kt.Hyperband(model_buider,
                     
                     objective= 'mean_squared_error',  ### should be the same as the loss funtion used when compiling
                     
                     max_epochs = 50,
                     
                     factor = 2,  
                     
                     seed = 10,
                     
                     directory='Exhaustive_Opt_norm',
                     
                     project_name='Teifi_ml_test_4')

# %%
### Create a callback to stop training early after reaching a certain value for the validation loss.

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [raw]
# rm -rf ./logs/

# %%
from keras.callbacks import TensorBoard

import datetime, os
log_dir = "Exhaustive_Opt_norm/Teifi_test_1" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %% [markdown]
# ### C. Run hyperparameter search

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
tuner.search(X_train, y_train, 
             epochs=100, 
             validation_data=(X_val, y_val), 
             callbacks=[stop_early,tb])
# Out:
# Trial 186 Complete [00h 00m 26s]
# mean_squared_error: 0.34358564019203186
#
# Best mean_squared_error So Far: 0.1853114515542984
# Total elapsed time: 00h 20m 54s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in Exhaustive_Opt_norm\Teifi_ml_test_4
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x000001D836A4C8E0>
# Trial summary
# Hyperparameters:
# units: 9
# activation: relu
# weight_init: lecun_normal
# num_layers: 1
# dropout_rate: 0.0
# optimizer: RMSprop
# tuner/epochs: 50
# tuner/initial_epoch: 25
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0160
# Score: 0.1853114515542984
# Trial summary
# Hyperparameters:
# units: 8
# activation: relu
# weight_init: glorot_uniform
# num_layers: 2
# dropout_rate: 0.0
# optimizer: SGD
# tuner/epochs: 50
# tuner/initial_epoch: 25
# tuner/bracket: 5
# tuner/round: 5
# tuner/trial_id: 0072
# Score: 0.1866440325975418
# Trial summary
# Hyperparameters:
# units: 10
# activation: relu
# weight_init: he_uniform
# num_layers: 3
# dropout_rate: 0.0
# optimizer: RMSprop
# tuner/epochs: 50
# tuner/initial_epoch: 25
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0168
# Score: 0.1870981603860855
# Trial summary
# Hyperparameters:
# units: 6
# activation: relu
# weight_init: he_uniform
# num_layers: 3
# dropout_rate: 0.0
# optimizer: RMSprop
# tuner/epochs: 50
# tuner/initial_epoch: 25
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0161
# Score: 0.18960724771022797
# Trial summary
# Hyperparameters:
# units: 8
# activation: relu
# weight_init: lecun_normal
# num_layers: 1
# dropout_rate: 0.0
# optimizer: RMSprop
# tuner/epochs: 50
# tuner/initial_epoch: 25
# tuner/bracket: 5
# tuner/round: 5
# tuner/trial_id: 0073
# Score: 0.19054944813251495
# Trial summary
# Hyperparameters:
# units: 8
# activation: relu
# weight_init: glorot_uniform
# num_layers: 2
# dropout_rate: 0.0
# optimizer: SGD
# tuner/epochs: 25
# tuner/initial_epoch: 13
# tuner/bracket: 5
# tuner/round: 4
# tuner/trial_id: 0067
# Score: 0.19232277572155
# Trial summary
# Hyperparameters:
# units: 9
# activation: relu
# weight_init: lecun_normal
# num_layers: 1
# dropout_rate: 0.0
# optimizer: RMSprop
# tuner/epochs: 25
# tuner/initial_epoch: 13
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0151
# Score: 0.19316571950912476
# Trial summary
# Hyperparameters:
# units: 8
# activation: relu
# weight_init: lecun_normal
# num_layers: 1
# dropout_rate: 0.0
# optimizer: RMSprop
# tuner/epochs: 25
# tuner/initial_epoch: 13
# tuner/bracket: 5
# tuner/round: 4
# tuner/trial_id: 0068
# Score: 0.1947568953037262
# Trial summary
# Hyperparameters:
# units: 10
# activation: relu
# weight_init: he_uniform
# num_layers: 3
# dropout_rate: 0.0
# optimizer: RMSprop
# tuner/epochs: 25
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.1961163878440857
# Trial summary
# Hyperparameters:
# units: 6
# activation: relu
# weight_init: he_uniform
# num_layers: 3
# dropout_rate: 0.0
# optimizer: RMSprop
# tuner/epochs: 25
# tuner/initial_epoch: 13
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0154
# Score: 0.19949592649936676

# %% [raw]
# %tensorboard --logdir Exhaustive_Opt_norm/Teifi_test_1

# %% [markdown]
# ### steps in tensorboard

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [raw]
# rm -rf ./logs/

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %% [markdown]
# ## d.  get the optimal hyperparameters

# %%
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]


print(f"""
The hyperparameter search is complete. 

The optimal number of units in the first densely-connected layer is {best_hps.get('units')}, 
The optimal activation function is {best_hps.get('activation')},
The optimal weight initialization is {best_hps.get('weight_init')}
The optimal optimizer is {best_hps.get('optimizer')}.
The optimal number of layers is {best_hps.get('num_layers')},
The optimal dropout rate is {best_hps.get('dropout_rate')},

""")
# Out:
# The hyperparameter search is complete.
#
# The optimal number of units in the first densely-connected layer is 9,
# The optimal activation function is relu,
# The optimal weight initialization is lecun_normal
# The optimal optimizer is RMSprop.
# The optimal number of layers is 1,
# The optimal dropout rate is 0.0,

# %% [markdown]
# ## e. Train the model using the best model

# %%
model = tuner.hypermodel.build(best_hps)

# %%
### model training 
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
mlp_amt_1 = model.fit(X_train, y_train, epochs=500, validation_data = (X_val, y_val), shuffle = 0, callbacks=[early_stopping])
# Out:
# Epoch 1/500
# 80/80 [==============================] - 1s 8ms/step - loss: 1.1297 - mean_squared_error: 1.1297 - val_loss: 0.9647 - val_mean_squared_error: 0.9647
# Epoch 2/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.8743 - mean_squared_error: 0.8743 - val_loss: 0.7627 - val_mean_squared_error: 0.7627
# Epoch 3/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.7160 - mean_squared_error: 0.7160 - val_loss: 0.6294 - val_mean_squared_error: 0.6294
# Epoch 4/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.6124 - mean_squared_error: 0.6124 - val_loss: 0.5385 - val_mean_squared_error: 0.5385
# Epoch 5/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5409 - mean_squared_error: 0.5409 - val_loss: 0.4738 - val_mean_squared_error: 0.4738
# Epoch 6/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.4859 - mean_squared_error: 0.4859 - val_loss: 0.4254 - val_mean_squared_error: 0.4254
# Epoch 7/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.4411 - mean_squared_error: 0.4411 - val_loss: 0.3864 - val_mean_squared_error: 0.3864
# Epoch 8/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.4023 - mean_squared_error: 0.4023 - val_loss: 0.3548 - val_mean_squared_error: 0.3548
# Epoch 9/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3692 - mean_squared_error: 0.3692 - val_loss: 0.3281 - val_mean_squared_error: 0.3281
# Epoch 10/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.3408 - mean_squared_error: 0.3408 - val_loss: 0.3048 - val_mean_squared_error: 0.3048
# Epoch 11/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.3166 - mean_squared_error: 0.3166 - val_loss: 0.2861 - val_mean_squared_error: 0.2861
# Epoch 12/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2963 - mean_squared_error: 0.2963 - val_loss: 0.2711 - val_mean_squared_error: 0.2711
# Epoch 13/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2794 - mean_squared_error: 0.2794 - val_loss: 0.2594 - val_mean_squared_error: 0.2594
# Epoch 14/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2654 - mean_squared_error: 0.2654 - val_loss: 0.2501 - val_mean_squared_error: 0.2501
# Epoch 15/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2538 - mean_squared_error: 0.2538 - val_loss: 0.2430 - val_mean_squared_error: 0.2430
# Epoch 16/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2442 - mean_squared_error: 0.2442 - val_loss: 0.2377 - val_mean_squared_error: 0.2377
# Epoch 17/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2363 - mean_squared_error: 0.2363 - val_loss: 0.2335 - val_mean_squared_error: 0.2335
# Epoch 18/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2297 - mean_squared_error: 0.2297 - val_loss: 0.2304 - val_mean_squared_error: 0.2304
# Epoch 19/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2240 - mean_squared_error: 0.2240 - val_loss: 0.2276 - val_mean_squared_error: 0.2276
# Epoch 20/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2192 - mean_squared_error: 0.2192 - val_loss: 0.2257 - val_mean_squared_error: 0.2257
# Epoch 21/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2152 - mean_squared_error: 0.2152 - val_loss: 0.2242 - val_mean_squared_error: 0.2242
# Epoch 22/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2121 - mean_squared_error: 0.2121 - val_loss: 0.2229 - val_mean_squared_error: 0.2229
# Epoch 23/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2095 - mean_squared_error: 0.2095 - val_loss: 0.2220 - val_mean_squared_error: 0.2220
# Epoch 24/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2074 - mean_squared_error: 0.2074 - val_loss: 0.2213 - val_mean_squared_error: 0.2213
# Epoch 25/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2057 - mean_squared_error: 0.2057 - val_loss: 0.2208 - val_mean_squared_error: 0.2208
# Epoch 26/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2043 - mean_squared_error: 0.2043 - val_loss: 0.2204 - val_mean_squared_error: 0.2204
# Epoch 27/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2030 - mean_squared_error: 0.2030 - val_loss: 0.2201 - val_mean_squared_error: 0.2201
# Epoch 28/500
# 80/80 [==============================] - 1s 6ms/step - loss: 0.2018 - mean_squared_error: 0.2018 - val_loss: 0.2200 - val_mean_squared_error: 0.2200
# Epoch 29/500
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2007 - mean_squared_error: 0.2007 - val_loss: 0.2198 - val_mean_squared_error: 0.2198
# Epoch 30/500
# 80/80 [==============================] - 0s 6ms/step - loss: 0.1997 - mean_squared_error: 0.1997 - val_loss: 0.2197 - val_mean_squared_error: 0.2197
# Epoch 31/500
# 80/80 [==============================] - 0s 6ms/step - loss: 0.1987 - mean_squared_error: 0.1987 - val_loss: 0.2198 - val_mean_squared_error: 0.2198
# Epoch 32/500
# 80/80 [==============================] - 0s 6ms/step - loss: 0.1977 - mean_squared_error: 0.1977 - val_loss: 0.2197 - val_mean_squared_error: 0.2197
# Epoch 33/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1967 - mean_squared_error: 0.1967 - val_loss: 0.2195 - val_mean_squared_error: 0.2195
# Epoch 34/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1958 - mean_squared_error: 0.1958 - val_loss: 0.2195 - val_mean_squared_error: 0.2195
# Epoch 35/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1949 - mean_squared_error: 0.1949 - val_loss: 0.2195 - val_mean_squared_error: 0.2195
# Epoch 36/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1942 - mean_squared_error: 0.1942 - val_loss: 0.2194 - val_mean_squared_error: 0.2194
# Epoch 37/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1934 - mean_squared_error: 0.1934 - val_loss: 0.2193 - val_mean_squared_error: 0.2193
# Epoch 38/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1928 - mean_squared_error: 0.1928 - val_loss: 0.2190 - val_mean_squared_error: 0.2190
# Epoch 39/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1922 - mean_squared_error: 0.1922 - val_loss: 0.2190 - val_mean_squared_error: 0.2190
# Epoch 40/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1916 - mean_squared_error: 0.1916 - val_loss: 0.2192 - val_mean_squared_error: 0.2192
# Epoch 41/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1911 - mean_squared_error: 0.1911 - val_loss: 0.2193 - val_mean_squared_error: 0.2193
# Epoch 42/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1905 - mean_squared_error: 0.1905 - val_loss: 0.2193 - val_mean_squared_error: 0.2193
# Epoch 43/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1900 - mean_squared_error: 0.1900 - val_loss: 0.2194 - val_mean_squared_error: 0.2194
# Epoch 44/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1896 - mean_squared_error: 0.1896 - val_loss: 0.2196 - val_mean_squared_error: 0.2196
# Epoch 45/500
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1891 - mean_squared_error: 0.1891 - val_loss: 0.2198 - val_mean_squared_error: 0.2198
# Epoch 46/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1886 - mean_squared_error: 0.1886 - val_loss: 0.2201 - val_mean_squared_error: 0.2201
# Epoch 47/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1882 - mean_squared_error: 0.1882 - val_loss: 0.2203 - val_mean_squared_error: 0.2203
# Epoch 48/500
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1877 - mean_squared_error: 0.1877 - val_loss: 0.2205 - val_mean_squared_error: 0.2205
# Epoch 49/500
# 80/80 [==============================] - 0s 6ms/step - loss: 0.1873 - mean_squared_error: 0.1873 - val_loss: 0.2207 - val_mean_squared_error: 0.2207

# %% [raw]
# ### To find out how much time the model is taking to train
# ### Think about this one more
# import time
# start_time = time.time()
# tuner.search(X_train, y_train, validation_data=(X_val, y_val))
# end_time = time.time()
#
# elapsed_time = end_time - start_time
# print("Time elapsed: {:.2f} seconds".format(elapsed_time))

# %% [markdown]
# ## Plot training and validation errors

# %%
plt.plot(mlp_amt_1.history['mean_squared_error'], label = 'Training loss')
plt.plot(mlp_amt_1.history['val_mean_squared_error'], label = 'Validation loss')
plt.title('Mean Squared Error')
plt.xlabel('epochs')
plt.ylabel('mse')
plt.legend()

# %%
model.summary()   #### this shows us that the number of layers are 3 in this MLP model
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 9)                 0
#
#  dense_2 (Dense)             (None, 9)                 90
#
#  dropout_2 (Dropout)         (None, 9)                 0
#
#  dense_3 (Dense)             (None, 1)                 10
#
#  dropout_3 (Dropout)         (None, 1)                 0
#
# =================================================================
# Total params: 100
# Trainable params: 100
# Non-trainable params: 0
# _________________________________________________________________

# %% [raw]
# #### find the best epoch by looking in to the validation loss
#
# val_acc_per_epoch = mlp_amt_1.history['val_loss']
#
# #### 'val_loss' should align with the objective function used when applying 'tuner.search' (both should be loss or both accuracy)
#
# best_epoch = val_acc_per_epoch.index(min(val_acc_per_epoch)) + 1
#
# print('Best epoch: %d' % (best_epoch,))

# %% [raw]
# ### Re-instantiate the hypermodel and train it with the optimal number of epochs from above.
#
# hypermodel = tuner.hypermodel.build(best_hps)
#
# # Retrain the model
#
# hypermodel.fit(X_train, y_train, epochs= best_epoch, verbose = 1, validation_data=(X_val, y_val), shuffle = False)
#
# # hypermodel.fit(X_train, y_train, epochs= 250, verbose = 1, validation_data=(X_val, y_val), shuffle = False)

# %% [markdown]
# ## f. Test best model

# %%
eval_result = model.evaluate(X_test, y_test)
# eval_result = hypermodel.evaluate(X_test, y_test)

print("[test loss, test accuracy]:", eval_result)
# Out:
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2428 - mean_squared_error: 0.2428
# [test loss, test accuracy]: [0.242751345038414, 0.242751345038414]

# %%
Y_pred = model.predict(X_test)   ### when using early stopping
# Y_pred = hypermodel.predict(X_test)
# Out:
# 18/18 [==============================] - 0s 5ms/step

# %%
Y_pred
# Out:
# array([[-0.27564934],
#        [-0.42463607],
#        [-0.46951795],
#        [-0.608995  ],
#        [-0.60794896],
#        [-0.58956915],
#        [-0.44033614],
#        [-0.45626637],
#        [-0.16578643],
#        [-0.20501992],
#        [-0.28862   ],
#        [-0.3742473 ],
#        [-0.18032882],
#        [-0.258385  ],
#        [-0.31959578],
#        [-0.4846564 ],
#        [-0.63935643],
#        [-0.51846087],
#        [-0.53098565],
#        [-0.46347472],
#        [-0.546932  ],
#        [-0.46526414],
#        [-0.43010503],
#        [-0.63408864],
#        [-0.6102113 ],
#        [-0.3395688 ],
#        [-0.45739645],
#        [-0.04768024],
#        [ 0.01886435],
#        [-0.26006788],
#        [-0.1320819 ],
#        [-0.23502883],
#        [-0.17743158],
#        [-0.40419272],
#        [-0.31355107],
#        [-0.32203722],
#        [-0.4615416 ],
#        [-0.46056056],
#        [-0.5197119 ],
#        [-0.56375486],
#        [-0.49354786],
#        [-0.5170643 ],
#        [-0.48541778],
#        [-0.02382327],
#        [ 0.69608   ],
#        [ 1.1633196 ],
#        [ 1.4741795 ],
#        [ 1.7512592 ],
#        [ 1.1349543 ],
#        [ 1.0895811 ],
#        [ 0.6970031 ],
#        [ 0.16831586],
#        [-0.12352547],
#        [-0.06553116],
#        [-0.07502145],
#        [-0.11360054],
#        [-0.13886485],
#        [-0.4009319 ],
#        [-0.49456125],
#        [-0.4405478 ],
#        [-0.55990005],
#        [-0.46573687],
#        [-0.44387734],
#        [-0.5860509 ],
#        [-0.69221723],
#        [-0.7964271 ],
#        [ 0.3268349 ],
#        [-0.1028699 ],
#        [-0.31962815],
#        [-0.45152718],
#        [-0.40939307],
#        [-0.76496094],
#        [-0.5573058 ],
#        [-0.41581786],
#        [-0.4693855 ],
#        [-0.4788584 ],
#        [-0.47457796],
#        [-0.35751498],
#        [-0.55534005],
#        [-0.4189156 ],
#        [-0.44337168],
#        [-0.3536707 ],
#        [-0.3020307 ],
#        [-0.4446267 ],
#        [-0.46754578],
#        [-0.6332795 ],
#        [-0.61749786],
#        [-0.6401643 ],
#        [-0.6135741 ],
#        [-0.6430724 ],
#        [-0.5589321 ],
#        [-0.51839465],
#        [-0.34382668],
#        [-0.39546233],
#        [-0.25469884],
#        [ 0.70187443],
#        [ 0.86222965],
#        [ 0.54575294],
#        [ 0.03068087],
#        [-0.13455366],
#        [-0.07678527],
#        [ 0.6329271 ],
#        [ 0.72564393],
#        [ 0.22873032],
#        [ 0.02994223],
#        [ 0.98802173],
#        [ 3.1917696 ],
#        [ 2.144223  ],
#        [ 1.5255231 ],
#        [ 0.6834244 ],
#        [ 0.59361446],
#        [ 0.72204506],
#        [ 0.5757263 ],
#        [ 0.7174533 ],
#        [ 0.054477  ],
#        [ 0.3494231 ],
#        [ 0.60767233],
#        [ 0.7655795 ],
#        [ 1.44883   ],
#        [ 0.94660294],
#        [ 0.5075816 ],
#        [ 0.60326403],
#        [ 0.05435231],
#        [ 0.21389866],
#        [ 0.35640705],
#        [ 0.22207211],
#        [-0.32818326],
#        [-0.5166798 ],
#        [-0.40858427],
#        [-0.55063653],
#        [-0.44497776],
#        [-0.3356565 ],
#        [-0.5387922 ],
#        [-0.62103695],
#        [-0.5503786 ],
#        [-0.5311244 ],
#        [-0.4822864 ],
#        [-0.40874976],
#        [-0.505964  ],
#        [-0.45333248],
#        [-0.4482296 ],
#        [-0.6458276 ],
#        [-0.40572473],
#        [-0.77079886],
#        [-0.30855313],
#        [-0.37063843],
#        [ 0.14143172],
#        [ 0.19871151],
#        [-0.1547784 ],
#        [-0.09264433],
#        [-0.13357115],
#        [ 0.22038925],
#        [ 0.51231813],
#        [ 1.3170667 ],
#        [ 1.9571505 ],
#        [ 1.2456177 ],
#        [ 0.46062538],
#        [ 0.03355744],
#        [ 0.11705614],
#        [-0.03332585],
#        [-0.13676894],
#        [-0.19791713],
#        [-0.3828817 ],
#        [-0.5215612 ],
#        [-0.4537042 ],
#        [-0.40198722],
#        [-0.5140272 ],
#        [-0.53178865],
#        [-0.69115996],
#        [-0.69054574],
#        [-0.6897626 ],
#        [-0.6872497 ],
#        [-0.6890896 ],
#        [-0.6821048 ],
#        [-0.6813733 ],
#        [-0.6697884 ],
#        [-0.6653797 ],
#        [-0.6666614 ],
#        [-0.6502983 ],
#        [-0.6564485 ],
#        [-0.6539529 ],
#        [-0.65965956],
#        [-0.6790222 ],
#        [-0.673669  ],
#        [-0.6602604 ],
#        [-0.6525611 ],
#        [-0.58920616],
#        [ 0.14215739],
#        [ 0.9621666 ],
#        [ 0.10257484],
#        [ 0.15484399],
#        [-0.08956912],
#        [-0.09914279],
#        [-0.07033047],
#        [-0.1103074 ],
#        [-0.43747753],
#        [-0.41925776],
#        [-0.40909296],
#        [-0.29275092],
#        [-0.4903072 ],
#        [-0.57564116],
#        [-0.6540974 ],
#        [-0.51245505],
#        [-0.741154  ],
#        [-0.34079492],
#        [-0.25995508],
#        [-0.44627935],
#        [-0.39206836],
#        [-0.14955005],
#        [-0.26138335],
#        [-0.6820211 ],
#        [-0.30346677],
#        [ 0.34068456],
#        [ 1.1806664 ],
#        [ 0.92652136],
#        [ 1.1222298 ],
#        [ 0.7161062 ],
#        [ 0.882215  ],
#        [ 0.9795521 ],
#        [ 1.833047  ],
#        [ 1.5835235 ],
#        [ 0.6175372 ],
#        [ 0.43799874],
#        [ 0.06045924],
#        [ 0.7816588 ],
#        [ 2.4083629 ],
#        [ 3.9778085 ],
#        [ 3.6702724 ],
#        [ 2.7386706 ],
#        [ 2.2550294 ],
#        [ 2.7918768 ],
#        [ 2.4502187 ],
#        [ 3.4012918 ],
#        [ 3.0220163 ],
#        [ 3.3428707 ],
#        [ 2.6533866 ],
#        [ 2.242544  ],
#        [ 2.3229058 ],
#        [ 1.9377393 ],
#        [ 2.4493418 ],
#        [ 2.4776118 ],
#        [ 2.1139593 ],
#        [ 1.0711603 ],
#        [ 0.720628  ],
#        [ 1.3288113 ],
#        [ 1.6017228 ],
#        [ 0.93843585],
#        [ 1.5543348 ],
#        [ 1.9871286 ],
#        [ 2.4621649 ],
#        [ 1.974319  ],
#        [ 1.6237582 ],
#        [ 1.1346341 ],
#        [ 0.26214227],
#        [ 0.03531565],
#        [-0.2210567 ],
#        [-0.26003808],
#        [-0.29427242],
#        [-0.40207762],
#        [-0.5018987 ],
#        [-0.67436713],
#        [-0.6525562 ],
#        [-0.61703414],
#        [-0.6404991 ],
#        [-0.5286066 ],
#        [-0.66268414],
#        [-0.40144235],
#        [-0.35643718],
#        [ 0.54227525],
#        [ 0.8033143 ],
#        [ 0.05117355],
#        [ 0.21457304],
#        [ 0.9455827 ],
#        [ 0.8489999 ],
#        [ 0.04535471],
#        [ 0.07528573],
#        [-0.08102446],
#        [-0.32261077],
#        [-0.24644744],
#        [-0.20580882],
#        [-0.2849962 ],
#        [-0.40822014],
#        [-0.4088177 ],
#        [-0.42837733],
#        [-0.5534315 ],
#        [-0.4064123 ],
#        [-0.46903223],
#        [-0.61200696],
#        [ 0.00814034],
#        [ 1.046423  ],
#        [ 0.34301013],
#        [ 0.27445588],
#        [-0.13612936],
#        [-0.054221  ],
#        [-0.0126586 ],
#        [ 0.53211665],
#        [ 0.20410031],
#        [-0.33863205],
#        [-0.48002374],
#        [-0.3674735 ],
#        [-0.35328487],
#        [-0.03568906],
#        [-0.06371122],
#        [-0.6100006 ],
#        [-0.28482985],
#        [-0.40163112],
#        [-0.22449082],
#        [ 0.20362833],
#        [ 0.38151088],
#        [ 0.17890792],
#        [-0.17486528],
#        [-0.19226576],
#        [-0.26563922],
#        [-0.28648195],
#        [-0.31471896],
#        [-0.4351164 ],
#        [-0.59983975],
#        [-0.6762458 ],
#        [-0.6815892 ],
#        [-0.64817065],
#        [-0.6204675 ],
#        [-0.6106436 ],
#        [-0.583317  ],
#        [-0.5448349 ],
#        [-0.46771318],
#        [-0.4087991 ],
#        [-0.3464144 ],
#        [-0.37118208],
#        [-0.50012845],
#        [-0.47764778],
#        [-0.443885  ],
#        [-0.36761445],
#        [-0.4034543 ],
#        [-0.5126762 ],
#        [-0.4532447 ],
#        [-0.4459114 ],
#        [-0.46960497],
#        [-0.48046064],
#        [-0.48854548],
#        [-0.56854403],
#        [-0.67308694],
#        [-0.69002354],
#        [-0.6880012 ],
#        [-0.6878714 ],
#        [-0.6804901 ],
#        [-0.67802995],
#        [-0.6709282 ],
#        [-0.68448263],
#        [-0.6606309 ],
#        [-0.64425457],
#        [-0.63279474],
#        [-0.600396  ],
#        [-0.15665156],
#        [-0.48493528],
#        [-0.14029893],
#        [-0.29907712],
#        [-0.13893087],
#        [ 0.40755406],
#        [ 1.5480425 ],
#        [ 0.9213335 ],
#        [ 0.146418  ],
#        [ 0.37270224],
#        [ 1.8683549 ],
#        [ 2.5297706 ],
#        [ 1.6811541 ],
#        [ 1.4655789 ],
#        [ 0.9747468 ],
#        [ 0.41330546],
#        [ 0.27119207],
#        [ 0.23272347],
#        [ 0.23473835],
#        [-0.26683012],
#        [-0.31907   ],
#        [-0.4830798 ],
#        [-0.44026303],
#        [-0.5357135 ],
#        [-0.5005006 ],
#        [-0.4824313 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.68625146],
#        [-0.66497415],
#        [-0.6556379 ],
#        [-0.6272309 ],
#        [-0.6579824 ],
#        [-0.5907471 ],
#        [-0.49135035],
#        [-0.38398647],
#        [-0.1608885 ],
#        [-0.33207697],
#        [-0.3437059 ],
#        [-0.30890226],
#        [-0.2693859 ],
#        [-0.3162291 ],
#        [-0.39895475],
#        [-0.42988873],
#        [-0.5727174 ],
#        [-0.52639383],
#        [-0.49631935],
#        [-0.46816385],
#        [-0.5378422 ],
#        [-0.55921656],
#        [-0.50383735],
#        [-0.5301755 ],
#        [-0.43883547],
#        [-0.40767485],
#        [-0.4161666 ],
#        [-0.36927852],
#        [-0.5375664 ],
#        [-0.5758819 ],
#        [-0.64094514],
#        [-0.6423964 ],
#        [-0.63713807],
#        [-0.6845466 ],
#        [-0.6666822 ],
#        [-0.6253209 ],
#        [-0.6310656 ],
#        [-0.5234427 ],
#        [-0.4208156 ],
#        [-0.5435163 ],
#        [-0.41621467],
#        [-0.5251938 ],
#        [-0.35297757],
#        [-0.46750247],
#        [-0.255076  ],
#        [-0.2445172 ],
#        [-0.18835884],
#        [-0.15546298],
#        [-0.18163188],
#        [-0.20317559],
#        [-0.28214955],
#        [-0.25209257],
#        [-0.28680015],
#        [-0.42623392],
#        [-0.48349404],
#        [-0.6155386 ],
#        [-0.5946514 ],
#        [-0.59600395],
#        [-0.5860509 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.68028575],
#        [-0.6447641 ],
#        [-0.68405885],
#        [-0.6959075 ],
#        [ 0.10264495],
#        [-0.42604706],
#        [-0.411739  ],
#        [-0.4736293 ],
#        [-0.360771  ],
#        [-0.5647879 ],
#        [-0.2599378 ],
#        [-0.16085467],
#        [-0.50327563],
#        [-0.49352038],
#        [-0.48362345],
#        [-0.44050634],
#        [ 0.11795355],
#        [ 1.3303236 ],
#        [ 1.3071803 ],
#        [ 0.9628495 ],
#        [ 0.74100846],
#        [ 0.7045154 ],
#        [ 2.499832  ],
#        [ 4.5696907 ],
#        [ 3.4340231 ],
#        [ 1.767397  ],
#        [ 0.73738366],
#        [ 0.4757632 ],
#        [ 0.24571902],
#        [ 0.08142545],
#        [-0.24457443],
#        [-0.40284732],
#        [-0.45573646],
#        [-0.4781754 ],
#        [-0.49694902],
#        [-0.42681664],
#        [-0.6069556 ],
#        [-0.533759  ],
#        [-0.5747534 ],
#        [-0.41057372],
#        [-0.43328482],
#        [-0.46834192],
#        [-0.49338812],
#        [-0.4729076 ],
#        [-0.42816937],
#        [-0.4983114 ],
#        [-0.5191757 ],
#        [-0.50981927],
#        [-0.5954846 ],
#        [-0.5806157 ],
#        [-0.5667104 ],
#        [-0.55495286],
#        [-0.5160491 ],
#        [ 0.22589123],
#        [ 0.49771047],
#        [ 0.37464103],
#        [ 0.22162142],
#        [-0.16762075],
#        [-0.14479098],
#        [ 0.38180318],
#        [ 0.31855604],
#        [-0.47493833],
#        [-0.4119463 ],
#        [-0.38938114],
#        [-0.56730086],
#        [-0.5442969 ],
#        [-0.47668105],
#        [-0.6485474 ],
#        [-0.6493121 ],
#        [-0.63944054],
#        [-0.7079072 ],
#        [-0.22541136],
#        [-0.11357518],
#        [ 0.14005609],
#        [ 0.3515563 ],
#        [ 0.9462244 ],
#        [ 0.5076811 ],
#        [ 0.41991842],
#        [ 0.61522573],
#        [ 0.4534207 ],
#        [ 0.20240739],
#        [-0.16495645],
#        [-0.27584815],
#        [-0.3387577 ],
#        [-0.45141125],
#        [-0.33747548],
#        [-0.4845993 ],
#        [-0.21227407],
#        [-0.12163253],
#        [-0.5242683 ],
#        [-0.41371977],
#        [-0.42065138],
#        [-0.32528734],
#        [ 0.15097629],
#        [ 0.6727517 ]], dtype=float32)

# %%
y_test
# Out:
# array([[-0.56212305],
#        [-0.57290687],
#        [-0.57818475],
#        [-0.5882844 ],
#        [-0.58369069],
#        [-0.51338408],
#        [-0.42525648],
#        [-0.4581618 ],
#        [-0.44578158],
#        [-0.46532929],
#        [-0.51706557],
#        [-0.53729745],
#        [-0.54394367],
#        [-0.55342431],
#        [-0.53309469],
#        [-0.49986358],
#        [-0.49627984],
#        [-0.54475816],
#        [-0.56886701],
#        [-0.58202913],
#        [-0.58880567],
#        [-0.59567995],
#        [-0.60297776],
#        [-0.59861211],
#        [-0.57404715],
#        [-0.34380768],
#        [-0.40114764],
#        [-0.43991727],
#        [-0.2613815 ],
#        [-0.3356628 ],
#        [-0.41352786],
#        [-0.44610738],
#        [-0.46044236],
#        [-0.47640633],
#        [-0.48878655],
#        [-0.4988862 ],
#        [-0.49953779],
#        [-0.52403759],
#        [-0.54381336],
#        [-0.56495746],
#        [-0.5844726 ],
#        [-0.59056497],
#        [-0.56036375],
#        [ 0.07842289],
#        [ 0.11784411],
#        [ 0.25858764],
#        [ 0.90301054],
#        [ 1.41939593],
#        [ 0.93168052],
#        [ 0.70069172],
#        [ 0.42963012],
#        [ 0.28628023],
#        [ 0.08168085],
#        [-0.04928882],
#        [-0.12487331],
#        [ 0.18756429],
#        [ 0.19636076],
#        [-0.13399557],
#        [-0.2610557 ],
#        [-0.33207906],
#        [-0.3832289 ],
#        [-0.42590807],
#        [-0.45425226],
#        [-0.4917187 ],
#        [-0.5041315 ],
#        [-0.14539841],
#        [ 0.38988311],
#        [-0.12226695],
#        [-0.30634123],
#        [-0.30992498],
#        [-0.30536385],
#        [-0.37964515],
#        [-0.42981762],
#        [-0.46304873],
#        [-0.44838794],
#        [-0.48455121],
#        [-0.45653282],
#        [-0.49953779],
#        [-0.52745844],
#        [-0.54821159],
#        [-0.56029859],
#        [-0.57254849],
#        [-0.58825182],
#        [-0.60441126],
#        [-0.61858335],
#        [-0.62141777],
#        [-0.62695629],
#        [-0.63842428],
#        [-0.65073934],
#        [-0.66067609],
#        [-0.66152316],
#        [-0.64907778],
#        [-0.61939784],
#        [-0.62285127],
#        [-0.60059946],
#        [-0.36661335],
#        [-0.12780547],
#        [-0.20762529],
#        [-0.43274977],
#        [-0.53094445],
#        [-0.48748337],
#        [-0.34152712],
#        [-0.42199853],
#        [-0.4373109 ],
#        [-0.33110167],
#        [ 0.42278842],
#        [ 3.58821457],
#        [ 2.23746768],
#        [ 1.27343968],
#        [ 0.80005926],
#        [ 0.79680131],
#        [ 0.66648323],
#        [ 0.62738781],
#        [ 0.51042733],
#        [ 0.32472407],
#        [ 0.42539478],
#        [ 0.40161173],
#        [ 0.56744149],
#        [ 1.61291828],
#        [ 1.09555551],
#        [ 0.78800484],
#        [ 0.86749887],
#        [ 0.48729587],
#        [ 0.43028171],
#        [ 0.56907046],
#        [ 0.36381949],
#        [ 0.17094873],
#        [ 0.01782499],
#        [-0.09099061],
#        [-0.16722669],
#        [-0.20436734],
#        [-0.2682232 ],
#        [-0.30471226],
#        [-0.24248538],
#        [-0.34836882],
#        [-0.38974481],
#        [-0.42525648],
#        [-0.46044236],
#        [-0.48878655],
#        [-0.47673212],
#        [-0.41580842],
#        [-0.46141975],
#        [-0.51155963],
#        [-0.38225152],
#        [-0.30438646],
#        [-0.40733775],
#        [ 0.03672111],
#        [-0.11021253],
#        [-0.12454751],
#        [-0.17048464],
#        [-0.25063026],
#        [ 0.00805113],
#        [ 0.28009012],
#        [ 0.83068401],
#        [ 1.37280722],
#        [ 0.8925851 ],
#        [ 0.62836519],
#        [ 0.39509583],
#        [ 0.10611549],
#        [ 0.08070346],
#        [ 0.03346316],
#        [-0.15093693],
#        [-0.24574333],
#        [-0.30797021],
#        [-0.35716529],
#        [-0.39821548],
#        [-0.4311208 ],
#        [-0.46304873],
#        [-0.49041552],
#        [-0.51107094],
#        [-0.52911999],
#        [-0.54775548],
#        [-0.56238368],
#        [-0.57170142],
#        [-0.58118206],
#        [-0.59177041],
#        [-0.60229359],
#        [-0.61066653],
#        [-0.61884399],
#        [-0.62552279],
#        [-0.63109389],
#        [-0.63630661],
#        [-0.6423664 ],
#        [-0.64901263],
#        [-0.65292217],
#        [-0.6558869 ],
#        [-0.65523531],
#        [-0.17537157],
#        [ 0.12729217],
#        [-0.28581614],
#        [-0.42167274],
#        [-0.38225152],
#        [-0.36791653],
#        [-0.35032359],
#        [-0.44545578],
#        [-0.4783611 ],
#        [-0.49790881],
#        [-0.5136773 ],
#        [-0.52993448],
#        [-0.54280339],
#        [-0.55427138],
#        [-0.48161905],
#        [-0.42004376],
#        [-0.44610738],
#        [-0.43046921],
#        [-0.32035043],
#        [-0.39332855],
#        [-0.43665931],
#        [-0.42199853],
#        [-0.39104799],
#        [-0.43209818],
#        [-0.21739915],
#        [-0.07079131],
#        [ 2.2087977 ],
#        [ 1.02941908],
#        [ 0.9264678 ],
#        [ 0.72740693],
#        [ 0.91180701],
#        [ 1.43731467],
#        [ 2.00875945],
#        [ 1.6454978 ],
#        [ 0.99879433],
#        [ 0.67821186],
#        [ 0.52541391],
#        [ 1.26105947],
#        [ 3.69572699],
#        [ 6.86571427],
#        [ 4.91094308],
#        [ 4.09645508],
#        [ 2.53263813],
#        [ 3.44160673],
#        [ 3.7217906 ],
#        [ 5.07709863],
#        [ 5.36379841],
#        [ 4.28867425],
#        [ 3.18097057],
#        [ 2.49680066],
#        [ 2.69227778],
#        [ 2.11496868],
#        [ 1.9647771 ],
#        [ 2.7313732 ],
#        [ 2.26385709],
#        [ 1.68035789],
#        [ 1.29396478],
#        [ 1.85661309],
#        [ 1.61389567],
#        [ 1.46109772],
#        [ 2.66947211],
#        [ 3.16468081],
#        [ 4.09971304],
#        [ 3.04413659],
#        [ 2.1814309 ],
#        [ 1.51420234],
#        [ 0.99618797],
#        [ 0.6821214 ],
#        [ 0.5123821 ],
#        [ 0.40584707],
#        [ 0.2615198 ],
#        [ 0.1054639 ],
#        [-0.01410294],
#        [-0.11249309],
#        [-0.11770581],
#        [-0.13399557],
#        [-0.21023165],
#        [-0.27082956],
#        [-0.28353557],
#        [-0.1998062 ],
#        [ 0.22698551],
#        [ 0.76617656],
#        [ 0.86130876],
#        [ 0.67137016],
#        [ 0.93037734],
#        [ 1.21414496],
#        [ 0.82905503],
#        [ 0.54333264],
#        [ 0.42311422],
#        [ 0.3022442 ],
#        [ 0.10285753],
#        [ 0.04193383],
#        [-0.0574337 ],
#        [-0.17243941],
#        [-0.26724581],
#        [-0.24900128],
#        [-0.29102886],
#        [-0.32295679],
#        [-0.33435962],
#        [-0.34054973],
#        [-0.27864864],
#        [ 1.73443989],
#        [ 4.90768513],
#        [ 2.44793138],
#        [ 1.38518744],
#        [ 0.76585076],
#        [ 0.58079909],
#        [ 0.63618428],
#        [ 0.82384231],
#        [ 0.51661744],
#        [ 0.4104082 ],
#        [ 0.30680533],
#        [ 0.12761797],
#        [ 0.07483915],
#        [ 0.23024346],
#        [ 0.65964153],
#        [ 0.46872554],
#        [ 0.25304912],
#        [ 0.13967239],
#        [ 0.60295317],
#        [ 0.72805852],
#        [ 0.66061892],
#        [ 0.464816  ],
#        [ 0.34101383],
#        [ 0.19245121],
#        [ 0.08363562],
#        [-0.02224782],
#        [-0.11249309],
#        [-0.18319065],
#        [-0.23108254],
#        [-0.2682232 ],
#        [-0.29819636],
#        [-0.27278433],
#        [-0.21544437],
#        [-0.28939988],
#        [-0.34673984],
#        [-0.37052289],
#        [-0.37769038],
#        [-0.32947269],
#        [-0.34543666],
#        [-0.38225152],
#        [-0.35195256],
#        [-0.32686633],
#        [-0.3561879 ],
#        [-0.32295679],
#        [-0.28386137],
#        [-0.3565137 ],
#        [-0.3972381 ],
#        [-0.41776319],
#        [-0.4376367 ],
#        [-0.45392646],
#        [-0.46402611],
#        [-0.48389962],
#        [-0.50673786],
#        [-0.52553624],
#        [-0.53993639],
#        [-0.55029668],
#        [-0.55560714],
#        [-0.56358912],
#        [-0.57378651],
#        [-0.58294136],
#        [-0.59190073],
#        [-0.59698313],
#        [-0.58365811],
#        [-0.53807936],
#        [ 0.12403422],
#        [-0.25291082],
#        [-0.27115535],
#        [-0.26594263],
#        [-0.02127044],
#        [ 0.29377352],
#        [ 0.88639499],
#        [ 0.53453617],
#        [ 0.32733043],
#        [ 0.66061892],
#        [ 1.59076421],
#        [ 2.49680066],
#        [ 1.94718416],
#        [ 1.65624904],
#        [ 1.26724958],
#        [ 0.86586989],
#        [ 0.57591216],
#        [ 0.53681674],
#        [ 0.44331352],
#        [ 0.21688585],
#        [ 0.05431405],
#        [-0.04994041],
#        [-0.13334398],
#        [-0.20273836],
#        [-0.25910093],
#        [-0.30699283],
#        [-0.34999779],
#        [-0.38811583],
#        [-0.41678581],
#        [-0.44350101],
#        [-0.46728406],
#        [-0.48878655],
#        [-0.5071614 ],
#        [-0.52286472],
#        [-0.53746035],
#        [-0.54837449],
#        [-0.54707131],
#        [-0.55977732],
#        [-0.5695186 ],
#        [-0.58092143],
#        [-0.57140821],
#        [-0.55293562],
#        [-0.52524303],
#        [-0.44317522],
#        [-0.5260901 ],
#        [-0.57688157],
#        [-0.59395324],
#        [-0.59219394],
#        [-0.59812342],
#        [-0.61040589],
#        [-0.62373092],
#        [-0.63034456],
#        [-0.63819622],
#        [-0.64288768],
#        [-0.64718817],
#        [-0.6275753 ],
#        [-0.63539439],
#        [-0.64135644],
#        [-0.65217284],
#        [-0.65937291],
#        [-0.66318472],
#        [-0.66816938],
#        [-0.67315405],
#        [-0.68032154],
#        [-0.68625102],
#        [-0.69191985],
#        [-0.69742579],
#        [-0.70175887],
#        [-0.7052123 ],
#        [-0.70788382],
#        [-0.69146374],
#        [-0.69514523],
#        [-0.69146374],
#        [-0.66103447],
#        [-0.68664197],
#        [-0.69635067],
#        [-0.70892636],
#        [-0.71645223],
#        [-0.71957987],
#        [-0.70961053],
#        [-0.67585815],
#        [-0.61894173],
#        [-0.60682215],
#        [-0.66220733],
#        [-0.69211533],
#        [-0.70384396],
#        [-0.71097887],
#        [-0.71739704],
#        [-0.72329393],
#        [-0.72873471],
#        [-0.73248136],
#        [-0.73583705],
#        [-0.73964885],
#        [-0.74235295],
#        [-0.74502447],
#        [-0.74743535],
#        [-0.74935755],
#        [-0.75180101],
#        [-0.75362546],
#        [-0.75571055],
#        [-0.75486349],
#        [-0.75170327],
#        [-0.75554766],
#        [-0.69081215],
#        [-0.64292025],
#        [-0.6994783 ],
#        [-0.72075273],
#        [-0.73134107],
#        [-0.73857373],
#        [-0.73261167],
#        [-0.73443613],
#        [-0.73714023],
#        [-0.73176461],
#        [-0.72231654],
#        [-0.72563966],
#        [-0.73016821],
#        [-0.64878457],
#        [-0.3428303 ],
#        [-0.31057657],
#        [-0.46858724],
#        [-0.51911808],
#        [-0.47379997],
#        [ 1.11901276],
#        [ 2.04166476],
#        [ 0.94243176],
#        [ 0.51857221],
#        [ 0.09699322],
#        [-0.11347048],
#        [-0.18481963],
#        [-0.22293766],
#        [-0.33957235],
#        [-0.40245082],
#        [-0.43665931],
#        [-0.40212502],
#        [-0.40179923],
#        [-0.46923883],
#        [-0.51432889],
#        [-0.52579688],
#        [-0.51234154],
#        [-0.54804869],
#        [-0.55941895],
#        [-0.56016827],
#        [-0.58388616],
#        [-0.60242391],
#        [-0.6220042 ],
#        [-0.63529665],
#        [-0.64246414],
#        [-0.63940167],
#        [-0.64621079],
#        [-0.65969871],
#        [-0.6601874 ],
#        [-0.65852585],
#        [-0.61900689],
#        [-0.22684721],
#        [-0.14344364],
#        [-0.2066479 ],
#        [-0.36661335],
#        [-0.44741056],
#        [-0.42655966],
#        [-0.30699283],
#        [-0.40538298],
#        [-0.4780353 ],
#        [-0.50312154],
#        [-0.52775165],
#        [-0.5542388 ],
#        [-0.57489422],
#        [-0.59366002],
#        [-0.60933077],
#        [-0.61926752],
#        [-0.63008392],
#        [-0.5338766 ],
#        [-0.37899356],
#        [-0.38257731],
#        [-0.4373109 ],
#        [ 0.13022433],
#        [ 0.70720763],
#        [ 0.27846115],
#        [ 0.06213313],
#        [ 0.48631848],
#        [ 0.51629164],
#        [ 0.37978345],
#        [ 0.06897483],
#        [-0.17146202],
#        [-0.25877514],
#        [-0.31937304],
#        [-0.37834197],
#        [-0.29656738],
#        [ 0.1123056 ],
#        [ 0.2344788 ],
#        [-0.10304503],
#        [-0.26626843],
#        [-0.33110167],
#        [-0.36433278],
#        [-0.07600403],
#        [-0.19100973]])

# %%
y_test.shape
# Out:
# (547, 1)

# %%
print(y_test[:,:-1].shape)   
print(y_test[:,1:2].shape)
# Out:
# (547, 0)
# (547, 0)

# %%
y_test[:,-1:]    ##### all rows and all columns including -1(which is the last column)
# Out:
# array([[-0.56212305],
#        [-0.57290687],
#        [-0.57818475],
#        [-0.5882844 ],
#        [-0.58369069],
#        [-0.51338408],
#        [-0.42525648],
#        [-0.4581618 ],
#        [-0.44578158],
#        [-0.46532929],
#        [-0.51706557],
#        [-0.53729745],
#        [-0.54394367],
#        [-0.55342431],
#        [-0.53309469],
#        [-0.49986358],
#        [-0.49627984],
#        [-0.54475816],
#        [-0.56886701],
#        [-0.58202913],
#        [-0.58880567],
#        [-0.59567995],
#        [-0.60297776],
#        [-0.59861211],
#        [-0.57404715],
#        [-0.34380768],
#        [-0.40114764],
#        [-0.43991727],
#        [-0.2613815 ],
#        [-0.3356628 ],
#        [-0.41352786],
#        [-0.44610738],
#        [-0.46044236],
#        [-0.47640633],
#        [-0.48878655],
#        [-0.4988862 ],
#        [-0.49953779],
#        [-0.52403759],
#        [-0.54381336],
#        [-0.56495746],
#        [-0.5844726 ],
#        [-0.59056497],
#        [-0.56036375],
#        [ 0.07842289],
#        [ 0.11784411],
#        [ 0.25858764],
#        [ 0.90301054],
#        [ 1.41939593],
#        [ 0.93168052],
#        [ 0.70069172],
#        [ 0.42963012],
#        [ 0.28628023],
#        [ 0.08168085],
#        [-0.04928882],
#        [-0.12487331],
#        [ 0.18756429],
#        [ 0.19636076],
#        [-0.13399557],
#        [-0.2610557 ],
#        [-0.33207906],
#        [-0.3832289 ],
#        [-0.42590807],
#        [-0.45425226],
#        [-0.4917187 ],
#        [-0.5041315 ],
#        [-0.14539841],
#        [ 0.38988311],
#        [-0.12226695],
#        [-0.30634123],
#        [-0.30992498],
#        [-0.30536385],
#        [-0.37964515],
#        [-0.42981762],
#        [-0.46304873],
#        [-0.44838794],
#        [-0.48455121],
#        [-0.45653282],
#        [-0.49953779],
#        [-0.52745844],
#        [-0.54821159],
#        [-0.56029859],
#        [-0.57254849],
#        [-0.58825182],
#        [-0.60441126],
#        [-0.61858335],
#        [-0.62141777],
#        [-0.62695629],
#        [-0.63842428],
#        [-0.65073934],
#        [-0.66067609],
#        [-0.66152316],
#        [-0.64907778],
#        [-0.61939784],
#        [-0.62285127],
#        [-0.60059946],
#        [-0.36661335],
#        [-0.12780547],
#        [-0.20762529],
#        [-0.43274977],
#        [-0.53094445],
#        [-0.48748337],
#        [-0.34152712],
#        [-0.42199853],
#        [-0.4373109 ],
#        [-0.33110167],
#        [ 0.42278842],
#        [ 3.58821457],
#        [ 2.23746768],
#        [ 1.27343968],
#        [ 0.80005926],
#        [ 0.79680131],
#        [ 0.66648323],
#        [ 0.62738781],
#        [ 0.51042733],
#        [ 0.32472407],
#        [ 0.42539478],
#        [ 0.40161173],
#        [ 0.56744149],
#        [ 1.61291828],
#        [ 1.09555551],
#        [ 0.78800484],
#        [ 0.86749887],
#        [ 0.48729587],
#        [ 0.43028171],
#        [ 0.56907046],
#        [ 0.36381949],
#        [ 0.17094873],
#        [ 0.01782499],
#        [-0.09099061],
#        [-0.16722669],
#        [-0.20436734],
#        [-0.2682232 ],
#        [-0.30471226],
#        [-0.24248538],
#        [-0.34836882],
#        [-0.38974481],
#        [-0.42525648],
#        [-0.46044236],
#        [-0.48878655],
#        [-0.47673212],
#        [-0.41580842],
#        [-0.46141975],
#        [-0.51155963],
#        [-0.38225152],
#        [-0.30438646],
#        [-0.40733775],
#        [ 0.03672111],
#        [-0.11021253],
#        [-0.12454751],
#        [-0.17048464],
#        [-0.25063026],
#        [ 0.00805113],
#        [ 0.28009012],
#        [ 0.83068401],
#        [ 1.37280722],
#        [ 0.8925851 ],
#        [ 0.62836519],
#        [ 0.39509583],
#        [ 0.10611549],
#        [ 0.08070346],
#        [ 0.03346316],
#        [-0.15093693],
#        [-0.24574333],
#        [-0.30797021],
#        [-0.35716529],
#        [-0.39821548],
#        [-0.4311208 ],
#        [-0.46304873],
#        [-0.49041552],
#        [-0.51107094],
#        [-0.52911999],
#        [-0.54775548],
#        [-0.56238368],
#        [-0.57170142],
#        [-0.58118206],
#        [-0.59177041],
#        [-0.60229359],
#        [-0.61066653],
#        [-0.61884399],
#        [-0.62552279],
#        [-0.63109389],
#        [-0.63630661],
#        [-0.6423664 ],
#        [-0.64901263],
#        [-0.65292217],
#        [-0.6558869 ],
#        [-0.65523531],
#        [-0.17537157],
#        [ 0.12729217],
#        [-0.28581614],
#        [-0.42167274],
#        [-0.38225152],
#        [-0.36791653],
#        [-0.35032359],
#        [-0.44545578],
#        [-0.4783611 ],
#        [-0.49790881],
#        [-0.5136773 ],
#        [-0.52993448],
#        [-0.54280339],
#        [-0.55427138],
#        [-0.48161905],
#        [-0.42004376],
#        [-0.44610738],
#        [-0.43046921],
#        [-0.32035043],
#        [-0.39332855],
#        [-0.43665931],
#        [-0.42199853],
#        [-0.39104799],
#        [-0.43209818],
#        [-0.21739915],
#        [-0.07079131],
#        [ 2.2087977 ],
#        [ 1.02941908],
#        [ 0.9264678 ],
#        [ 0.72740693],
#        [ 0.91180701],
#        [ 1.43731467],
#        [ 2.00875945],
#        [ 1.6454978 ],
#        [ 0.99879433],
#        [ 0.67821186],
#        [ 0.52541391],
#        [ 1.26105947],
#        [ 3.69572699],
#        [ 6.86571427],
#        [ 4.91094308],
#        [ 4.09645508],
#        [ 2.53263813],
#        [ 3.44160673],
#        [ 3.7217906 ],
#        [ 5.07709863],
#        [ 5.36379841],
#        [ 4.28867425],
#        [ 3.18097057],
#        [ 2.49680066],
#        [ 2.69227778],
#        [ 2.11496868],
#        [ 1.9647771 ],
#        [ 2.7313732 ],
#        [ 2.26385709],
#        [ 1.68035789],
#        [ 1.29396478],
#        [ 1.85661309],
#        [ 1.61389567],
#        [ 1.46109772],
#        [ 2.66947211],
#        [ 3.16468081],
#        [ 4.09971304],
#        [ 3.04413659],
#        [ 2.1814309 ],
#        [ 1.51420234],
#        [ 0.99618797],
#        [ 0.6821214 ],
#        [ 0.5123821 ],
#        [ 0.40584707],
#        [ 0.2615198 ],
#        [ 0.1054639 ],
#        [-0.01410294],
#        [-0.11249309],
#        [-0.11770581],
#        [-0.13399557],
#        [-0.21023165],
#        [-0.27082956],
#        [-0.28353557],
#        [-0.1998062 ],
#        [ 0.22698551],
#        [ 0.76617656],
#        [ 0.86130876],
#        [ 0.67137016],
#        [ 0.93037734],
#        [ 1.21414496],
#        [ 0.82905503],
#        [ 0.54333264],
#        [ 0.42311422],
#        [ 0.3022442 ],
#        [ 0.10285753],
#        [ 0.04193383],
#        [-0.0574337 ],
#        [-0.17243941],
#        [-0.26724581],
#        [-0.24900128],
#        [-0.29102886],
#        [-0.32295679],
#        [-0.33435962],
#        [-0.34054973],
#        [-0.27864864],
#        [ 1.73443989],
#        [ 4.90768513],
#        [ 2.44793138],
#        [ 1.38518744],
#        [ 0.76585076],
#        [ 0.58079909],
#        [ 0.63618428],
#        [ 0.82384231],
#        [ 0.51661744],
#        [ 0.4104082 ],
#        [ 0.30680533],
#        [ 0.12761797],
#        [ 0.07483915],
#        [ 0.23024346],
#        [ 0.65964153],
#        [ 0.46872554],
#        [ 0.25304912],
#        [ 0.13967239],
#        [ 0.60295317],
#        [ 0.72805852],
#        [ 0.66061892],
#        [ 0.464816  ],
#        [ 0.34101383],
#        [ 0.19245121],
#        [ 0.08363562],
#        [-0.02224782],
#        [-0.11249309],
#        [-0.18319065],
#        [-0.23108254],
#        [-0.2682232 ],
#        [-0.29819636],
#        [-0.27278433],
#        [-0.21544437],
#        [-0.28939988],
#        [-0.34673984],
#        [-0.37052289],
#        [-0.37769038],
#        [-0.32947269],
#        [-0.34543666],
#        [-0.38225152],
#        [-0.35195256],
#        [-0.32686633],
#        [-0.3561879 ],
#        [-0.32295679],
#        [-0.28386137],
#        [-0.3565137 ],
#        [-0.3972381 ],
#        [-0.41776319],
#        [-0.4376367 ],
#        [-0.45392646],
#        [-0.46402611],
#        [-0.48389962],
#        [-0.50673786],
#        [-0.52553624],
#        [-0.53993639],
#        [-0.55029668],
#        [-0.55560714],
#        [-0.56358912],
#        [-0.57378651],
#        [-0.58294136],
#        [-0.59190073],
#        [-0.59698313],
#        [-0.58365811],
#        [-0.53807936],
#        [ 0.12403422],
#        [-0.25291082],
#        [-0.27115535],
#        [-0.26594263],
#        [-0.02127044],
#        [ 0.29377352],
#        [ 0.88639499],
#        [ 0.53453617],
#        [ 0.32733043],
#        [ 0.66061892],
#        [ 1.59076421],
#        [ 2.49680066],
#        [ 1.94718416],
#        [ 1.65624904],
#        [ 1.26724958],
#        [ 0.86586989],
#        [ 0.57591216],
#        [ 0.53681674],
#        [ 0.44331352],
#        [ 0.21688585],
#        [ 0.05431405],
#        [-0.04994041],
#        [-0.13334398],
#        [-0.20273836],
#        [-0.25910093],
#        [-0.30699283],
#        [-0.34999779],
#        [-0.38811583],
#        [-0.41678581],
#        [-0.44350101],
#        [-0.46728406],
#        [-0.48878655],
#        [-0.5071614 ],
#        [-0.52286472],
#        [-0.53746035],
#        [-0.54837449],
#        [-0.54707131],
#        [-0.55977732],
#        [-0.5695186 ],
#        [-0.58092143],
#        [-0.57140821],
#        [-0.55293562],
#        [-0.52524303],
#        [-0.44317522],
#        [-0.5260901 ],
#        [-0.57688157],
#        [-0.59395324],
#        [-0.59219394],
#        [-0.59812342],
#        [-0.61040589],
#        [-0.62373092],
#        [-0.63034456],
#        [-0.63819622],
#        [-0.64288768],
#        [-0.64718817],
#        [-0.6275753 ],
#        [-0.63539439],
#        [-0.64135644],
#        [-0.65217284],
#        [-0.65937291],
#        [-0.66318472],
#        [-0.66816938],
#        [-0.67315405],
#        [-0.68032154],
#        [-0.68625102],
#        [-0.69191985],
#        [-0.69742579],
#        [-0.70175887],
#        [-0.7052123 ],
#        [-0.70788382],
#        [-0.69146374],
#        [-0.69514523],
#        [-0.69146374],
#        [-0.66103447],
#        [-0.68664197],
#        [-0.69635067],
#        [-0.70892636],
#        [-0.71645223],
#        [-0.71957987],
#        [-0.70961053],
#        [-0.67585815],
#        [-0.61894173],
#        [-0.60682215],
#        [-0.66220733],
#        [-0.69211533],
#        [-0.70384396],
#        [-0.71097887],
#        [-0.71739704],
#        [-0.72329393],
#        [-0.72873471],
#        [-0.73248136],
#        [-0.73583705],
#        [-0.73964885],
#        [-0.74235295],
#        [-0.74502447],
#        [-0.74743535],
#        [-0.74935755],
#        [-0.75180101],
#        [-0.75362546],
#        [-0.75571055],
#        [-0.75486349],
#        [-0.75170327],
#        [-0.75554766],
#        [-0.69081215],
#        [-0.64292025],
#        [-0.6994783 ],
#        [-0.72075273],
#        [-0.73134107],
#        [-0.73857373],
#        [-0.73261167],
#        [-0.73443613],
#        [-0.73714023],
#        [-0.73176461],
#        [-0.72231654],
#        [-0.72563966],
#        [-0.73016821],
#        [-0.64878457],
#        [-0.3428303 ],
#        [-0.31057657],
#        [-0.46858724],
#        [-0.51911808],
#        [-0.47379997],
#        [ 1.11901276],
#        [ 2.04166476],
#        [ 0.94243176],
#        [ 0.51857221],
#        [ 0.09699322],
#        [-0.11347048],
#        [-0.18481963],
#        [-0.22293766],
#        [-0.33957235],
#        [-0.40245082],
#        [-0.43665931],
#        [-0.40212502],
#        [-0.40179923],
#        [-0.46923883],
#        [-0.51432889],
#        [-0.52579688],
#        [-0.51234154],
#        [-0.54804869],
#        [-0.55941895],
#        [-0.56016827],
#        [-0.58388616],
#        [-0.60242391],
#        [-0.6220042 ],
#        [-0.63529665],
#        [-0.64246414],
#        [-0.63940167],
#        [-0.64621079],
#        [-0.65969871],
#        [-0.6601874 ],
#        [-0.65852585],
#        [-0.61900689],
#        [-0.22684721],
#        [-0.14344364],
#        [-0.2066479 ],
#        [-0.36661335],
#        [-0.44741056],
#        [-0.42655966],
#        [-0.30699283],
#        [-0.40538298],
#        [-0.4780353 ],
#        [-0.50312154],
#        [-0.52775165],
#        [-0.5542388 ],
#        [-0.57489422],
#        [-0.59366002],
#        [-0.60933077],
#        [-0.61926752],
#        [-0.63008392],
#        [-0.5338766 ],
#        [-0.37899356],
#        [-0.38257731],
#        [-0.4373109 ],
#        [ 0.13022433],
#        [ 0.70720763],
#        [ 0.27846115],
#        [ 0.06213313],
#        [ 0.48631848],
#        [ 0.51629164],
#        [ 0.37978345],
#        [ 0.06897483],
#        [-0.17146202],
#        [-0.25877514],
#        [-0.31937304],
#        [-0.37834197],
#        [-0.29656738],
#        [ 0.1123056 ],
#        [ 0.2344788 ],
#        [-0.10304503],
#        [-0.26626843],
#        [-0.33110167],
#        [-0.36433278],
#        [-0.07600403],
#        [-0.19100973]])

# %% [markdown]
# ## Evaluation metics

# %% [raw]
# !pip install hydroeval

# %%
###nse

import hydroeval as he
nse = he.evaluator(he.nse, Y_pred, y_test[:,-1:]  )
print(nse)
# Out:
# [0.75680404]

# %%
##rmse
rmse = he.evaluator(he.rmse, Y_pred, y_test[:,-1:]  )
print(rmse)
# Out:
# [0.49269804]

# %%
###logrmse
from sklearn.metrics import mean_squared_error
#### log of predicted values
y_pred_lg = np.log1p(Y_pred)

#### log of test values
y_test_lg = np.log1p(y_test[:,-1:])

# %%
##calculate mse
mse = mean_squared_error(y_pred_lg, y_test_lg)
rmse_lg = np.sqrt(mse)   
print(rmse_lg)
# Out:
# 0.4271424664660639

# %% [markdown]
# ## g. plot

# %%
import matplotlib.pyplot as plt
# plt.plot(Q_pred)
# plt.plot(y_test)

plt.figure(figsize = (16, 12))

plt.subplot(2, 1, 1)

plt.plot(Y_pred[:,-1],'b', label = "Predicted")

plt.plot(y_test[:,-1], 'm',  label = "Observed")  

plt.legend()
plt.grid()

plt.subplot(2,1,2)

plt.plot(Y_pred[:,-1] - y_test[:,-1],'r', label = "Error")

plt.legend()

plt.grid()

# %% [markdown]
# ##  save_model

# %% [raw]
# save_model(Y_pred,'MLP_hT_1.h5')  #### recommended to save as .h5 file

# %% [markdown]
# ## h. Denormalize the data

# %%
#### Original data
df_train_norm

# df_val_f

# df_test_f
# Out:
#                   Rt     R_t_1     R_t_2     R_t_3     R_t_4     R_t_5  \
# Date
# 09/10/2000  1.774218  1.181452 -0.366196 -0.184231 -0.442218  0.558794
# 10/10/2000  2.639196  1.773159  1.181413 -0.366309 -0.184270 -0.442644
# 11/10/2000  0.954766  2.637962  1.773146  1.181349 -0.366351 -0.184698
# 12/10/2000  2.715071  0.953872  2.637986  1.773101  1.181334 -0.366777
# 13/10/2000 -0.198537  2.713822  0.953823  2.637969  1.773096  1.180899
# ...              ...       ...       ...       ...       ...       ...
# 28/09/2007 -0.532388 -0.608843 -0.502750  0.528905  0.240584  3.350681
# 29/09/2007 -0.532388 -0.532983 -0.608958 -0.502867  0.528879  0.240155
# 30/09/2007 -0.441338 -0.532983 -0.533095 -0.609079 -0.502911  0.528447
# 01/10/2007 -0.593088 -0.441951 -0.533095 -0.533213 -0.609125 -0.503337
# 02/10/2007 -0.608263 -0.593671 -0.442059 -0.533213 -0.533258 -0.609550
#
#                R_t_6     R_t_7     R_t_8        Qt
# Date
# 09/10/2000  0.558342 -0.170123  1.346565  1.134868
# 10/10/2000  0.558342  0.558236 -0.170393  1.226337
# 11/10/2000 -0.443107  0.558236  0.557747  1.872033
# 12/10/2000 -0.185158 -0.443258  0.557747  2.910104
# 13/10/2000 -0.367240 -0.185297 -0.443445  2.542519
# ...              ...       ...       ...       ...
# 28/09/2007 -0.245852  0.300276  0.132999 -0.435775
# 29/09/2007  3.350262 -0.245994  0.299864 -0.514136
# 30/09/2007  0.239699  3.350279 -0.246241 -0.564572
# 01/10/2007  0.527995  0.239579  3.348949 -0.596031
# 02/10/2007 -0.503801  0.527888  0.239186 -0.617687
#
# [2550 rows x 10 columns]

# %%
### normalized data after model training
Y_pred    #### model out put
# y_obser = y_test[:,-1:]      ## observed discharge
# Out:
# array([[-0.27564934],
#        [-0.42463607],
#        [-0.46951795],
#        [-0.608995  ],
#        [-0.60794896],
#        [-0.58956915],
#        [-0.44033614],
#        [-0.45626637],
#        [-0.16578643],
#        [-0.20501992],
#        [-0.28862   ],
#        [-0.3742473 ],
#        [-0.18032882],
#        [-0.258385  ],
#        [-0.31959578],
#        [-0.4846564 ],
#        [-0.63935643],
#        [-0.51846087],
#        [-0.53098565],
#        [-0.46347472],
#        [-0.546932  ],
#        [-0.46526414],
#        [-0.43010503],
#        [-0.63408864],
#        [-0.6102113 ],
#        [-0.3395688 ],
#        [-0.45739645],
#        [-0.04768024],
#        [ 0.01886435],
#        [-0.26006788],
#        [-0.1320819 ],
#        [-0.23502883],
#        [-0.17743158],
#        [-0.40419272],
#        [-0.31355107],
#        [-0.32203722],
#        [-0.4615416 ],
#        [-0.46056056],
#        [-0.5197119 ],
#        [-0.56375486],
#        [-0.49354786],
#        [-0.5170643 ],
#        [-0.48541778],
#        [-0.02382327],
#        [ 0.69608   ],
#        [ 1.1633196 ],
#        [ 1.4741795 ],
#        [ 1.7512592 ],
#        [ 1.1349543 ],
#        [ 1.0895811 ],
#        [ 0.6970031 ],
#        [ 0.16831586],
#        [-0.12352547],
#        [-0.06553116],
#        [-0.07502145],
#        [-0.11360054],
#        [-0.13886485],
#        [-0.4009319 ],
#        [-0.49456125],
#        [-0.4405478 ],
#        [-0.55990005],
#        [-0.46573687],
#        [-0.44387734],
#        [-0.5860509 ],
#        [-0.69221723],
#        [-0.7964271 ],
#        [ 0.3268349 ],
#        [-0.1028699 ],
#        [-0.31962815],
#        [-0.45152718],
#        [-0.40939307],
#        [-0.76496094],
#        [-0.5573058 ],
#        [-0.41581786],
#        [-0.4693855 ],
#        [-0.4788584 ],
#        [-0.47457796],
#        [-0.35751498],
#        [-0.55534005],
#        [-0.4189156 ],
#        [-0.44337168],
#        [-0.3536707 ],
#        [-0.3020307 ],
#        [-0.4446267 ],
#        [-0.46754578],
#        [-0.6332795 ],
#        [-0.61749786],
#        [-0.6401643 ],
#        [-0.6135741 ],
#        [-0.6430724 ],
#        [-0.5589321 ],
#        [-0.51839465],
#        [-0.34382668],
#        [-0.39546233],
#        [-0.25469884],
#        [ 0.70187443],
#        [ 0.86222965],
#        [ 0.54575294],
#        [ 0.03068087],
#        [-0.13455366],
#        [-0.07678527],
#        [ 0.6329271 ],
#        [ 0.72564393],
#        [ 0.22873032],
#        [ 0.02994223],
#        [ 0.98802173],
#        [ 3.1917696 ],
#        [ 2.144223  ],
#        [ 1.5255231 ],
#        [ 0.6834244 ],
#        [ 0.59361446],
#        [ 0.72204506],
#        [ 0.5757263 ],
#        [ 0.7174533 ],
#        [ 0.054477  ],
#        [ 0.3494231 ],
#        [ 0.60767233],
#        [ 0.7655795 ],
#        [ 1.44883   ],
#        [ 0.94660294],
#        [ 0.5075816 ],
#        [ 0.60326403],
#        [ 0.05435231],
#        [ 0.21389866],
#        [ 0.35640705],
#        [ 0.22207211],
#        [-0.32818326],
#        [-0.5166798 ],
#        [-0.40858427],
#        [-0.55063653],
#        [-0.44497776],
#        [-0.3356565 ],
#        [-0.5387922 ],
#        [-0.62103695],
#        [-0.5503786 ],
#        [-0.5311244 ],
#        [-0.4822864 ],
#        [-0.40874976],
#        [-0.505964  ],
#        [-0.45333248],
#        [-0.4482296 ],
#        [-0.6458276 ],
#        [-0.40572473],
#        [-0.77079886],
#        [-0.30855313],
#        [-0.37063843],
#        [ 0.14143172],
#        [ 0.19871151],
#        [-0.1547784 ],
#        [-0.09264433],
#        [-0.13357115],
#        [ 0.22038925],
#        [ 0.51231813],
#        [ 1.3170667 ],
#        [ 1.9571505 ],
#        [ 1.2456177 ],
#        [ 0.46062538],
#        [ 0.03355744],
#        [ 0.11705614],
#        [-0.03332585],
#        [-0.13676894],
#        [-0.19791713],
#        [-0.3828817 ],
#        [-0.5215612 ],
#        [-0.4537042 ],
#        [-0.40198722],
#        [-0.5140272 ],
#        [-0.53178865],
#        [-0.69115996],
#        [-0.69054574],
#        [-0.6897626 ],
#        [-0.6872497 ],
#        [-0.6890896 ],
#        [-0.6821048 ],
#        [-0.6813733 ],
#        [-0.6697884 ],
#        [-0.6653797 ],
#        [-0.6666614 ],
#        [-0.6502983 ],
#        [-0.6564485 ],
#        [-0.6539529 ],
#        [-0.65965956],
#        [-0.6790222 ],
#        [-0.673669  ],
#        [-0.6602604 ],
#        [-0.6525611 ],
#        [-0.58920616],
#        [ 0.14215739],
#        [ 0.9621666 ],
#        [ 0.10257484],
#        [ 0.15484399],
#        [-0.08956912],
#        [-0.09914279],
#        [-0.07033047],
#        [-0.1103074 ],
#        [-0.43747753],
#        [-0.41925776],
#        [-0.40909296],
#        [-0.29275092],
#        [-0.4903072 ],
#        [-0.57564116],
#        [-0.6540974 ],
#        [-0.51245505],
#        [-0.741154  ],
#        [-0.34079492],
#        [-0.25995508],
#        [-0.44627935],
#        [-0.39206836],
#        [-0.14955005],
#        [-0.26138335],
#        [-0.6820211 ],
#        [-0.30346677],
#        [ 0.34068456],
#        [ 1.1806664 ],
#        [ 0.92652136],
#        [ 1.1222298 ],
#        [ 0.7161062 ],
#        [ 0.882215  ],
#        [ 0.9795521 ],
#        [ 1.833047  ],
#        [ 1.5835235 ],
#        [ 0.6175372 ],
#        [ 0.43799874],
#        [ 0.06045924],
#        [ 0.7816588 ],
#        [ 2.4083629 ],
#        [ 3.9778085 ],
#        [ 3.6702724 ],
#        [ 2.7386706 ],
#        [ 2.2550294 ],
#        [ 2.7918768 ],
#        [ 2.4502187 ],
#        [ 3.4012918 ],
#        [ 3.0220163 ],
#        [ 3.3428707 ],
#        [ 2.6533866 ],
#        [ 2.242544  ],
#        [ 2.3229058 ],
#        [ 1.9377393 ],
#        [ 2.4493418 ],
#        [ 2.4776118 ],
#        [ 2.1139593 ],
#        [ 1.0711603 ],
#        [ 0.720628  ],
#        [ 1.3288113 ],
#        [ 1.6017228 ],
#        [ 0.93843585],
#        [ 1.5543348 ],
#        [ 1.9871286 ],
#        [ 2.4621649 ],
#        [ 1.974319  ],
#        [ 1.6237582 ],
#        [ 1.1346341 ],
#        [ 0.26214227],
#        [ 0.03531565],
#        [-0.2210567 ],
#        [-0.26003808],
#        [-0.29427242],
#        [-0.40207762],
#        [-0.5018987 ],
#        [-0.67436713],
#        [-0.6525562 ],
#        [-0.61703414],
#        [-0.6404991 ],
#        [-0.5286066 ],
#        [-0.66268414],
#        [-0.40144235],
#        [-0.35643718],
#        [ 0.54227525],
#        [ 0.8033143 ],
#        [ 0.05117355],
#        [ 0.21457304],
#        [ 0.9455827 ],
#        [ 0.8489999 ],
#        [ 0.04535471],
#        [ 0.07528573],
#        [-0.08102446],
#        [-0.32261077],
#        [-0.24644744],
#        [-0.20580882],
#        [-0.2849962 ],
#        [-0.40822014],
#        [-0.4088177 ],
#        [-0.42837733],
#        [-0.5534315 ],
#        [-0.4064123 ],
#        [-0.46903223],
#        [-0.61200696],
#        [ 0.00814034],
#        [ 1.046423  ],
#        [ 0.34301013],
#        [ 0.27445588],
#        [-0.13612936],
#        [-0.054221  ],
#        [-0.0126586 ],
#        [ 0.53211665],
#        [ 0.20410031],
#        [-0.33863205],
#        [-0.48002374],
#        [-0.3674735 ],
#        [-0.35328487],
#        [-0.03568906],
#        [-0.06371122],
#        [-0.6100006 ],
#        [-0.28482985],
#        [-0.40163112],
#        [-0.22449082],
#        [ 0.20362833],
#        [ 0.38151088],
#        [ 0.17890792],
#        [-0.17486528],
#        [-0.19226576],
#        [-0.26563922],
#        [-0.28648195],
#        [-0.31471896],
#        [-0.4351164 ],
#        [-0.59983975],
#        [-0.6762458 ],
#        [-0.6815892 ],
#        [-0.64817065],
#        [-0.6204675 ],
#        [-0.6106436 ],
#        [-0.583317  ],
#        [-0.5448349 ],
#        [-0.46771318],
#        [-0.4087991 ],
#        [-0.3464144 ],
#        [-0.37118208],
#        [-0.50012845],
#        [-0.47764778],
#        [-0.443885  ],
#        [-0.36761445],
#        [-0.4034543 ],
#        [-0.5126762 ],
#        [-0.4532447 ],
#        [-0.4459114 ],
#        [-0.46960497],
#        [-0.48046064],
#        [-0.48854548],
#        [-0.56854403],
#        [-0.67308694],
#        [-0.69002354],
#        [-0.6880012 ],
#        [-0.6878714 ],
#        [-0.6804901 ],
#        [-0.67802995],
#        [-0.6709282 ],
#        [-0.68448263],
#        [-0.6606309 ],
#        [-0.64425457],
#        [-0.63279474],
#        [-0.600396  ],
#        [-0.15665156],
#        [-0.48493528],
#        [-0.14029893],
#        [-0.29907712],
#        [-0.13893087],
#        [ 0.40755406],
#        [ 1.5480425 ],
#        [ 0.9213335 ],
#        [ 0.146418  ],
#        [ 0.37270224],
#        [ 1.8683549 ],
#        [ 2.5297706 ],
#        [ 1.6811541 ],
#        [ 1.4655789 ],
#        [ 0.9747468 ],
#        [ 0.41330546],
#        [ 0.27119207],
#        [ 0.23272347],
#        [ 0.23473835],
#        [-0.26683012],
#        [-0.31907   ],
#        [-0.4830798 ],
#        [-0.44026303],
#        [-0.5357135 ],
#        [-0.5005006 ],
#        [-0.4824313 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.68625146],
#        [-0.66497415],
#        [-0.6556379 ],
#        [-0.6272309 ],
#        [-0.6579824 ],
#        [-0.5907471 ],
#        [-0.49135035],
#        [-0.38398647],
#        [-0.1608885 ],
#        [-0.33207697],
#        [-0.3437059 ],
#        [-0.30890226],
#        [-0.2693859 ],
#        [-0.3162291 ],
#        [-0.39895475],
#        [-0.42988873],
#        [-0.5727174 ],
#        [-0.52639383],
#        [-0.49631935],
#        [-0.46816385],
#        [-0.5378422 ],
#        [-0.55921656],
#        [-0.50383735],
#        [-0.5301755 ],
#        [-0.43883547],
#        [-0.40767485],
#        [-0.4161666 ],
#        [-0.36927852],
#        [-0.5375664 ],
#        [-0.5758819 ],
#        [-0.64094514],
#        [-0.6423964 ],
#        [-0.63713807],
#        [-0.6845466 ],
#        [-0.6666822 ],
#        [-0.6253209 ],
#        [-0.6310656 ],
#        [-0.5234427 ],
#        [-0.4208156 ],
#        [-0.5435163 ],
#        [-0.41621467],
#        [-0.5251938 ],
#        [-0.35297757],
#        [-0.46750247],
#        [-0.255076  ],
#        [-0.2445172 ],
#        [-0.18835884],
#        [-0.15546298],
#        [-0.18163188],
#        [-0.20317559],
#        [-0.28214955],
#        [-0.25209257],
#        [-0.28680015],
#        [-0.42623392],
#        [-0.48349404],
#        [-0.6155386 ],
#        [-0.5946514 ],
#        [-0.59600395],
#        [-0.5860509 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.6934515 ],
#        [-0.68028575],
#        [-0.6447641 ],
#        [-0.68405885],
#        [-0.6959075 ],
#        [ 0.10264495],
#        [-0.42604706],
#        [-0.411739  ],
#        [-0.4736293 ],
#        [-0.360771  ],
#        [-0.5647879 ],
#        [-0.2599378 ],
#        [-0.16085467],
#        [-0.50327563],
#        [-0.49352038],
#        [-0.48362345],
#        [-0.44050634],
#        [ 0.11795355],
#        [ 1.3303236 ],
#        [ 1.3071803 ],
#        [ 0.9628495 ],
#        [ 0.74100846],
#        [ 0.7045154 ],
#        [ 2.499832  ],
#        [ 4.5696907 ],
#        [ 3.4340231 ],
#        [ 1.767397  ],
#        [ 0.73738366],
#        [ 0.4757632 ],
#        [ 0.24571902],
#        [ 0.08142545],
#        [-0.24457443],
#        [-0.40284732],
#        [-0.45573646],
#        [-0.4781754 ],
#        [-0.49694902],
#        [-0.42681664],
#        [-0.6069556 ],
#        [-0.533759  ],
#        [-0.5747534 ],
#        [-0.41057372],
#        [-0.43328482],
#        [-0.46834192],
#        [-0.49338812],
#        [-0.4729076 ],
#        [-0.42816937],
#        [-0.4983114 ],
#        [-0.5191757 ],
#        [-0.50981927],
#        [-0.5954846 ],
#        [-0.5806157 ],
#        [-0.5667104 ],
#        [-0.55495286],
#        [-0.5160491 ],
#        [ 0.22589123],
#        [ 0.49771047],
#        [ 0.37464103],
#        [ 0.22162142],
#        [-0.16762075],
#        [-0.14479098],
#        [ 0.38180318],
#        [ 0.31855604],
#        [-0.47493833],
#        [-0.4119463 ],
#        [-0.38938114],
#        [-0.56730086],
#        [-0.5442969 ],
#        [-0.47668105],
#        [-0.6485474 ],
#        [-0.6493121 ],
#        [-0.63944054],
#        [-0.7079072 ],
#        [-0.22541136],
#        [-0.11357518],
#        [ 0.14005609],
#        [ 0.3515563 ],
#        [ 0.9462244 ],
#        [ 0.5076811 ],
#        [ 0.41991842],
#        [ 0.61522573],
#        [ 0.4534207 ],
#        [ 0.20240739],
#        [-0.16495645],
#        [-0.27584815],
#        [-0.3387577 ],
#        [-0.45141125],
#        [-0.33747548],
#        [-0.4845993 ],
#        [-0.21227407],
#        [-0.12163253],
#        [-0.5242683 ],
#        [-0.41371977],
#        [-0.42065138],
#        [-0.32528734],
#        [ 0.15097629],
#        [ 0.6727517 ]], dtype=float32)

# %%
def denormalize(data, original_data, type='min_max'):   ### default is min-max in this case(there is no reason behind this)

    if type == 'min_max':
        min = np.min(original_data)
        max = np.max(original_data)
        data = data * (max - min) + min
    elif type == 'z_score':
        mean = np.mean(original_data)
        std = np.std(original_data)
        data = data * std + mean
    elif type == 'max':                
        max = np.max(original_data)
        data = data * max
    else:
        raise ValueError("Invalid normalization type. Choose either 'max', 'min_max', or 'z_score'.")
    return data

# %%
Y_observ_unnorm = df_test['Qt']

# %%
Y_observ_unnorm = Y_observ_unnorm.to_numpy()

# %% [markdown]
# ###  denormalized predicted discharge

# %%
### Standard denormalization (becasue we used standard(z-score) in this experiment)

Y_pred_denorm = denormalize(Y_pred, Y_observ_unnorm, type='z_score')

# %%
print(Y_pred_denorm)
print(Y_pred_denorm.shape)
# Out:
# [[ 17.009798 ]
#  [ 12.440963 ]
#  [ 11.064612 ]
#  [  6.7873993]
#  [  6.819479 ]
#  [  7.383114 ]
#  [ 11.959503 ]
#  [ 11.470985 ]
#  [ 20.37886  ]
#  [ 19.175724 ]
#  [ 16.61204  ]
#  [ 13.986187 ]
#  [ 19.932903 ]
#  [ 17.539227 ]
#  [ 15.662134 ]
#  [ 10.600375 ]
#  [  5.8563347]
#  [  9.563725 ]
#  [  9.17964  ]
#  [ 11.249934 ]
#  [  8.690628 ]
#  [ 11.19506  ]
#  [ 12.273251 ]
#  [  6.0178776]
#  [  6.750101 ]
#  [ 15.049641 ]
#  [ 11.436331 ]
#  [ 24.000711 ]
#  [ 26.041372 ]
#  [ 17.487621 ]
#  [ 21.412445 ]
#  [ 18.25547  ]
#  [ 20.02175  ]
#  [ 13.06788  ]
#  [ 15.847502 ]
#  [ 15.587265 ]
#  [ 11.309216 ]
#  [ 11.3393   ]
#  [  9.525361 ]
#  [  8.174738 ]
#  [ 10.327709 ]
#  [  9.606553 ]
#  [ 10.577026 ]
#  [ 24.732311 ]
#  [ 46.808907 ]
#  [ 61.137306 ]
#  [ 70.67015  ]
#  [ 79.1671   ]
#  [ 60.267456 ]
#  [ 58.876038 ]
#  [ 46.83722  ]
#  [ 30.624462 ]
#  [ 21.674837 ]
#  [ 23.453295 ]
#  [ 23.162266 ]
#  [ 21.979197 ]
#  [ 21.20444  ]
#  [ 13.167876 ]
#  [ 10.296633 ]
#  [ 11.953012 ]
#  [  8.29295  ]
#  [ 11.180563 ]
#  [ 11.850908 ]
#  [  7.491005 ]
#  [  4.235302 ]
#  [  1.0395966]
#  [ 35.485615 ]
#  [ 22.308262 ]
#  [ 15.661141 ]
#  [ 11.616318 ]
#  [ 12.908405 ]
#  [  2.0045395]
#  [  8.372503 ]
#  [ 12.711382 ]
#  [ 11.068673 ]
#  [ 10.778176 ]
#  [ 10.909441 ]
#  [ 14.499302 ]
#  [  8.432787 ]
#  [ 12.616386 ]
#  [ 11.866415 ]
#  [ 14.617191 ]
#  [ 16.200787 ]
#  [ 11.827929 ]
#  [ 11.125091 ]
#  [  6.0426903]
#  [  6.5266514]
#  [  5.83156  ]
#  [  6.6469784]
#  [  5.74238  ]
#  [  8.322632 ]
#  [  9.565756 ]
#  [ 14.919067 ]
#  [ 13.335606 ]
#  [ 17.652267 ]
#  [ 46.986603 ]
#  [ 51.90406  ]
#  [ 42.198967 ]
#  [ 26.403738 ]
#  [ 21.336647 ]
#  [ 23.108175 ]
#  [ 44.872257 ]
#  [ 47.715515 ]
#  [ 32.477135 ]
#  [ 26.381088 ]
#  [ 55.761612 ]
#  [123.34187  ]
#  [ 91.21774  ]
#  [ 72.24466  ]
#  [ 46.42081  ]
#  [ 43.666695 ]
#  [ 47.605156 ]
#  [ 43.118134 ]
#  [ 47.46434  ]
#  [ 27.133472 ]
#  [ 36.178307 ]
#  [ 44.097794 ]
#  [ 48.940186 ]
#  [ 69.892784 ]
#  [ 54.49146  ]
#  [ 41.028404 ]
#  [ 43.96261  ]
#  [ 27.129648 ]
#  [ 32.02231  ]
#  [ 36.39248  ]
#  [ 32.272953 ]
#  [ 15.398789 ]
#  [  9.618343 ]
#  [ 12.9332075]
#  [  8.577024 ]
#  [ 11.8171625]
#  [ 15.169615 ]
#  [  8.940245 ]
#  [  6.4181213]
#  [  8.584934 ]
#  [  9.1753845]
#  [ 10.673054 ]
#  [ 12.928133 ]
#  [  9.946956 ]
#  [ 11.560956 ]
#  [ 11.717442 ]
#  [  5.6578903]
#  [ 13.020899 ]
#  [  1.8255138]
#  [ 16.000769 ]
#  [ 14.096857 ]
#  [ 29.80003  ]
#  [ 31.556576 ]
#  [ 20.716434 ]
#  [ 22.621841 ]
#  [ 21.366776 ]
#  [ 32.221348 ]
#  [ 41.173656 ]
#  [ 65.85212  ]
#  [ 85.48097  ]
#  [ 63.661064 ]
#  [ 39.588444 ]
#  [ 26.491951 ]
#  [ 29.052528 ]
#  [ 24.440905 ]
#  [ 21.268713 ]
#  [ 19.39354  ]
#  [ 13.721404 ]
#  [  9.46865  ]
#  [ 11.549557 ]
#  [ 13.135513 ]
#  [  9.699689 ]
#  [  9.155014 ]
#  [  4.267725 ]
#  [  4.28656  ]
#  [  4.3105774]
#  [  4.387636 ]
#  [  4.331215 ]
#  [  4.54541  ]
#  [  4.5678425]
#  [  4.9231052]
#  [  5.058304 ]
#  [  5.018999 ]
#  [  5.52079  ]
#  [  5.3321896]
#  [  5.408718 ]
#  [  5.233717 ]
#  [  4.639942 ]
#  [  4.804104 ]
#  [  5.215294 ]
#  [  5.451399 ]
#  [  7.394247 ]
#  [ 29.822285 ]
#  [ 54.968735 ]
#  [ 28.608444 ]
#  [ 30.211332 ]
#  [ 22.716145 ]
#  [ 22.422558 ]
#  [ 23.306118 ]
#  [ 22.080185 ]
#  [ 12.047165 ]
#  [ 12.605894 ]
#  [ 12.917608 ]
#  [ 16.48536  ]
#  [ 10.427087 ]
#  [  7.810232 ]
#  [  5.4042873]
#  [  9.7479   ]
#  [  2.734604 ]
#  [ 15.01204  ]
#  [ 17.49108  ]
#  [ 11.777248 ]
#  [ 13.439686 ]
#  [ 20.876766 ]
#  [ 17.44728  ]
#  [  4.5479774]
#  [ 16.156746 ]
#  [ 35.91033  ]
#  [ 61.669266 ]
#  [ 53.875637 ]
#  [ 59.877243 ]
#  [ 47.423035 ]
#  [ 52.516937 ]
#  [ 55.50188  ]
#  [ 81.67521  ]
#  [ 74.0233   ]
#  [ 44.40031  ]
#  [ 38.894573 ]
#  [ 27.316923 ]
#  [ 49.433273 ]
#  [ 99.31787  ]
#  [147.4466   ]
#  [138.01567  ]
#  [109.44711  ]
#  [ 94.615746 ]
#  [111.078735 ]
#  [100.601425 ]
#  [129.76709  ]
#  [118.13621  ]
#  [127.97555  ]
#  [106.83179  ]
#  [ 94.232864 ]
#  [ 96.69724  ]
#  [ 84.885704 ]
#  [100.57454  ]
#  [101.44147  ]
#  [ 90.28968  ]
#  [ 58.311142 ]
#  [ 47.5617   ]
#  [ 66.21228  ]
#  [ 74.581406 ]
#  [ 54.241005 ]
#  [ 73.1282   ]
#  [ 86.40028  ]
#  [100.96777  ]
#  [ 86.00746  ]
#  [ 75.25714  ]
#  [ 60.257637 ]
#  [ 33.501747 ]
#  [ 26.54587  ]
#  [ 18.683939 ]
#  [ 17.488533 ]
#  [ 16.438702 ]
#  [ 13.132741 ]
#  [ 10.071622 ]
#  [  4.782694 ]
#  [  5.4515514]
#  [  6.5408726]
#  [  5.821293 ]
#  [  9.252596 ]
#  [  5.1409664]
#  [ 13.152223 ]
#  [ 14.532353 ]
#  [ 42.092323 ]
#  [ 50.097363 ]
#  [ 27.03217  ]
#  [ 32.042988 ]
#  [ 54.460175 ]
#  [ 51.49836  ]
#  [ 26.853727 ]
#  [ 27.771595 ]
#  [ 22.978176 ]
#  [ 15.569676 ]
#  [ 17.905306 ]
#  [ 19.151531 ]
#  [ 16.723167 ]
#  [ 12.944374 ]
#  [ 12.926049 ]
#  [ 12.326233 ]
#  [  8.491314 ]
#  [ 12.999813 ]
#  [ 11.079507 ]
#  [  6.695036 ]
#  [ 25.71251  ]
#  [ 57.552544 ]
#  [ 35.981647 ]
#  [ 33.879356 ]
#  [ 21.288326 ]
#  [ 23.800133 ]
#  [ 25.074688 ]
#  [ 41.7808   ]
#  [ 31.721828 ]
#  [ 15.078367 ]
#  [ 10.74244  ]
#  [ 14.1939125]
#  [ 14.629023 ]
#  [ 24.368435 ]
#  [ 23.509106 ]
#  [  6.756563 ]
#  [ 16.728268 ]
#  [ 13.146434 ]
#  [ 18.578629 ]
#  [ 31.707355 ]
#  [ 37.16231  ]
#  [ 30.949278 ]
#  [ 20.100449 ]
#  [ 19.566845 ]
#  [ 17.316769 ]
#  [ 16.677605 ]
#  [ 15.8116865]
#  [ 12.119572 ]
#  [  7.0681553]
#  [  4.7250824]
#  [  4.561222 ]
#  [  5.5860367]
#  [  6.435585 ]
#  [  6.736843 ]
#  [  7.5748444]
#  [  8.754938 ]
#  [ 11.119957 ]
#  [ 12.92662  ]
#  [ 14.839713 ]
#  [ 14.080185 ]
#  [ 10.125909 ]
#  [ 10.815302 ]
#  [ 11.850674 ]
#  [ 14.18959  ]
#  [ 13.090524 ]
#  [  9.741119 ]
#  [ 11.563649 ]
#  [ 11.788531 ]
#  [ 11.061943 ]
#  [ 10.729043 ]
#  [ 10.4811125]
#  [  8.027872 ]
#  [  4.821953 ]
#  [  4.302574 ]
#  [  4.3645916]
#  [  4.368572 ]
#  [  4.5949287]
#  [  4.67037  ]
#  [  4.888153 ]
#  [  4.472492 ]
#  [  5.203932 ]
#  [  5.706129 ]
#  [  6.057556 ]
#  [  7.051098 ]
#  [ 20.65899  ]
#  [ 10.591823 ]
#  [ 21.160461 ]
#  [ 16.29136  ]
#  [ 21.202415 ]
#  [ 37.960953 ]
#  [ 72.93524  ]
#  [ 53.716545 ]
#  [ 29.95294  ]
#  [ 36.892185 ]
#  [ 82.75796  ]
#  [103.04097  ]
#  [ 77.01725  ]
#  [ 70.40641  ]
#  [ 55.354523 ]
#  [ 38.13733  ]
#  [ 33.77927  ]
#  [ 32.59959  ]
#  [ 32.661377 ]
#  [ 17.280249 ]
#  [ 15.678257 ]
#  [ 10.648724 ]
#  [ 11.961745 ]
#  [  9.034655 ]
#  [ 10.114495 ]
#  [ 10.668611 ]
#  [  4.1974506]
#  [  4.1974506]
#  [  4.1974506]
#  [  4.1974506]
#  [  4.1974506]
#  [  4.1974506]
#  [  4.1974506]
#  [  4.1974506]
#  [  4.1974506]
#  [  4.418249 ]
#  [  5.0707397]
#  [  5.357046 ]
#  [  6.228178 ]
#  [  5.2851486]
#  [  7.3469906]
#  [ 10.395098 ]
#  [ 13.687525 ]
#  [ 20.52906  ]
#  [ 15.279386 ]
#  [ 14.922771 ]
#  [ 15.990062 ]
#  [ 17.201874 ]
#  [ 15.765377 ]
#  [ 13.228507 ]
#  [ 12.279884 ]
#  [  7.899891 ]
#  [  9.320454 ]
#  [ 10.242719 ]
#  [ 11.106137 ]
#  [  8.969376 ]
#  [  8.31391  ]
#  [ 10.012171 ]
#  [  9.204483 ]
#  [ 12.005523 ]
#  [ 12.961096 ]
#  [ 12.700687 ]
#  [ 14.13856  ]
#  [  8.977833 ]
#  [  7.802849 ]
#  [  5.8076153]
#  [  5.763111 ]
#  [  5.924364 ]
#  [  4.4705315]
#  [  5.018362 ]
#  [  6.286749 ]
#  [  6.1105824]
#  [  9.4109535]
#  [ 12.558122 ]
#  [  8.795374 ]
#  [ 12.699213 ]
#  [  9.357252 ]
#  [ 14.638446 ]
#  [ 11.126418 ]
#  [ 17.640701 ]
#  [ 17.964499 ]
#  [ 19.686653 ]
#  [ 20.69544  ]
#  [ 19.892944 ]
#  [ 19.232283 ]
#  [ 16.810463 ]
#  [ 17.732191 ]
#  [ 16.667847 ]
#  [ 12.391963 ]
#  [ 10.63602  ]
#  [  6.586735 ]
#  [  7.2272625]
#  [  7.1857853]
#  [  7.491005 ]
#  [  4.1974506]
#  [  4.1974506]
#  [  4.1974506]
#  [  4.1974506]
#  [  4.1974506]
#  [  4.1974506]
#  [  4.6011944]
#  [  5.690502 ]
#  [  4.485489 ]
#  [  4.122137 ]
#  [ 28.610594 ]
#  [ 12.397693 ]
#  [ 12.836465 ]
#  [ 10.938533 ]
#  [ 14.399452 ]
#  [  8.143057 ]
#  [ 17.49161  ]
#  [ 20.530098 ]
#  [ 10.029397 ]
#  [ 10.328552 ]
#  [ 10.632051 ]
#  [ 11.954284 ]
#  [ 29.080048 ]
#  [ 66.25866  ]
#  [ 65.54894  ]
#  [ 54.989677 ]
#  [ 48.186687 ]
#  [ 47.06759  ]
#  [102.12287  ]
#  [165.59727  ]
#  [130.77084  ]
#  [ 79.66198  ]
#  [ 48.07553  ]
#  [ 40.052658 ]
#  [ 32.99811  ]
#  [ 27.959875 ]
#  [ 17.962744 ]
#  [ 13.109138 ]
#  [ 11.487236 ]
#  [ 10.799122 ]
#  [ 10.223409 ]
#  [ 12.374093 ]
#  [  6.8499413]
#  [  9.094591 ]
#  [  7.8374557]
#  [ 12.872199 ]
#  [ 12.175739 ]
#  [ 11.100677 ]
#  [ 10.332608 ]
#  [ 10.960665 ]
#  [ 12.33261  ]
#  [ 10.18163  ]
#  [  9.541804 ]
#  [  9.82873  ]
#  [  7.2017097]
#  [  7.6576824]
#  [  8.084103 ]
#  [  8.44466  ]
#  [  9.637685 ]
#  [ 32.39007  ]
#  [ 40.725697 ]
#  [ 36.95164  ]
#  [ 32.259132 ]
#  [ 20.322609 ]
#  [ 21.022709 ]
#  [ 37.171276 ]
#  [ 35.231735 ]
#  [ 10.89839  ]
#  [ 12.830108 ]
#  [ 13.522092 ]
#  [  8.065996 ]
#  [  8.771435 ]
#  [ 10.844948 ]
#  [  5.574484 ]
#  [  5.551035 ]
#  [  5.853756 ]
#  [  3.7541523]
#  [ 18.5504   ]
#  [ 21.979975 ]
#  [ 29.757845 ]
#  [ 36.243725 ]
#  [ 54.47985  ]
#  [ 41.031456 ]
#  [ 38.34012  ]
#  [ 44.329426 ]
#  [ 39.367504 ]
#  [ 31.669914 ]
#  [ 20.404312 ]
#  [ 17.0037   ]
#  [ 15.074513 ]
#  [ 11.619873 ]
#  [ 15.113834 ]
#  [ 10.602126 ]
#  [ 18.953268 ]
#  [ 21.732887 ]
#  [  9.385633 ]
#  [ 12.7757225]
#  [ 12.563157 ]
#  [ 15.4875965]
#  [ 30.092724 ]
#  [ 46.09352  ]]
# (547, 1)

# %% [markdown]
# ### denormalized Observed discharge

# %%
len(y_test)
# Out:
# 547

# %%
Y_obser_denorm = denormalize(y_test, Y_observ_unnorm, type='z_score')

# %%
Y_obser_denorm
# Out:
# array([[  8.22477858],
#        [  7.89408128],
#        [  7.73222943],
#        [  7.42251292],
#        [  7.56338398],
#        [  9.7194105 ],
#        [ 12.42193679],
#        [ 11.41286043],
#        [ 11.79251292],
#        [ 11.19306162],
#        [  9.60651384],
#        [  8.98608174],
#        [  8.7822683 ],
#        [  8.49153441],
#        [  9.11496377],
#        [ 10.13403098],
#        [ 10.24393039],
#        [  8.75729116],
#        [  8.01796788],
#        [  7.61433734],
#        [  7.40652755],
#        [  7.19572051],
#        [  6.97192536],
#        [  7.10580282],
#        [  7.85911329],
#        [ 14.91965055],
#        [ 13.16126006],
#        [ 11.97234831],
#        [ 17.44733688],
#        [ 15.16942193],
#        [ 12.78160757],
#        [ 11.78252207],
#        [ 11.34292444],
#        [ 10.85337255],
#        [ 10.47372006],
#        [ 10.16400355],
#        [ 10.14402184],
#        [  9.39270954],
#        [  8.78626464],
#        [  8.13785814],
#        [  7.53940593],
#        [  7.35257694],
#        [  8.2787292 ],
#        [ 27.8677987 ],
#        [ 29.07669216],
#        [ 33.39274154],
#        [ 53.15465283],
#        [ 68.99015809],
#        [ 54.03384808],
#        [ 46.95033185],
#        [ 38.63794044],
#        [ 34.24196422],
#        [ 27.96770725],
#        [ 23.95138352],
#        [ 21.63350515],
#        [ 31.21473514],
#        [ 31.48448823],
#        [ 21.35376121],
#        [ 17.45732774],
#        [ 15.27932133],
#        [ 13.71075709],
#        [ 12.40195508],
#        [ 11.53275069],
#        [ 10.38380236],
#        [ 10.00315078],
#        [ 21.00408128],
#        [ 37.41905613],
#        [ 21.71343199],
#        [ 16.06859888],
#        [ 15.95869948],
#        [ 16.09857145],
#        [ 13.8206565 ],
#        [ 12.28206482],
#        [ 11.2629976 ],
#        [ 11.71258608],
#        [ 10.60360117],
#        [ 11.46281471],
#        [ 10.14402184],
#        [  9.28780556],
#        [  8.65138809],
#        [  8.28072737],
#        [  7.90507122],
#        [  7.42351201],
#        [  6.9279656 ],
#        [  6.4933634 ],
#        [  6.40644296],
#        [  6.23659843],
#        [  5.88492033],
#        [  5.50726601],
#        [  5.20254493],
#        [  5.17656871],
#        [  5.55821937],
#        [  6.46838627],
#        [  6.3624832 ],
#        [  7.0448586 ],
#        [ 14.2202907 ],
#        [ 21.54358745],
#        [ 19.09582796],
#        [ 12.19214712],
#        [  9.18090341],
#        [ 10.51368348],
#        [ 14.98958654],
#        [ 12.52184534],
#        [ 12.05227515],
#        [ 15.3092939 ],
#        [ 38.42813249],
#        [135.49928016],
#        [ 94.07719512],
#        [ 64.51425502],
#        [ 49.99754264],
#        [ 49.89763409],
#        [ 45.90129207],
#        [ 44.70238946],
#        [ 41.1156725 ],
#        [ 35.42088512],
#        [ 38.50805933],
#        [ 37.77872691],
#        [ 42.86407213],
#        [ 74.92472599],
#        [ 59.05924817],
#        [ 49.627881  ],
#        [ 52.06564963],
#        [ 40.40632179],
#        [ 38.65792215],
#        [ 42.9140264 ],
#        [ 36.61978772],
#        [ 30.70520153],
#        [ 26.00949966],
#        [ 22.67255407],
#        [ 20.33469399],
#        [ 19.19573651],
#        [ 17.23752892],
#        [ 16.11855316],
#        [ 18.02680647],
#        [ 14.77977858],
#        [ 13.51093999],
#        [ 12.42193679],
#        [ 11.34292444],
#        [ 10.47372006],
#        [ 10.84338169],
#        [ 12.71167159],
#        [ 11.31295188],
#        [  9.77535929],
#        [ 13.74072966],
#        [ 16.12854401],
#        [ 12.97143382],
#        [ 26.58896925],
#        [ 22.08309362],
#        [ 21.643496  ],
#        [ 20.23478544],
#        [ 17.7770351 ],
#        [ 25.70977401],
#        [ 34.05213798],
#        [ 50.93668301],
#        [ 67.56146581],
#        [ 52.83494547],
#        [ 44.73236202],
#        [ 37.57890981],
#        [ 28.71702138],
#        [ 27.93773468],
#        [ 26.4890607 ],
#        [ 20.83423674],
#        [ 17.92689792],
#        [ 16.01864461],
#        [ 14.5100255 ],
#        [ 13.25117776],
#        [ 12.2421014 ],
#        [ 11.2629976 ],
#        [ 10.42376578],
#        [  9.79034557],
#        [  9.2368522 ],
#        [  8.66537529],
#        [  8.2167859 ],
#        [  7.93104745],
#        [  7.64031356],
#        [  7.31561077],
#        [  6.99290616],
#        [  6.73614118],
#        [  6.48537072],
#        [  6.28055819],
#        [  6.10971457],
#        [  5.94986089],
#        [  5.76403098],
#        [  5.56021754],
#        [  5.44032728],
#        [  5.3494105 ],
#        [  5.36939221],
#        [ 20.08492261],
#        [ 29.36642696],
#        [ 16.69802275],
#        [ 12.5318362 ],
#        [ 13.74072966],
#        [ 14.18032728],
#        [ 14.71983345],
#        [ 11.80250378],
#        [ 10.79342742],
#        [ 10.19397611],
#        [  9.71041873],
#        [  9.21187506],
#        [  8.81723629],
#        [  8.46555819],
#        [ 10.69351887],
#        [ 12.58179047],
#        [ 11.78252207],
#        [ 12.26208311],
#        [ 15.63899212],
#        [ 13.40104059],
#        [ 12.07225686],
#        [ 12.52184534],
#        [ 13.47097657],
#        [ 12.21212883],
#        [ 18.79610231],
#        [ 23.29198709],
#        [ 93.19799988],
#        [ 57.03110459],
#        [ 53.8739944 ],
#        [ 47.76958196],
#        [ 53.42440592],
#        [ 69.53965512],
#        [ 87.06361487],
#        [ 75.92381149],
#        [ 56.09196422],
#        [ 46.26096285],
#        [ 41.57525183],
#        [ 64.13460253],
#        [138.79626233],
#        [236.00728197],
#        [176.06215167],
#        [151.08501404],
#        [103.1289098 ],
#        [131.00339539],
#        [139.59553073],
#        [181.15748774],
#        [189.94944019],
#        [156.97961852],
#        [123.01071135],
#        [102.02991574],
#        [108.02442877],
#        [ 90.32063362],
#        [ 85.71484944],
#        [109.22333138],
#        [ 94.88645438],
#        [ 76.99283298],
#        [ 65.14367889],
#        [ 82.39788557],
#        [ 74.95469855],
#        [ 70.26898753],
#        [107.32506892],
#        [122.51116859],
#        [151.18492259],
#        [118.81455222],
#        [ 92.35876805],
#        [ 71.89749691],
#        [ 56.01203738],
#        [ 46.38085311],
#        [ 41.17561763],
#        [ 37.90860802],
#        [ 33.48265924],
#        [ 28.69703967],
#        [ 25.03039586],
#        [ 22.01315764],
#        [ 21.85330396],
#        [ 21.35376121],
#        [ 19.01590112],
#        [ 17.15760208],
#        [ 16.76795874],
#        [ 19.33560849],
#        [ 32.4236286 ],
#        [ 48.95849371],
#        [ 51.87582339],
#        [ 46.05115489],
#        [ 53.99388466],
#        [ 62.69591941],
#        [ 50.88672874],
#        [ 42.12474886],
#        [ 38.43812334],
#        [ 34.73151612],
#        [ 28.61711283],
#        [ 26.74882293],
#        [ 23.70161214],
#        [ 20.17484031],
#        [ 17.26750149],
#        [ 17.82698937],
#        [ 16.53816907],
#        [ 15.55906528],
#        [ 15.20938535],
#        [ 15.0195591 ],
#        [ 16.91782156],
#        [ 78.65131492],
#        [175.96224311],
#        [100.53128748],
#        [ 67.94111831],
#        [ 48.94850286],
#        [ 43.27369719],
#        [ 44.97214255],
#        [ 50.72687505],
#        [ 41.30549874],
#        [ 38.04848   ],
#        [ 34.87138809],
#        [ 29.37641781],
#        [ 27.75789929],
#        [ 32.52353715],
#        [ 45.69148411],
#        [ 39.83684305],
#        [ 33.22289701],
#        [ 29.74607945],
#        [ 43.95307533],
#        [ 47.78956367],
#        [ 45.72145667],
#        [ 39.71695279],
#        [ 35.92042787],
#        [ 31.36459797],
#        [ 28.02765238],
#        [ 24.78062449],
#        [ 22.01315764],
#        [ 19.84514209],
#        [ 18.3764864 ],
#        [ 17.23752892],
#        [ 16.31837026],
#        [ 17.09765695],
#        [ 18.85604744],
#        [ 16.58812335],
#        [ 14.82973286],
#        [ 14.10040044],
#        [ 13.88060163],
#        [ 15.35924818],
#        [ 14.86969628],
#        [ 13.74072966],
#        [ 14.66987918],
#        [ 15.43917502],
#        [ 14.53999806],
#        [ 15.55906528],
#        [ 16.75796788],
#        [ 14.53000721],
#        [ 13.28115032],
#        [ 12.65172646],
#        [ 12.0422843 ],
#        [ 11.54274155],
#        [ 11.23302504],
#        [ 10.62358288],
#        [  9.92322394],
#        [  9.34675161],
#        [  8.90515581],
#        [  8.58744662],
#        [  8.42459568],
#        [  8.17981974],
#        [  7.86710597],
#        [  7.58636295],
#        [  7.31161443],
#        [  7.15575709],
#        [  7.56438306],
#        [  8.96210369],
#        [ 29.26651841],
#        [ 17.70709911],
#        [ 17.14761123],
#        [ 17.30746491],
#        [ 24.81059705],
#        [ 34.47175389],
#        [ 52.64511922],
#        [ 41.85499577],
#        [ 35.50081196],
#        [ 45.72145667],
#        [ 74.24534784],
#        [102.02991574],
#        [ 85.17534327],
#        [ 76.25350971],
#        [ 64.32442878],
#        [ 52.01569536],
#        [ 43.12383436],
#        [ 41.92493175],
#        [ 39.05755636],
#        [ 32.1139121 ],
#        [ 27.12847542],
#        [ 23.93140181],
#        [ 21.37374292],
#        [ 19.24569079],
#        [ 17.51727287],
#        [ 16.04861717],
#        [ 14.72982431],
#        [ 13.56089427],
#        [ 12.68169902],
#        [ 11.86244891],
#        [ 11.13311649],
#        [ 10.47372006],
#        [  9.91023583],
#        [  9.42867662],
#        [  8.98108631],
#        [  8.64639267],
#        [  8.68635609],
#        [  8.29671274],
#        [  7.99798617],
#        [  7.64830625],
#        [  7.94003921],
#        [  8.5065207 ],
#        [  9.35574338],
#        [ 11.87243976],
#        [  9.32976715],
#        [  7.77219285],
#        [  7.24867205],
#        [  7.30262266],
#        [  7.1207891 ],
#        [  6.74413387],
#        [  6.33550789],
#        [  6.13269354],
#        [  5.89191393],
#        [  5.74804562],
#        [  5.61616633],
#        [  6.2176158 ],
#        [  5.97783528],
#        [  5.79500264],
#        [  5.46330625],
#        [  5.24250835],
#        [  5.12561535],
#        [  4.97275526],
#        [  4.81989518],
#        [  4.60009637],
#        [  4.41826281],
#        [  4.24442193],
#        [  4.07557648],
#        [  3.94269811],
#        [  3.83679505],
#        [  3.75487003],
#        [  4.25840913],
#        [  4.14551247],
#        [  4.25840913],
#        [  5.19155499],
#        [  4.40627378],
#        [  4.1085463 ],
#        [  3.7228993 ],
#        [  3.49211055],
#        [  3.39619834],
#        [  3.7019185 ],
#        [  4.73697109],
#        [  6.48237346],
#        [  6.85403327],
#        [  5.15558791],
#        [  4.23842742],
#        [  3.87875664],
#        [  3.65995691],
#        [  3.46313707],
#        [  3.28230259],
#        [  3.11545531],
#        [  3.00056048],
#        [  2.89765467],
#        [  2.78076167],
#        [  2.69783757],
#        [  2.61591256],
#        [  2.54198023],
#        [  2.48303419],
#        [  2.40810277],
#        [  2.35215398],
#        [  2.28821251],
#        [  2.31418874],
#        [  2.41110003],
#        [  2.29320794],
#        [  4.27839084],
#        [  5.74704653],
#        [  4.01263409],
#        [  3.36023126],
#        [  3.03552847],
#        [  2.81373149],
#        [  2.99656414],
#        [  2.94061535],
#        [  2.85769125],
#        [  3.02254036],
#        [  3.31227516],
#        [  3.21036843],
#        [  3.07149555],
#        [  5.56721114],
#        [ 14.94962312],
#        [ 15.93871777],
#        [ 11.09315307],
#        [  9.54357145],
#        [ 10.93329939],
#        [ 59.77858973],
#        [ 88.07269123],
#        [ 54.36354629],
#        [ 41.36544387],
#        [ 28.43727744],
#        [ 21.98318507],
#        [ 19.79518782],
#        [ 18.62625778],
#        [ 15.04953167],
#        [ 13.12129664],
#        [ 12.07225686],
#        [ 13.1312875 ],
#        [ 13.14127835],
#        [ 11.07317136],
#        [  9.69043702],
#        [  9.33875892],
#        [  9.75138124],
#        [  8.65638352],
#        [  8.30770268],
#        [  8.28472371],
#        [  7.55738947],
#        [  6.98890981],
#        [  6.38845943],
#        [  5.98083254],
#        [  5.76103373],
#        [  5.85494777],
#        [  5.64613889],
#        [  5.2325175 ],
#        [  5.21753121],
#        [  5.26848457],
#        [  6.48037529],
#        [ 18.50636752],
#        [ 21.06402641],
#        [ 19.12580053],
#        [ 14.2202907 ],
#        [ 11.74255865],
#        [ 12.38197337],
#        [ 16.04861717],
#        [ 13.03137895],
#        [ 10.80341827],
#        [ 10.03412243],
#        [  9.27881379],
#        [  8.46655728],
#        [  7.83313707],
#        [  7.25766381],
#        [  6.77710369],
#        [  6.47238261],
#        [  6.14068622],
#        [  9.09098572],
#        [ 13.84063821],
#        [ 13.7307388 ],
#        [ 12.05227515],
#        [ 29.45634465],
#        [ 47.15014895],
#        [ 34.0021837 ],
#        [ 27.36825595],
#        [ 40.37634922],
#        [ 41.29550789],
#        [ 37.10933962],
#        [ 27.5780639 ],
#        [ 20.20481287],
#        [ 17.52726372],
#        [ 15.66896468],
#        [ 13.86061992],
#        [ 16.36832454],
#        [ 28.90684762],
#        [ 32.65341827],
#        [ 22.30289244],
#        [ 17.29747406],
#        [ 15.3092939 ],
#        [ 14.29022668],
#        [ 23.1321334 ],
#        [ 19.60536157]])

# %% [markdown]
# # Plot the denomalized data

# %%
plt.figure(figsize = (16, 12))

plt.subplot(2, 1, 1)

plt.plot(Y_pred_denorm,'b', label = "Predicted")

plt.plot(Y_obser_denorm , 'm',  label = "Observed")  

plt.legend()
plt.grid()

plt.subplot(2,1,2)

plt.plot(Y_pred_denorm - Y_obser_denorm ,'r', label = "Error")

plt.legend()

plt.grid()

# %% [markdown]
# ### NSE after denormalization

# %%
nse_d = he.evaluator(he.nse, Y_pred_denorm , Y_obser_denorm  )
print(nse_d)
# Out:
# [0.75680404]

# %% [markdown]
# ### RMSE after denormalization (in m3/sec)

# %%
#### rmse in m3/sec
rmse_d = he.evaluator(he.rmse, Y_pred_denorm, Y_obser_denorm)
print(rmse_d)    ###
# Out:
# [15.10910763]
